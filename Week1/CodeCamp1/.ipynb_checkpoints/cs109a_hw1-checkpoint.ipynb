# %% [markdown]
# # CS 109A/STAT 121A/AC 209A/CSCI E-109A: Homework 1
#
#
#
# **Harvard University**<br/>
# **Fall 2017**<br/>
# **Instructors**: Pavlos Protopapas, Kevin Rader, Rahul Dave, Margo Levine
#
# ---
#
# ### INSTRUCTIONS
#
# **WARNING**: There is web page scraping in this homework. It takes about 40 minutes. **Do not wait till the last minute** to do this homework.
#
# - To submit your assignment follow the instructions given in canvas.
# - Restart the kernel and run the whole notebook again before you submit. There is an important CAVEAT to this. DO NOT run the web-page fetching cells again. (We have provided hints like `# DO NOT RERUN THIS CELL WHEN SUBMITTING` on some of the cells where we provide the code). Instead load your data structures from the JSON files we will ask you to save below. Otherwise you will be waiting for a long time. (Another reason to not wait until the last moment to submit.)
#
# - Do not include your name in the notebook.
#
# ---

# %% [markdown]
# # Homework 1: Rihanna or Mariah?

# %% [markdown]
# Billboard Magazine puts out a top 100 list of "singles" every week. Information from this list, as well as that from music sales, radio, and other sources is used to determine a top-100 "singles" of the year list. A **single** is typically one song, but sometimes can be two songs which are on one "single" record.
#
# In this homework you will:
#
# 1. Scrape Wikipedia to obtain infprmation about the best singers and groups from each year (distinguishing between the two groups) as determined by the Billboard top 100 charts. You will have to clean this data. Along the way you will learn how to save data in json files to avoid repeated scraping.
# 2. Scrape Wikipedia to obtain information on these singers. You will have to scrape the web pages, this time using a cache to guard against network timeouts (or your laptop going to sleep). You will again clean the data, and save it to a json file.
# 3. Use pandas to represent these two datasets and merge them.
# 4. Use the individual and merged datasets to visualize the performance of the artists and their songs. We have kept the amount of analysis limited here for reasons of time; but you might enjoy exploring music genres and other aspects of the music business you can find on these wikipedia pages at your own leisure.

# %% [markdown]
# You should have worked through Lab0 and Lab 1, and Lecture 2.  Lab 2 will help as well.

# %% [markdown]
# As usual, first we import the necessary libraries.  In particular, we use [Seaborn](http://stanford.edu/~mwaskom/software/seaborn/) to give us a nicer default color palette, with our plots being of large (`poster`) size and with a white-grid background.

# %%
# %matplotlib inline
import numpy as np
import scipy as sp
import matplotlib as mpl
import matplotlib.cm as cm
import matplotlib.pyplot as plt
import pandas as pd
import time
pd.set_option('display.width', 500)
pd.set_option('display.max_columns', 100)
pd.set_option('display.notebook_repr_html', True)
import seaborn as sns
sns.set_style("whitegrid")
sns.set_context("poster")

# %%
import requests 
from bs4 import BeautifulSoup

request = requests.get('http://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_1970')
pageBillboard = request.text
soup = BeautifulSoup(pageBillboard, 'html.parser')
pageTables = soup.find_all('table', 'wikitable')
tableRows = [row for row in pageTables[0].find_all('tr')]
print(tableRows)
# tableRows

#we have to get td values of each row
def tdValues(inp):
    return [each for each in inp.find_all('td')]

#iterating from 1st index because in zeroth index only yhe column headings will be present
tdVal = [tdValues(each) for each in tableRows[1:]]
# print(tdVal)
#converting into given dictionary format in homework description
topBillboard = [{'band_singer':each[2].a.string, 'ranking':each[0].string, 'title':each[1].a.string,
                'url':each[2].a['href']} for each in tdVal]
topBillboard
# Out:
# [<tr>
# <th scope="col" style="background:#dde;">No.
# </th>
# <th scope="col" style="background:#dde;">Title
# </th>
# <th scope="col" style="background:#dde;">Artist(s)
# </th></tr>, <tr>
# <td>1</td>
# <td>"<a class="mw-redirect" href="/wiki/Bridge_Over_Troubled_Water_(song)" title="Bridge Over Troubled Water (song)">Bridge Over Troubled Water</a>"</td>
# <td><a href="/wiki/Simon_%26_Garfunkel" title="Simon &amp; Garfunkel">Simon &amp; Garfunkel</a>
# </td></tr>, <tr>
# <td>2</td>
# <td>"<a href="/wiki/(They_Long_to_Be)_Close_to_You" title="(They Long to Be) Close to You">(They Long to Be) Close to You</a>"</td>
# <td><a href="/wiki/The_Carpenters" title="The Carpenters">The Carpenters</a>
# </td></tr>, <tr>
# <td>3</td>
# <td>"<a href="/wiki/American_Woman" title="American Woman">American Woman</a>"</td>
# <td><a href="/wiki/The_Guess_Who" title="The Guess Who">The Guess Who</a>
# </td></tr>, <tr>
# <td>4</td>
# <td>"<a href="/wiki/Raindrops_Keep_Fallin%27_on_My_Head" title="Raindrops Keep Fallin' on My Head">Raindrops Keep Fallin' on My Head</a>"</td>
# <td><a class="mw-redirect" href="/wiki/B.J._Thomas" title="B.J. Thomas">B.J. Thomas</a>
# </td></tr>, <tr>
# <td>5</td>
# <td>"<a href="/wiki/War_(The_Temptations_song)#Edwin_Starr_version" title="War (The Temptations song)">War</a>"</td>
# <td><a href="/wiki/Edwin_Starr" title="Edwin Starr">Edwin Starr</a>
# </td></tr>, <tr>
# <td>6</td>
# <td>"<a href="/wiki/Ain%27t_No_Mountain_High_Enough" title="Ain't No Mountain High Enough">Ain't No Mountain High Enough</a>"</td>
# <td><a href="/wiki/Diana_Ross" title="Diana Ross">Diana Ross</a>
# </td></tr>, <tr>
# <td>7</td>
# <td>"<a href="/wiki/I%27ll_Be_There_(The_Jackson_5_song)" title="I'll Be There (The Jackson 5 song)">I'll Be There</a>"</td>
# <td><a href="/wiki/The_Jackson_5" title="The Jackson 5">The Jackson 5</a>
# </td></tr>, <tr>
# <td>8</td>
# <td>"<a href="/wiki/Get_Ready_(The_Temptations_song)#Rare_Earth_version" title="Get Ready (The Temptations song)">Get Ready</a>"</td>
# <td><a href="/wiki/Rare_Earth_(band)" title="Rare Earth (band)">Rare Earth</a>
# </td></tr>, <tr>
# <td>9</td>
# <td>"<a href="/wiki/Let_It_Be_(Beatles_song)" title="Let It Be (Beatles song)">Let It Be</a>"</td>
# <td><a href="/wiki/The_Beatles" title="The Beatles">The Beatles</a>
# </td></tr>, <tr>
# <td>10</td>
# <td>"<a href="/wiki/Band_of_Gold_(Freda_Payne_song)" title="Band of Gold (Freda Payne song)">Band of Gold</a>"</td>
# <td><a href="/wiki/Freda_Payne" title="Freda Payne">Freda Payne</a>
# </td></tr>, <tr>
# <td>11</td>
# <td>"<a href="/wiki/Mama_Told_Me_Not_to_Come" title="Mama Told Me Not to Come">Mama Told Me (Not to Come)</a>"</td>
# <td><a href="/wiki/Three_Dog_Night" title="Three Dog Night">Three Dog Night</a>
# </td></tr>, <tr>
# <td>12</td>
# <td>"<a href="/wiki/Everything_Is_Beautiful" title="Everything Is Beautiful">Everything Is Beautiful</a>"</td>
# <td><a href="/wiki/Ray_Stevens" title="Ray Stevens">Ray Stevens</a>
# </td></tr>, <tr>
# <td>13</td>
# <td>"<a href="/wiki/Make_It_with_You" title="Make It with You">Make It with You</a>"</td>
# <td><a href="/wiki/Bread_(band)" title="Bread (band)">Bread</a>
# </td></tr>, <tr>
# <td>14</td>
# <td>"<a href="/wiki/Hitchin%27_a_Ride_(Vanity_Fare_song)" title="Hitchin' a Ride (Vanity Fare song)">Hitchin' a Ride</a>"</td>
# <td><a href="/wiki/Vanity_Fare" title="Vanity Fare">Vanity Fare</a>
# </td></tr>, <tr>
# <td>15</td>
# <td>"<a href="/wiki/ABC_(The_Jackson_5_song)" title="ABC (The Jackson 5 song)">ABC</a>"</td>
# <td><a href="/wiki/The_Jackson_5" title="The Jackson 5">The Jackson 5</a>
# </td></tr>, <tr>
# <td>16</td>
# <td>"<a href="/wiki/The_Love_You_Save" title="The Love You Save">The Love You Save</a>"</td>
# <td><a href="/wiki/The_Jackson_5" title="The Jackson 5">The Jackson 5</a>
# </td></tr>, <tr>
# <td>17</td>
# <td>"<a href="/wiki/Cracklin%27_Rosie" title="Cracklin' Rosie">Cracklin' Rosie</a>"</td>
# <td><a href="/wiki/Neil_Diamond" title="Neil Diamond">Neil Diamond</a>
# </td></tr>, <tr>
# <td>18</td>
# <td>"<a href="/wiki/Candida_(song)" title="Candida (song)">Candida</a>"</td>
# <td><a href="/wiki/Tony_Orlando_and_Dawn" title="Tony Orlando and Dawn">Dawn</a>
# </td></tr>, <tr>
# <td>19</td>
# <td>"<a href="/wiki/Thank_You_(Falettinme_Be_Mice_Elf_Agin)" title="Thank You (Falettinme Be Mice Elf Agin)">Thank You (Falettinme Be Mice Elf Agin)</a>"</td>
# <td><a class="mw-redirect" href="/wiki/Sly_%26_the_Family_Stone" title="Sly &amp; the Family Stone">Sly &amp; the Family Stone</a>
# </td></tr>, <tr>
# <td>20</td>
# <td>"<a href="/wiki/Spill_the_Wine" title="Spill the Wine">Spill the Wine</a>"</td>
# <td><a href="/wiki/Eric_Burdon" title="Eric Burdon">Eric Burdon</a> &amp; <a class="mw-redirect" href="/wiki/War_(U.S._band)" title="War (U.S. band)">War</a>
# </td></tr>, <tr>
# <td>21</td>
# <td>"<a href="/wiki/O-o-h_Child" title="O-o-h Child">O-o-h Child</a>"</td>
# <td><a href="/wiki/Five_Stairsteps" title="Five Stairsteps">Five Stairsteps</a>
# </td></tr>, <tr>
# <td>22</td>
# <td>"<a href="/wiki/Spirit_in_the_Sky" title="Spirit in the Sky">Spirit in the Sky</a>"</td>
# <td><a href="/wiki/Norman_Greenbaum" title="Norman Greenbaum">Norman Greenbaum</a>
# </td></tr>, <tr>
# <td>23</td>
# <td>"<a href="/wiki/Lay_Down_(Candles_in_the_Rain)" title="Lay Down (Candles in the Rain)">Lay Down (Candles in the Rain)</a>"</td>
# <td><a class="mw-redirect" href="/wiki/Melanie_Safka" title="Melanie Safka">Melanie</a>
# </td></tr>, <tr>
# <td>24</td>
# <td>"<a href="/wiki/Ball_of_Confusion_(That%27s_What_the_World_Is_Today)" title="Ball of Confusion (That's What the World Is Today)">Ball of Confusion (That's What the World Is Today)</a>"</td>
# <td><a href="/wiki/The_Temptations" title="The Temptations">The Temptations</a>
# </td></tr>, <tr>
# <td>25</td>
# <td>"<a href="/wiki/Love_on_a_Two-Way_Street" title="Love on a Two-Way Street">Love on a Two-Way Street</a>"</td>
# <td><a href="/wiki/Ray,_Goodman_%26_Brown" title="Ray, Goodman &amp; Brown">The Moments</a>
# </td></tr>, <tr>
# <td>26</td>
# <td>"<a href="/wiki/Which_Way_You_Goin%27_Billy%3F_(song)" title="Which Way You Goin' Billy? (song)">Which Way You Goin' Billy?</a>"</td>
# <td><a href="/wiki/The_Poppy_Family" title="The Poppy Family">The Poppy Family</a>
# </td></tr>, <tr>
# <td>27</td>
# <td>"<a href="/wiki/All_Right_Now" title="All Right Now">All Right Now</a>"</td>
# <td><a href="/wiki/Free_(band)" title="Free (band)">Free</a>
# </td></tr>, <tr>
# <td>28</td>
# <td>"<a href="/wiki/I_Want_You_Back" title="I Want You Back">I Want You Back</a>"</td>
# <td><a href="/wiki/The_Jackson_5" title="The Jackson 5">The Jackson 5</a>
# </td></tr>, <tr>
# <td>29</td>
# <td>"<a href="/wiki/Julie,_Do_Ya_Love_Me" title="Julie, Do Ya Love Me">Julie, Do Ya Love Me</a>"</td>
# <td><a href="/wiki/Bobby_Sherman" title="Bobby Sherman">Bobby Sherman</a>
# </td></tr>, <tr>
# <td>30</td>
# <td>"<a href="/wiki/Green-Eyed_Lady" title="Green-Eyed Lady">Green-Eyed Lady</a>"</td>
# <td><a href="/wiki/Sugarloaf_(band)" title="Sugarloaf (band)">Sugarloaf</a>
# </td></tr>, <tr>
# <td>31</td>
# <td>"<a href="/wiki/Signed,_Sealed,_Delivered_I%27m_Yours" title="Signed, Sealed, Delivered I'm Yours">Signed, Sealed, Delivered I'm Yours</a>"</td>
# <td><a href="/wiki/Stevie_Wonder" title="Stevie Wonder">Stevie Wonder</a>
# </td></tr>, <tr>
# <td>32</td>
# <td>"<a href="/wiki/Ride_Captain_Ride" title="Ride Captain Ride">Ride Captain Ride</a>"</td>
# <td><a href="/wiki/Blues_Image" title="Blues Image">Blues Image</a>
# </td></tr>, <tr>
# <td>33</td>
# <td>"<a href="/wiki/Venus_(Shocking_Blue_song)" title="Venus (Shocking Blue song)">Venus</a>"</td>
# <td><a href="/wiki/Shocking_Blue" title="Shocking Blue">Shocking Blue</a>
# </td></tr>, <tr>
# <td>34</td>
# <td>"<a href="/wiki/Instant_Karma!" title="Instant Karma!">Instant Karma!</a>"</td>
# <td><a href="/wiki/John_Lennon" title="John Lennon">John Lennon</a>
# </td></tr>, <tr>
# <td>35</td>
# <td>"<a href="/wiki/Patches_(Chairmen_of_the_Board_song)" title="Patches (Chairmen of the Board song)">Patches</a>"</td>
# <td><a href="/wiki/Clarence_Carter" title="Clarence Carter">Clarence Carter</a>
# </td></tr>, <tr>
# <td>36</td>
# <td>"<a class="mw-redirect" href="/wiki/Lookin%27_out_My_Back_Door" title="Lookin' out My Back Door">Lookin' out My Back Door</a>"</td>
# <td><a href="/wiki/Creedence_Clearwater_Revival" title="Creedence Clearwater Revival">Creedence Clearwater Revival</a>
# </td></tr>, <tr>
# <td>37</td>
# <td>"<a href="/wiki/Rainy_Night_in_Georgia" title="Rainy Night in Georgia">Rainy Night in Georgia</a>"</td>
# <td><a href="/wiki/Brook_Benton" title="Brook Benton">Brook Benton</a>
# </td></tr>, <tr>
# <td>38</td>
# <td>"<a class="mw-redirect" href="/wiki/Something%27s_Burning_(song)" title="Something's Burning (song)">Something's Burning</a>"</td>
# <td><a href="/wiki/Kenny_Rogers" title="Kenny Rogers">Kenny Rogers</a> &amp; <a class="mw-redirect" href="/wiki/The_First_Edition_(band)" title="The First Edition (band)">The First Edition</a>
# </td></tr>, <tr>
# <td>39</td>
# <td>"<a href="/wiki/Give_Me_Just_a_Little_More_Time" title="Give Me Just a Little More Time">Give Me Just a Little More Time</a>"</td>
# <td><a href="/wiki/Chairmen_of_the_Board" title="Chairmen of the Board">Chairmen of the Board</a>
# </td></tr>, <tr>
# <td>40</td>
# <td>"<a href="/wiki/Love_Grows_(Where_My_Rosemary_Goes)" title="Love Grows (Where My Rosemary Goes)">Love Grows (Where My Rosemary Goes)</a>"</td>
# <td><a href="/wiki/Edison_Lighthouse" title="Edison Lighthouse">Edison Lighthouse</a>
# </td></tr>, <tr>
# <td>41</td>
# <td>"<a href="/wiki/The_Long_and_Winding_Road" title="The Long and Winding Road">The Long and Winding Road</a>"</td>
# <td><a href="/wiki/The_Beatles" title="The Beatles">The Beatles</a>
# </td></tr>, <tr>
# <td>42</td>
# <td>"<a href="/wiki/Snowbird_(song)" title="Snowbird (song)">Snowbird</a>"</td>
# <td><a href="/wiki/Anne_Murray" title="Anne Murray">Anne Murray</a>
# </td></tr>, <tr>
# <td>43</td>
# <td>"<a href="/wiki/Reflections_of_My_Life" title="Reflections of My Life">Reflections of My Life</a>"</td>
# <td><a href="/wiki/Marmalade_(band)" title="Marmalade (band)">Marmalade</a>
# </td></tr>, <tr>
# <td>44</td>
# <td>"<a href="/wiki/Hey_There_Lonely_Girl" title="Hey There Lonely Girl">Hey There Lonely Girl</a>"</td>
# <td><a href="/wiki/Eddie_Holman" title="Eddie Holman">Eddie Holman</a>
# </td></tr>, <tr>
# <td>45</td>
# <td>"<a href="/wiki/The_Rapper" title="The Rapper">The Rapper</a>"</td>
# <td><a href="/wiki/The_Jaggerz" title="The Jaggerz">The Jaggerz</a>
# </td></tr>, <tr>
# <td>46</td>
# <td>"<a href="/wiki/He_Ain%27t_Heavy,_He%27s_My_Brother" title="He Ain't Heavy, He's My Brother">He Ain't Heavy, He's My Brother</a>"</td>
# <td><a href="/wiki/The_Hollies" title="The Hollies">The Hollies</a>
# </td></tr>, <tr>
# <td>47</td>
# <td>"<a href="/wiki/Tighter,_Tighter" title="Tighter, Tighter">Tighter, Tighter</a>"</td>
# <td><a href="/wiki/Alive_N_Kickin%27" title="Alive N Kickin'">Alive N Kickin'</a>
# </td></tr>, <tr>
# <td>48</td>
# <td>"<a href="/wiki/Come_and_Get_It_(Badfinger_song)" title="Come and Get It (Badfinger song)">Come and Get It</a>"</td>
# <td><a href="/wiki/Badfinger" title="Badfinger">Badfinger</a>
# </td></tr>, <tr>
# <td>49</td>
# <td>"<a href="/wiki/Cecilia_(Simon_%26_Garfunkel_song)" title="Cecilia (Simon &amp; Garfunkel song)">Cecilia</a>"</td>
# <td><a href="/wiki/Simon_%26_Garfunkel" title="Simon &amp; Garfunkel">Simon &amp; Garfunkel</a>
# </td></tr>, <tr>
# <td>50</td>
# <td>"<a href="/wiki/Love_Land_(song)" title="Love Land (song)">Love Land</a>"</td>
# <td><a href="/wiki/Charles_Wright_%26_the_Watts_103rd_Street_Rhythm_Band" title="Charles Wright &amp; the Watts 103rd Street Rhythm Band">Charles Wright &amp; the Watts 103rd Street Rhythm Band</a>
# </td></tr>, <tr>
# <td>51</td>
# <td>"<a class="mw-redirect" href="/wiki/Turn_Back_the_Hands_of_Time_(song)" title="Turn Back the Hands of Time (song)">Turn Back the Hands of Time</a>"</td>
# <td><a href="/wiki/Tyrone_Davis" title="Tyrone Davis">Tyrone Davis</a>
# </td></tr>, <tr>
# <td>52</td>
# <td>"<a href="/wiki/Lola_(song)" title="Lola (song)">Lola</a>"</td>
# <td><a href="/wiki/The_Kinks" title="The Kinks">The Kinks</a>
# </td></tr>, <tr>
# <td>53</td>
# <td>"<a class="mw-redirect" href="/wiki/In_the_Summertime_(Mungo_Jerry_song)" title="In the Summertime (Mungo Jerry song)">In the Summertime</a>"</td>
# <td><a href="/wiki/Mungo_Jerry" title="Mungo Jerry">Mungo Jerry</a>
# </td></tr>, <tr>
# <td>54</td>
# <td>"<a href="/wiki/Indiana_Wants_Me" title="Indiana Wants Me">Indiana Wants Me</a>"</td>
# <td><a href="/wiki/R._Dean_Taylor" title="R. Dean Taylor">R. Dean Taylor</a>
# </td></tr>, <tr>
# <td>55</td>
# <td>"<a href="/wiki/(I_Know)_I%27m_Losing_You" title="(I Know) I'm Losing You">(I Know) I'm Losing You</a>"</td>
# <td><a href="/wiki/Rare_Earth_(band)" title="Rare Earth (band)">Rare Earth</a>
# </td></tr>, <tr>
# <td>56</td>
# <td>"<a href="/wiki/Easy_Come,_Easy_Go_(Bobby_Sherman_song)" title="Easy Come, Easy Go (Bobby Sherman song)">Easy Come, Easy Go</a>"</td>
# <td><a href="/wiki/Bobby_Sherman" title="Bobby Sherman">Bobby Sherman</a>
# </td></tr>, <tr>
# <td>57</td>
# <td>"<a href="/wiki/Express_Yourself_(Charles_Wright_%26_the_Watts_103rd_Street_Rhythm_Band_song)" title="Express Yourself (Charles Wright &amp; the Watts 103rd Street Rhythm Band song)">Express Yourself</a>"</td>
# <td><a href="/wiki/Charles_Wright_%26_the_Watts_103rd_Street_Rhythm_Band" title="Charles Wright &amp; the Watts 103rd Street Rhythm Band">Charles Wright &amp; the Watts 103rd Street Rhythm Band</a>
# </td></tr>, <tr>
# <td>58</td>
# <td>"<a href="/wiki/Still_Water_(Love)" title="Still Water (Love)">Still Water (Love)</a>"</td>
# <td><a class="mw-redirect" href="/wiki/The_Four_Tops" title="The Four Tops">The Four Tops</a>
# </td></tr>, <tr>
# <td>59</td>
# <td>"<a href="/wiki/Make_Me_Smile" title="Make Me Smile">Make Me Smile</a>"</td>
# <td><a href="/wiki/Chicago_(band)" title="Chicago (band)">Chicago</a>
# </td></tr>, <tr>
# <td>60</td>
# <td>"<a href="/wiki/The_House_of_the_Rising_Sun" title="The House of the Rising Sun">The House of the Rising Sun</a>"</td>
# <td><a href="/wiki/Frijid_Pink" title="Frijid Pink">Frijid Pink</a>
# </td></tr>, <tr>
# <td>61</td>
# <td>"<a href="/wiki/25_or_6_to_4" title="25 or 6 to 4">25 or 6 to 4</a>"</td>
# <td><a href="/wiki/Chicago_(band)" title="Chicago (band)">Chicago</a>
# </td></tr>, <tr>
# <td>62</td>
# <td>"<a href="/wiki/My_Baby_Loves_Lovin%27" title="My Baby Loves Lovin'">My Baby Loves Lovin'</a>"</td>
# <td><a href="/wiki/White_Plains_(band)" title="White Plains (band)">White Plains</a>
# </td></tr>, <tr>
# <td>63</td>
# <td>"<a href="/wiki/Love_or_Let_Me_Be_Lonely" title="Love or Let Me Be Lonely">Love or Let Me Be Lonely</a>"</td>
# <td><a href="/wiki/The_Friends_of_Distinction" title="The Friends of Distinction">The Friends of Distinction</a>
# </td></tr>, <tr>
# <td>64</td>
# <td>"<a href="/wiki/United_We_Stand_(song)" title="United We Stand (song)">United We Stand</a>"</td>
# <td><a class="mw-redirect" href="/wiki/The_Brotherhood_of_Man" title="The Brotherhood of Man">The Brotherhood of Man</a>
# </td></tr>, <tr>
# <td>65</td>
# <td>"<a href="/wiki/We%27ve_Only_Just_Begun" title="We've Only Just Begun">We've Only Just Begun</a>"</td>
# <td><a href="/wiki/The_Carpenters" title="The Carpenters">The Carpenters</a>
# </td></tr>, <tr>
# <td>66</td>
# <td>"<a href="/wiki/Arizona_(song)" title="Arizona (song)">Arizona</a>"</td>
# <td><a href="/wiki/Mark_Lindsay" title="Mark Lindsay">Mark Lindsay</a>
# </td></tr>, <tr>
# <td>67</td>
# <td>"<a href="/wiki/Fire_and_Rain_(song)" title="Fire and Rain (song)">Fire and Rain</a>"</td>
# <td><a href="/wiki/James_Taylor" title="James Taylor">James Taylor</a>
# </td></tr>, <tr>
# <td>68</td>
# <td>"<a href="/wiki/Groovy_Situation" title="Groovy Situation">Groovy Situation</a>"</td>
# <td><a href="/wiki/Gene_Chandler" title="Gene Chandler">Gene Chandler</a>
# </td></tr>, <tr>
# <td>69</td>
# <td>"<a href="/wiki/Evil_Ways" title="Evil Ways">Evil Ways</a>"</td>
# <td><a href="/wiki/Santana_(band)" title="Santana (band)">Santana</a>
# </td></tr>, <tr>
# <td>70</td>
# <td>"<a href="/wiki/No_Time_(The_Guess_Who_song)" title="No Time (The Guess Who song)">No Time</a>"</td>
# <td><a href="/wiki/The_Guess_Who" title="The Guess Who">The Guess Who</a>
# </td></tr>, <tr>
# <td>71</td>
# <td>"<a href="/wiki/Didn%27t_I_(Blow_Your_Mind_This_Time)" title="Didn't I (Blow Your Mind This Time)">Didn't I (Blow Your Mind This Time)</a>"</td>
# <td><a href="/wiki/The_Delfonics" title="The Delfonics">The Delfonics</a>
# </td></tr>, <tr>
# <td>72</td>
# <td>"<a href="/wiki/The_Wonder_of_You" title="The Wonder of You">The Wonder of You</a>"</td>
# <td><a href="/wiki/Elvis_Presley" title="Elvis Presley">Elvis Presley</a>
# </td></tr>, <tr>
# <td>73</td>
# <td>"<a href="/wiki/Up_Around_the_Bend" title="Up Around the Bend">Up Around the Bend</a>"</td>
# <td><a href="/wiki/Creedence_Clearwater_Revival" title="Creedence Clearwater Revival">Creedence Clearwater Revival</a>
# </td></tr>, <tr>
# <td>74</td>
# <td>"<a class="mw-redirect" href="/wiki/(If_You_Let_Me_Make_Love_To_You_Then)_Why_Can%27t_I_Touch_You%3F" title="(If You Let Me Make Love To You Then) Why Can't I Touch You?">(If You Let Me Make Love To You Then) Why Can't I Touch You?</a>"</td>
# <td><a href="/wiki/Ronnie_Dyson" title="Ronnie Dyson">Ronnie Dyson</a>
# </td></tr>, <tr>
# <td>75</td>
# <td>"<a href="/wiki/I_Just_Can%27t_Help_Believing" title="I Just Can't Help Believing">I Just Can't Help Believing</a>"</td>
# <td><a class="mw-redirect" href="/wiki/B.J._Thomas" title="B.J. Thomas">B.J. Thomas</a>
# </td></tr>, <tr>
# <td>76</td>
# <td>"<a href="/wiki/It%27s_a_Shame_(The_Spinners_song)" title="It's a Shame (The Spinners song)">It's a Shame</a>"</td>
# <td><a class="mw-redirect" href="/wiki/The_Spinners_(American_band)" title="The Spinners (American band)">The Spinners</a>
# </td></tr>, <tr>
# <td>77</td>
# <td>"<a href="/wiki/For_the_Love_of_Him" title="For the Love of Him">For the Love of Him</a>"</td>
# <td><a href="/wiki/Bobbi_Martin" title="Bobbi Martin">Bobbi Martin</a>
# </td></tr>, <tr>
# <td>78</td>
# <td>"<a href="/wiki/Mississippi_Queen" title="Mississippi Queen">Mississippi Queen</a>"</td>
# <td><a href="/wiki/Mountain_(band)" title="Mountain (band)">Mountain</a>
# </td></tr>, <tr>
# <td>79</td>
# <td>"<a href="/wiki/I_Want_to_Take_You_Higher" title="I Want to Take You Higher">I Want to Take You Higher</a>"</td>
# <td><a href="/wiki/Ike_%26_Tina_Turner" title="Ike &amp; Tina Turner">Ike &amp; Tina Turner</a>
# </td></tr>, <tr>
# <td>80</td>
# <td>"<a href="/wiki/The_Letter_(The_Box_Tops_song)" title="The Letter (The Box Tops song)">The Letter</a>"</td>
# <td><a href="/wiki/Joe_Cocker" title="Joe Cocker">Joe Cocker</a>
# </td></tr>, <tr>
# <td>81</td>
# <td>"<a href="/wiki/Ma_Belle_Amie" title="Ma Belle Amie">Ma Belle Amie</a>"</td>
# <td><a href="/wiki/Tee_Set" title="Tee Set">Tee Set</a>
# </td></tr>, <tr>
# <td>82</td>
# <td>"<a href="/wiki/The_Bells_(The_Originals_song)" title="The Bells (The Originals song)">The Bells</a>"</td>
# <td><a href="/wiki/The_Originals_(band)" title="The Originals (band)">The Originals</a>
# </td></tr>, <tr>
# <td>83</td>
# <td>"<a href="/wiki/Yellow_River_(song)" title="Yellow River (song)">Yellow River</a>"</td>
# <td><a href="/wiki/Christie_(band)" title="Christie (band)">Christie</a>
# </td></tr>, <tr>
# <td>84</td>
# <td>"<a href="/wiki/Somebody%27s_Been_Sleeping" title="Somebody's Been Sleeping">Somebody's Been Sleeping</a>"</td>
# <td><a href="/wiki/100_Proof_(Aged_in_Soul)" title="100 Proof (Aged in Soul)">100 Proof (Aged in Soul)</a>
# </td></tr>, <tr>
# <td>85</td>
# <td>"<a href="/wiki/Vehicle_(song)" title="Vehicle (song)">Vehicle</a>"</td>
# <td><a href="/wiki/The_Ides_of_March_(band)" title="The Ides of March (band)">The Ides of March</a>
# </td></tr>, <tr>
# <td>86</td>
# <td>"<a class="mw-redirect" href="/wiki/Gimme_Dat_Ding_(song)" title="Gimme Dat Ding (song)">Gimme Dat Ding</a>"</td>
# <td><a href="/wiki/The_Pipkins" title="The Pipkins">The Pipkins</a>
# </td></tr>, <tr>
# <td>87</td>
# <td>"<a href="/wiki/Lay_a_Little_Lovin%27_on_Me" title="Lay a Little Lovin' on Me">Lay a Little Lovin' on Me</a>"</td>
# <td><a href="/wiki/Robin_McNamara" title="Robin McNamara">Robin McNamara</a>
# </td></tr>, <tr>
# <td>88</td>
# <td>"<a href="/wiki/Up_the_Ladder_to_the_Roof" title="Up the Ladder to the Roof">Up the Ladder to the Roof</a>"</td>
# <td><a href="/wiki/The_Supremes" title="The Supremes">The Supremes</a>
# </td></tr>, <tr>
# <td>89</td>
# <td>"<a href="/wiki/Travelin%27_Band" title="Travelin' Band">Travelin' Band</a>"</td>
# <td><a href="/wiki/Creedence_Clearwater_Revival" title="Creedence Clearwater Revival">Creedence Clearwater Revival</a>
# </td></tr>, <tr>
# <td>90</td>
# <td>"<a href="/wiki/Come_Saturday_Morning_(song)" title="Come Saturday Morning (song)">Come Saturday Morning</a>"</td>
# <td><a href="/wiki/The_Sandpipers" title="The Sandpipers">The Sandpipers</a>
# </td></tr>, <tr>
# <td>91</td>
# <td>"<a href="/wiki/Psychedelic_Shack_(song)" title="Psychedelic Shack (song)">Psychedelic Shack</a>"</td>
# <td><a href="/wiki/The_Temptations" title="The Temptations">The Temptations</a>
# </td></tr>, <tr>
# <td>92</td>
# <td>"<a class="mw-redirect" href="/wiki/Without_Love_(There_Is_Nothing)" title="Without Love (There Is Nothing)">Without Love (There Is Nothing)</a>"</td>
# <td><a href="/wiki/Tom_Jones_(singer)" title="Tom Jones (singer)">Tom Jones</a>
# </td></tr>, <tr>
# <td>93</td>
# <td>"<a href="/wiki/Are_You_Ready%3F_(Pacific_Gas_%26_Electric_song)" title="Are You Ready? (Pacific Gas &amp; Electric song)">Are You Ready?</a>"</td>
# <td><a href="/wiki/Pacific_Gas_%26_Electric_(band)" title="Pacific Gas &amp; Electric (band)">Pacific Gas &amp; Electric</a>
# </td></tr>, <tr>
# <td>94</td>
# <td>"<a href="/wiki/Woodstock_(song)" title="Woodstock (song)">Woodstock</a>"</td>
# <td><a href="/wiki/Crosby,_Stills,_Nash_%26_Young" title="Crosby, Stills, Nash &amp; Young">Crosby, Stills, Nash &amp; Young</a>
# </td></tr>, <tr>
# <td>95</td>
# <td>"<a href="/wiki/I%27ll_Never_Fall_in_Love_Again" title="I'll Never Fall in Love Again">I'll Never Fall in Love Again</a>"</td>
# <td><a href="/wiki/Dionne_Warwick" title="Dionne Warwick">Dionne Warwick</a>
# </td></tr>, <tr>
# <td>96</td>
# <td>"<a class="mw-redirect" href="/wiki/Look_What_They%27ve_Done_to_My_Song_Ma" title="Look What They've Done to My Song Ma">Look What They've Done to My Song Ma</a>"</td>
# <td><a href="/wiki/The_New_Seekers" title="The New Seekers">The New Seekers</a>
# </td></tr>, <tr>
# <td>97</td>
# <td>"<a class="mw-redirect" href="/wiki/Walk_A_Mile_In_My_Shoes" title="Walk A Mile In My Shoes">Walk A Mile In My Shoes</a>"</td>
# <td><a href="/wiki/Joe_South" title="Joe South">Joe South</a>
# </td></tr>, <tr>
# <td>98</td>
# <td>"<a class="mw-redirect" href="/wiki/The_Thrill_Is_Gone_(1951_song)" title="The Thrill Is Gone (1951 song)">The Thrill Is Gone</a>"</td>
# <td><a href="/wiki/B.B._King" title="B.B. King">B.B. King</a>
# </td></tr>, <tr>
# <td>99</td>
# <td>"<a href="/wiki/It%27s_Only_Make_Believe" title="It's Only Make Believe">It's Only Make Believe</a>"</td>
# <td><a href="/wiki/Glen_Campbell" title="Glen Campbell">Glen Campbell</a>
# </td></tr>, <tr>
# <td>100</td>
# <td>"<a href="/wiki/Call_Me_(Aretha_Franklin_song)" title="Call Me (Aretha Franklin song)">Call Me</a>"</td>
# <td><a href="/wiki/Aretha_Franklin" title="Aretha Franklin">Aretha Franklin</a>
# </td></tr>]
# [{'band_singer': 'Simon & Garfunkel',
#   'ranking': '1',
#   'title': 'Bridge Over Troubled Water',
#   'url': '/wiki/Simon_%26_Garfunkel'},
#  {'band_singer': 'The Carpenters',
#   'ranking': '2',
#   'title': '(They Long to Be) Close to You',
#   'url': '/wiki/The_Carpenters'},
#  {'band_singer': 'The Guess Who',
#   'ranking': '3',
#   'title': 'American Woman',
#   'url': '/wiki/The_Guess_Who'},
#  {'band_singer': 'B.J. Thomas',
#   'ranking': '4',
#   'title': "Raindrops Keep Fallin' on My Head",
#   'url': '/wiki/B.J._Thomas'},
#  {'band_singer': 'Edwin Starr',
#   'ranking': '5',
#   'title': 'War',
#   'url': '/wiki/Edwin_Starr'},
#  {'band_singer': 'Diana Ross',
#   'ranking': '6',
#   'title': "Ain't No Mountain High Enough",
#   'url': '/wiki/Diana_Ross'},
#  {'band_singer': 'The Jackson 5',
#   'ranking': '7',
#   'title': "I'll Be There",
#   'url': '/wiki/The_Jackson_5'},
#  {'band_singer': 'Rare Earth',
#   'ranking': '8',
#   'title': 'Get Ready',
#   'url': '/wiki/Rare_Earth_(band)'},
#  {'band_singer': 'The Beatles',
#   'ranking': '9',
#   'title': 'Let It Be',
#   'url': '/wiki/The_Beatles'},
#  {'band_singer': 'Freda Payne',
#   'ranking': '10',
#   'title': 'Band of Gold',
#   'url': '/wiki/Freda_Payne'},
#  {'band_singer': 'Three Dog Night',
#   'ranking': '11',
#   'title': 'Mama Told Me (Not to Come)',
#   'url': '/wiki/Three_Dog_Night'},
#  {'band_singer': 'Ray Stevens',
#   'ranking': '12',
#   'title': 'Everything Is Beautiful',
#   'url': '/wiki/Ray_Stevens'},
#  {'band_singer': 'Bread',
#   'ranking': '13',
#   'title': 'Make It with You',
#   'url': '/wiki/Bread_(band)'},
#  {'band_singer': 'Vanity Fare',
#   'ranking': '14',
#   'title': "Hitchin' a Ride",
#   'url': '/wiki/Vanity_Fare'},
#  {'band_singer': 'The Jackson 5',
#   'ranking': '15',
#   'title': 'ABC',
#   'url': '/wiki/The_Jackson_5'},
#  {'band_singer': 'The Jackson 5',
#   'ranking': '16',
#   'title': 'The Love You Save',
#   'url': '/wiki/The_Jackson_5'},
#  {'band_singer': 'Neil Diamond',
#   'ranking': '17',
#   'title': "Cracklin' Rosie",
#   'url': '/wiki/Neil_Diamond'},
#  {'band_singer': 'Dawn',
#   'ranking': '18',
#   'title': 'Candida',
#   'url': '/wiki/Tony_Orlando_and_Dawn'},
#  {'band_singer': 'Sly & the Family Stone',
#   'ranking': '19',
#   'title': 'Thank You (Falettinme Be Mice Elf Agin)',
#   'url': '/wiki/Sly_%26_the_Family_Stone'},
#  {'band_singer': 'Eric Burdon',
#   'ranking': '20',
#   'title': 'Spill the Wine',
#   'url': '/wiki/Eric_Burdon'},
#  {'band_singer': 'Five Stairsteps',
#   'ranking': '21',
#   'title': 'O-o-h Child',
#   'url': '/wiki/Five_Stairsteps'},
#  {'band_singer': 'Norman Greenbaum',
#   'ranking': '22',
#   'title': 'Spirit in the Sky',
#   'url': '/wiki/Norman_Greenbaum'},
#  {'band_singer': 'Melanie',
#   'ranking': '23',
#   'title': 'Lay Down (Candles in the Rain)',
#   'url': '/wiki/Melanie_Safka'},
#  {'band_singer': 'The Temptations',
#   'ranking': '24',
#   'title': "Ball of Confusion (That's What the World Is Today)",
#   'url': '/wiki/The_Temptations'},
#  {'band_singer': 'The Moments',
#   'ranking': '25',
#   'title': 'Love on a Two-Way Street',
#   'url': '/wiki/Ray,_Goodman_%26_Brown'},
#  {'band_singer': 'The Poppy Family',
#   'ranking': '26',
#   'title': "Which Way You Goin' Billy?",
#   'url': '/wiki/The_Poppy_Family'},
#  {'band_singer': 'Free',
#   'ranking': '27',
#   'title': 'All Right Now',
#   'url': '/wiki/Free_(band)'},
#  {'band_singer': 'The Jackson 5',
#   'ranking': '28',
#   'title': 'I Want You Back',
#   'url': '/wiki/The_Jackson_5'},
#  {'band_singer': 'Bobby Sherman',
#   'ranking': '29',
#   'title': 'Julie, Do Ya Love Me',
#   'url': '/wiki/Bobby_Sherman'},
#  {'band_singer': 'Sugarloaf',
#   'ranking': '30',
#   'title': 'Green-Eyed Lady',
#   'url': '/wiki/Sugarloaf_(band)'},
#  {'band_singer': 'Stevie Wonder',
#   'ranking': '31',
#   'title': "Signed, Sealed, Delivered I'm Yours",
#   'url': '/wiki/Stevie_Wonder'},
#  {'band_singer': 'Blues Image',
#   'ranking': '32',
#   'title': 'Ride Captain Ride',
#   'url': '/wiki/Blues_Image'},
#  {'band_singer': 'Shocking Blue',
#   'ranking': '33',
#   'title': 'Venus',
#   'url': '/wiki/Shocking_Blue'},
#  {'band_singer': 'John Lennon',
#   'ranking': '34',
#   'title': 'Instant Karma!',
#   'url': '/wiki/John_Lennon'},
#  {'band_singer': 'Clarence Carter',
#   'ranking': '35',
#   'title': 'Patches',
#   'url': '/wiki/Clarence_Carter'},
#  {'band_singer': 'Creedence Clearwater Revival',
#   'ranking': '36',
#   'title': "Lookin' out My Back Door",
#   'url': '/wiki/Creedence_Clearwater_Revival'},
#  {'band_singer': 'Brook Benton',
#   'ranking': '37',
#   'title': 'Rainy Night in Georgia',
#   'url': '/wiki/Brook_Benton'},
#  {'band_singer': 'Kenny Rogers',
#   'ranking': '38',
#   'title': "Something's Burning",
#   'url': '/wiki/Kenny_Rogers'},
#  {'band_singer': 'Chairmen of the Board',
#   'ranking': '39',
#   'title': 'Give Me Just a Little More Time',
#   'url': '/wiki/Chairmen_of_the_Board'},
#  {'band_singer': 'Edison Lighthouse',
#   'ranking': '40',
#   'title': 'Love Grows (Where My Rosemary Goes)',
#   'url': '/wiki/Edison_Lighthouse'},
#  {'band_singer': 'The Beatles',
#   'ranking': '41',
#   'title': 'The Long and Winding Road',
#   'url': '/wiki/The_Beatles'},
#  {'band_singer': 'Anne Murray',
#   'ranking': '42',
#   'title': 'Snowbird',
#   'url': '/wiki/Anne_Murray'},
#  {'band_singer': 'Marmalade',
#   'ranking': '43',
#   'title': 'Reflections of My Life',
#   'url': '/wiki/Marmalade_(band)'},
#  {'band_singer': 'Eddie Holman',
#   'ranking': '44',
#   'title': 'Hey There Lonely Girl',
#   'url': '/wiki/Eddie_Holman'},
#  {'band_singer': 'The Jaggerz',
#   'ranking': '45',
#   'title': 'The Rapper',
#   'url': '/wiki/The_Jaggerz'},
#  {'band_singer': 'The Hollies',
#   'ranking': '46',
#   'title': "He Ain't Heavy, He's My Brother",
#   'url': '/wiki/The_Hollies'},
#  {'band_singer': "Alive N Kickin'",
#   'ranking': '47',
#   'title': 'Tighter, Tighter',
#   'url': '/wiki/Alive_N_Kickin%27'},
#  {'band_singer': 'Badfinger',
#   'ranking': '48',
#   'title': 'Come and Get It',
#   'url': '/wiki/Badfinger'},
#  {'band_singer': 'Simon & Garfunkel',
#   'ranking': '49',
#   'title': 'Cecilia',
#   'url': '/wiki/Simon_%26_Garfunkel'},
#  {'band_singer': 'Charles Wright & the Watts 103rd Street Rhythm Band',
#   'ranking': '50',
#   'title': 'Love Land',
#   'url': '/wiki/Charles_Wright_%26_the_Watts_103rd_Street_Rhythm_Band'},
#  {'band_singer': 'Tyrone Davis',
#   'ranking': '51',
#   'title': 'Turn Back the Hands of Time',
#   'url': '/wiki/Tyrone_Davis'},
#  {'band_singer': 'The Kinks',
#   'ranking': '52',
#   'title': 'Lola',
#   'url': '/wiki/The_Kinks'},
#  {'band_singer': 'Mungo Jerry',
#   'ranking': '53',
#   'title': 'In the Summertime',
#   'url': '/wiki/Mungo_Jerry'},
#  {'band_singer': 'R. Dean Taylor',
#   'ranking': '54',
#   'title': 'Indiana Wants Me',
#   'url': '/wiki/R._Dean_Taylor'},
#  {'band_singer': 'Rare Earth',
#   'ranking': '55',
#   'title': "(I Know) I'm Losing You",
#   'url': '/wiki/Rare_Earth_(band)'},
#  {'band_singer': 'Bobby Sherman',
#   'ranking': '56',
#   'title': 'Easy Come, Easy Go',
#   'url': '/wiki/Bobby_Sherman'},
#  {'band_singer': 'Charles Wright & the Watts 103rd Street Rhythm Band',
#   'ranking': '57',
#   'title': 'Express Yourself',
#   'url': '/wiki/Charles_Wright_%26_the_Watts_103rd_Street_Rhythm_Band'},
#  {'band_singer': 'The Four Tops',
#   'ranking': '58',
#   'title': 'Still Water (Love)',
#   'url': '/wiki/The_Four_Tops'},
#  {'band_singer': 'Chicago',
#   'ranking': '59',
#   'title': 'Make Me Smile',
#   'url': '/wiki/Chicago_(band)'},
#  {'band_singer': 'Frijid Pink',
#   'ranking': '60',
#   'title': 'The House of the Rising Sun',
#   'url': '/wiki/Frijid_Pink'},
#  {'band_singer': 'Chicago',
#   'ranking': '61',
#   'title': '25 or 6 to 4',
#   'url': '/wiki/Chicago_(band)'},
#  {'band_singer': 'White Plains',
#   'ranking': '62',
#   'title': "My Baby Loves Lovin'",
#   'url': '/wiki/White_Plains_(band)'},
#  {'band_singer': 'The Friends of Distinction',
#   'ranking': '63',
#   'title': 'Love or Let Me Be Lonely',
#   'url': '/wiki/The_Friends_of_Distinction'},
#  {'band_singer': 'The Brotherhood of Man',
#   'ranking': '64',
#   'title': 'United We Stand',
#   'url': '/wiki/The_Brotherhood_of_Man'},
#  {'band_singer': 'The Carpenters',
#   'ranking': '65',
#   'title': "We've Only Just Begun",
#   'url': '/wiki/The_Carpenters'},
#  {'band_singer': 'Mark Lindsay',
#   'ranking': '66',
#   'title': 'Arizona',
#   'url': '/wiki/Mark_Lindsay'},
#  {'band_singer': 'James Taylor',
#   'ranking': '67',
#   'title': 'Fire and Rain',
#   'url': '/wiki/James_Taylor'},
#  {'band_singer': 'Gene Chandler',
#   'ranking': '68',
#   'title': 'Groovy Situation',
#   'url': '/wiki/Gene_Chandler'},
#  {'band_singer': 'Santana',
#   'ranking': '69',
#   'title': 'Evil Ways',
#   'url': '/wiki/Santana_(band)'},
#  {'band_singer': 'The Guess Who',
#   'ranking': '70',
#   'title': 'No Time',
#   'url': '/wiki/The_Guess_Who'},
#  {'band_singer': 'The Delfonics',
#   'ranking': '71',
#   'title': "Didn't I (Blow Your Mind This Time)",
#   'url': '/wiki/The_Delfonics'},
#  {'band_singer': 'Elvis Presley',
#   'ranking': '72',
#   'title': 'The Wonder of You',
#   'url': '/wiki/Elvis_Presley'},
#  {'band_singer': 'Creedence Clearwater Revival',
#   'ranking': '73',
#   'title': 'Up Around the Bend',
#   'url': '/wiki/Creedence_Clearwater_Revival'},
#  {'band_singer': 'Ronnie Dyson',
#   'ranking': '74',
#   'title': "(If You Let Me Make Love To You Then) Why Can't I Touch You?",
#   'url': '/wiki/Ronnie_Dyson'},
#  {'band_singer': 'B.J. Thomas',
#   'ranking': '75',
#   'title': "I Just Can't Help Believing",
#   'url': '/wiki/B.J._Thomas'},
#  {'band_singer': 'The Spinners',
#   'ranking': '76',
#   'title': "It's a Shame",
#   'url': '/wiki/The_Spinners_(American_band)'},
#  {'band_singer': 'Bobbi Martin',
#   'ranking': '77',
#   'title': 'For the Love of Him',
#   'url': '/wiki/Bobbi_Martin'},
#  {'band_singer': 'Mountain',
#   'ranking': '78',
#   'title': 'Mississippi Queen',
#   'url': '/wiki/Mountain_(band)'},
#  {'band_singer': 'Ike & Tina Turner',
#   'ranking': '79',
#   'title': 'I Want to Take You Higher',
#   'url': '/wiki/Ike_%26_Tina_Turner'},
#  {'band_singer': 'Joe Cocker',
#   'ranking': '80',
#   'title': 'The Letter',
#   'url': '/wiki/Joe_Cocker'},
#  {'band_singer': 'Tee Set',
#   'ranking': '81',
#   'title': 'Ma Belle Amie',
#   'url': '/wiki/Tee_Set'},
#  {'band_singer': 'The Originals',
#   'ranking': '82',
#   'title': 'The Bells',
#   'url': '/wiki/The_Originals_(band)'},
#  {'band_singer': 'Christie',
#   'ranking': '83',
#   'title': 'Yellow River',
#   'url': '/wiki/Christie_(band)'},
#  {'band_singer': '100 Proof (Aged in Soul)',
#   'ranking': '84',
#   'title': "Somebody's Been Sleeping",
#   'url': '/wiki/100_Proof_(Aged_in_Soul)'},
#  {'band_singer': 'The Ides of March',
#   'ranking': '85',
#   'title': 'Vehicle',
#   'url': '/wiki/The_Ides_of_March_(band)'},
#  {'band_singer': 'The Pipkins',
#   'ranking': '86',
#   'title': 'Gimme Dat Ding',
#   'url': '/wiki/The_Pipkins'},
#  {'band_singer': 'Robin McNamara',
#   'ranking': '87',
#   'title': "Lay a Little Lovin' on Me",
#   'url': '/wiki/Robin_McNamara'},
#  {'band_singer': 'The Supremes',
#   'ranking': '88',
#   'title': 'Up the Ladder to the Roof',
#   'url': '/wiki/The_Supremes'},
#  {'band_singer': 'Creedence Clearwater Revival',
#   'ranking': '89',
#   'title': "Travelin' Band",
#   'url': '/wiki/Creedence_Clearwater_Revival'},
#  {'band_singer': 'The Sandpipers',
#   'ranking': '90',
#   'title': 'Come Saturday Morning',
#   'url': '/wiki/The_Sandpipers'},
#  {'band_singer': 'The Temptations',
#   'ranking': '91',
#   'title': 'Psychedelic Shack',
#   'url': '/wiki/The_Temptations'},
#  {'band_singer': 'Tom Jones',
#   'ranking': '92',
#   'title': 'Without Love (There Is Nothing)',
#   'url': '/wiki/Tom_Jones_(singer)'},
#  {'band_singer': 'Pacific Gas & Electric',
#   'ranking': '93',
#   'title': 'Are You Ready?',
#   'url': '/wiki/Pacific_Gas_%26_Electric_(band)'},
#  {'band_singer': 'Crosby, Stills, Nash & Young',
#   'ranking': '94',
#   'title': 'Woodstock',
#   'url': '/wiki/Crosby,_Stills,_Nash_%26_Young'},
#  {'band_singer': 'Dionne Warwick',
#   'ranking': '95',
#   'title': "I'll Never Fall in Love Again",
#   'url': '/wiki/Dionne_Warwick'},
#  {'band_singer': 'The New Seekers',
#   'ranking': '96',
#   'title': "Look What They've Done to My Song Ma",
#   'url': '/wiki/The_New_Seekers'},
#  {'band_singer': 'Joe South',
#   'ranking': '97',
#   'title': 'Walk A Mile In My Shoes',
#   'url': '/wiki/Joe_South'},
#  {'band_singer': 'B.B. King',
#   'ranking': '98',
#   'title': 'The Thrill Is Gone',
#   'url': '/wiki/B.B._King'},
#  {'band_singer': 'Glen Campbell',
#   'ranking': '99',
#   'title': "It's Only Make Believe",
#   'url': '/wiki/Glen_Campbell'},
#  {'band_singer': 'Aretha Franklin',
#   'ranking': '100',
#   'title': 'Call Me',
#   'url': '/wiki/Aretha_Franklin'}]

# %%
#getting the same data for the years 1992 to 2015
urls = ['http://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_'+str(i) for i in range(1992, 2015)]
def getData(url):
    yearsData = {}
    for url in urls:
        request = requests.get(url)
        yearsData[url.split('_')[-1]] = request.text
    return yearsData

yearsData = getData(urls)

yearsData
# Out:
# {'1992': '<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>Billboard Year-End Hot 100 singles of 1992 - Wikipedia</title>\n<script>document.documentElement.className=document.documentElement.className.replace(/(^|\\s)client-nojs(\\s|$)/,"$1client-js$2");RLCONF={"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"Billboard_Year-End_Hot_100_singles_of_1992","wgTitle":"Billboard Year-End Hot 100 singles of 1992","wgCurRevisionId":900740155,"wgRevisionId":900740155,"wgArticleId":24333129,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["1992 record charts","Billboard charts"],"wgBreakFrames":!1,"wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgMonthNamesShort":["","Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"],"wgRelevantPageName":\n"Billboard_Year-End_Hot_100_singles_of_1992","wgRelevantArticleId":24333129,"wgRequestId":"XU8buQpAMEwAAB@oYjUAAACM","wgCSPNonce":!1,"wgIsProbablyEditable":!0,"wgRelevantPageIsProbablyEditable":!0,"wgRestrictionEdit":[],"wgRestrictionMove":[],"wgMediaViewerOnClick":!0,"wgMediaViewerEnabledByDefault":!0,"wgPopupsReferencePreviews":!1,"wgPopupsConflictsWithNavPopupGadget":!1,"wgVisualEditor":{"pageLanguageCode":"en","pageLanguageDir":"ltr","pageVariantFallbacks":"en"},"wgMFDisplayWikibaseDescriptions":{"search":!0,"nearby":!0,"watchlist":!0,"tagline":!1},"wgWMESchemaEditAttemptStepOversample":!1,"wgPoweredByHHVM":!0,"wgULSCurrentAutonym":"English","wgNoticeProject":"wikipedia","wgWikibaseItemId":"Q1415621","wgCentralAuthMobileDomain":!1,"wgEditSubmitButtonLabelPublish":!0};RLSTATE={"ext.gadget.charinsert-styles":"ready","ext.globalCssJs.user.styles":"ready","ext.globalCssJs.site.styles":"ready","site.styles":"ready","noscript":"ready","user.styles":\n"ready","ext.globalCssJs.user":"ready","ext.globalCssJs.site":"ready","user":"ready","user.options":"ready","user.tokens":"loading","ext.cite.styles":"ready","mediawiki.legacy.shared":"ready","mediawiki.legacy.commonPrint":"ready","jquery.tablesorter.styles":"ready","wikibase.client.init":"ready","ext.visualEditor.desktopArticleTarget.noscript":"ready","ext.uls.interlanguage":"ready","ext.wikimediaBadges":"ready","ext.3d.styles":"ready","mediawiki.skinning.interface":"ready","skins.vector.styles":"ready"};RLPAGEMODULES=["ext.cite.ux-enhancements","site","mediawiki.page.startup","mediawiki.page.ready","jquery.tablesorter","mediawiki.searchSuggest","ext.gadget.teahouse","ext.gadget.ReferenceTooltips","ext.gadget.watchlist-notice","ext.gadget.DRN-wizard","ext.gadget.charinsert","ext.gadget.refToolbar","ext.gadget.extra-toolbar-buttons","ext.gadget.switcher","ext.centralauth.centralautologin","ext.popups","ext.visualEditor.desktopArticleTarget.init","ext.visualEditor.targetLoader",\n"ext.eventLogging","ext.wikimediaEvents","ext.navigationTiming","ext.uls.compactlinks","ext.uls.interface","ext.cx.eventlogging.campaigns","ext.quicksurveys.init","ext.centralNotice.geoIP","ext.centralNotice.startUp","skins.vector.js"];</script>\n<script>(RLQ=window.RLQ||[]).push(function(){mw.loader.implement("user.tokens@0tffind",function($,jQuery,require,module){/*@nomin*/mw.user.tokens.set({"editToken":"+\\\\","patrolToken":"+\\\\","watchToken":"+\\\\","csrfToken":"+\\\\"});\n});});</script>\n<link rel="stylesheet" href="/w/load.php?lang=en&amp;modules=ext.3d.styles%7Cext.cite.styles%7Cext.uls.interlanguage%7Cext.visualEditor.desktopArticleTarget.noscript%7Cext.wikimediaBadges%7Cjquery.tablesorter.styles%7Cmediawiki.legacy.commonPrint%2Cshared%7Cmediawiki.skinning.interface%7Cskins.vector.styles%7Cwikibase.client.init&amp;only=styles&amp;skin=vector"/>\n<script asy ...
#  '1993': '<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>Billboard Year-End Hot 100 singles of 1993 - Wikipedia</title>\n<script>document.documentElement.className=document.documentElement.className.replace(/(^|\\s)client-nojs(\\s|$)/,"$1client-js$2");RLCONF={"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"Billboard_Year-End_Hot_100_singles_of_1993","wgTitle":"Billboard Year-End Hot 100 singles of 1993","wgCurRevisionId":908748068,"wgRevisionId":908748068,"wgArticleId":23204983,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["1993 record charts","Billboard charts"],"wgBreakFrames":!1,"wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgMonthNamesShort":["","Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"],"wgRelevantPageName":\n"Billboard_Year-End_Hot_100_singles_of_1993","wgRelevantArticleId":23204983,"wgRequestId":"XU8ZsgpAICEAAJCs3pUAAABV","wgCSPNonce":!1,"wgIsProbablyEditable":!0,"wgRelevantPageIsProbablyEditable":!0,"wgRestrictionEdit":[],"wgRestrictionMove":[],"wgMediaViewerOnClick":!0,"wgMediaViewerEnabledByDefault":!0,"wgPopupsReferencePreviews":!1,"wgPopupsConflictsWithNavPopupGadget":!1,"wgVisualEditor":{"pageLanguageCode":"en","pageLanguageDir":"ltr","pageVariantFallbacks":"en"},"wgMFDisplayWikibaseDescriptions":{"search":!0,"nearby":!0,"watchlist":!0,"tagline":!1},"wgWMESchemaEditAttemptStepOversample":!1,"wgPoweredByHHVM":!0,"wgULSCurrentAutonym":"English","wgNoticeProject":"wikipedia","wgWikibaseItemId":"Q435206","wgCentralAuthMobileDomain":!1,"wgEditSubmitButtonLabelPublish":!0};RLSTATE={"ext.gadget.charinsert-styles":"ready","ext.globalCssJs.user.styles":"ready","ext.globalCssJs.site.styles":"ready","site.styles":"ready","noscript":"ready","user.styles":\n"ready","ext.globalCssJs.user":"ready","ext.globalCssJs.site":"ready","user":"ready","user.options":"ready","user.tokens":"loading","ext.cite.styles":"ready","mediawiki.legacy.shared":"ready","mediawiki.legacy.commonPrint":"ready","jquery.tablesorter.styles":"ready","wikibase.client.init":"ready","ext.visualEditor.desktopArticleTarget.noscript":"ready","ext.uls.interlanguage":"ready","ext.wikimediaBadges":"ready","ext.3d.styles":"ready","mediawiki.skinning.interface":"ready","skins.vector.styles":"ready"};RLPAGEMODULES=["ext.cite.ux-enhancements","site","mediawiki.page.startup","mediawiki.page.ready","jquery.tablesorter","mediawiki.searchSuggest","ext.gadget.teahouse","ext.gadget.ReferenceTooltips","ext.gadget.watchlist-notice","ext.gadget.DRN-wizard","ext.gadget.charinsert","ext.gadget.refToolbar","ext.gadget.extra-toolbar-buttons","ext.gadget.switcher","ext.centralauth.centralautologin","ext.popups","ext.visualEditor.desktopArticleTarget.init","ext.visualEditor.targetLoader",\n"ext.eventLogging","ext.wikimediaEvents","ext.navigationTiming","ext.uls.compactlinks","ext.uls.interface","ext.cx.eventlogging.campaigns","ext.quicksurveys.init","ext.centralNotice.geoIP","ext.centralNotice.startUp","skins.vector.js"];</script>\n<script>(RLQ=window.RLQ||[]).push(function(){mw.loader.implement("user.tokens@0tffind",function($,jQuery,require,module){/*@nomin*/mw.user.tokens.set({"editToken":"+\\\\","patrolToken":"+\\\\","watchToken":"+\\\\","csrfToken":"+\\\\"});\n});});</script>\n<link rel="stylesheet" href="/w/load.php?lang=en&amp;modules=ext.3d.styles%7Cext.cite.styles%7Cext.uls.interlanguage%7Cext.visualEditor.desktopArticleTarget.noscript%7Cext.wikimediaBadges%7Cjquery.tablesorter.styles%7Cmediawiki.legacy.commonPrint%2Cshared%7Cmediawiki.skinning.interface%7Cskins.vector.styles%7Cwikibase.client.init&amp;only=styles&amp;skin=vector"/>\n<script asyn ...
#  '1994': '<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>Billboard Year-End Hot 100 singles of 1994 - Wikipedia</title>\n<script>document.documentElement.className=document.documentElement.className.replace(/(^|\\s)client-nojs(\\s|$)/,"$1client-js$2");RLCONF={"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"Billboard_Year-End_Hot_100_singles_of_1994","wgTitle":"Billboard Year-End Hot 100 singles of 1994","wgCurRevisionId":898792566,"wgRevisionId":898792566,"wgArticleId":23193314,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Use mdy dates from May 2019","Articles with short description","1994 record charts","Billboard charts"],"wgBreakFrames":!1,"wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgMonthNamesShort":["","Jan","Feb","Mar","Apr","May","Jun","Jul","Aug",\n"Sep","Oct","Nov","Dec"],"wgRelevantPageName":"Billboard_Year-End_Hot_100_singles_of_1994","wgRelevantArticleId":23193314,"wgRequestId":"XU8ZhApAIC4AAHX0mwkAAAAR","wgCSPNonce":!1,"wgIsProbablyEditable":!0,"wgRelevantPageIsProbablyEditable":!0,"wgRestrictionEdit":[],"wgRestrictionMove":[],"wgMediaViewerOnClick":!0,"wgMediaViewerEnabledByDefault":!0,"wgPopupsReferencePreviews":!1,"wgPopupsConflictsWithNavPopupGadget":!1,"wgVisualEditor":{"pageLanguageCode":"en","pageLanguageDir":"ltr","pageVariantFallbacks":"en"},"wgMFDisplayWikibaseDescriptions":{"search":!0,"nearby":!0,"watchlist":!0,"tagline":!1},"wgWMESchemaEditAttemptStepOversample":!1,"wgPoweredByHHVM":!0,"wgULSCurrentAutonym":"English","wgNoticeProject":"wikipedia","wgWikibaseItemId":"Q1414017","wgCentralAuthMobileDomain":!1,"wgEditSubmitButtonLabelPublish":!0};RLSTATE={"ext.gadget.charinsert-styles":"ready","ext.globalCssJs.user.styles":"ready","ext.globalCssJs.site.styles":"ready",\n"site.styles":"ready","noscript":"ready","user.styles":"ready","ext.globalCssJs.user":"ready","ext.globalCssJs.site":"ready","user":"ready","user.options":"ready","user.tokens":"loading","ext.cite.styles":"ready","mediawiki.legacy.shared":"ready","mediawiki.legacy.commonPrint":"ready","jquery.tablesorter.styles":"ready","wikibase.client.init":"ready","ext.visualEditor.desktopArticleTarget.noscript":"ready","ext.uls.interlanguage":"ready","ext.wikimediaBadges":"ready","ext.3d.styles":"ready","mediawiki.skinning.interface":"ready","skins.vector.styles":"ready"};RLPAGEMODULES=["ext.cite.ux-enhancements","site","mediawiki.page.startup","mediawiki.page.ready","jquery.tablesorter","mediawiki.searchSuggest","ext.gadget.teahouse","ext.gadget.ReferenceTooltips","ext.gadget.watchlist-notice","ext.gadget.DRN-wizard","ext.gadget.charinsert","ext.gadget.refToolbar","ext.gadget.extra-toolbar-buttons","ext.gadget.switcher","ext.centralauth.centralautologin","mmv.head","mmv.bootstrap.autostart",\n"ext.popups","ext.visualEditor.desktopArticleTarget.init","ext.visualEditor.targetLoader","ext.eventLogging","ext.wikimediaEvents","ext.navigationTiming","ext.uls.compactlinks","ext.uls.interface","ext.cx.eventlogging.campaigns","ext.quicksurveys.init","ext.centralNotice.geoIP","ext.centralNotice.startUp","skins.vector.js"];</script>\n<script>(RLQ=window.RLQ||[]).push(function(){mw.loader.implement("user.tokens@0tffind",function($,jQuery,require,module){/*@nomin*/mw.user.tokens.set({"editToken":"+\\\\","patrolToken":"+\\\\","watchToken":"+\\\\","csrfToken":"+\\\\"});\n});});</script>\n<link rel="stylesheet" href="/w/load.php?lang=en&amp;modules=ext.3d.styles%7Cext.cite.styles%7Cext.uls.interlanguage%7Cext.visualEditor.desktopArticleTarget.noscript%7Cext.wikimediaBadges%7Cjquery.tablesorter.styles%7Cmediawiki.legacy.commonPrint%2Cshared%7Cmediawiki.skinning.i ...
#  '1995': '<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>Billboard Year-End Hot 100 singles of 1995 - Wikipedia</title>\n<script>document.documentElement.className=document.documentElement.className.replace(/(^|\\s)client-nojs(\\s|$)/,"$1client-js$2");RLCONF={"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"Billboard_Year-End_Hot_100_singles_of_1995","wgTitle":"Billboard Year-End Hot 100 singles of 1995","wgCurRevisionId":907891164,"wgRevisionId":907891164,"wgArticleId":20155098,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["1995 record charts","Billboard charts"],"wgBreakFrames":!1,"wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgMonthNamesShort":["","Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"],"wgRelevantPageName":\n"Billboard_Year-End_Hot_100_singles_of_1995","wgRelevantArticleId":20155098,"wgRequestId":"XU8dfwpAICkAAF6c1rUAAADA","wgCSPNonce":!1,"wgIsProbablyEditable":!0,"wgRelevantPageIsProbablyEditable":!0,"wgRestrictionEdit":[],"wgRestrictionMove":[],"wgMediaViewerOnClick":!0,"wgMediaViewerEnabledByDefault":!0,"wgPopupsReferencePreviews":!1,"wgPopupsConflictsWithNavPopupGadget":!1,"wgVisualEditor":{"pageLanguageCode":"en","pageLanguageDir":"ltr","pageVariantFallbacks":"en"},"wgMFDisplayWikibaseDescriptions":{"search":!0,"nearby":!0,"watchlist":!0,"tagline":!1},"wgWMESchemaEditAttemptStepOversample":!1,"wgPoweredByHHVM":!0,"wgULSCurrentAutonym":"English","wgNoticeProject":"wikipedia","wgWikibaseItemId":"Q1413208","wgCentralAuthMobileDomain":!1,"wgEditSubmitButtonLabelPublish":!0};RLSTATE={"ext.gadget.charinsert-styles":"ready","ext.globalCssJs.user.styles":"ready","ext.globalCssJs.site.styles":"ready","site.styles":"ready","noscript":"ready","user.styles":\n"ready","ext.globalCssJs.user":"ready","ext.globalCssJs.site":"ready","user":"ready","user.options":"ready","user.tokens":"loading","ext.cite.styles":"ready","mediawiki.legacy.shared":"ready","mediawiki.legacy.commonPrint":"ready","jquery.tablesorter.styles":"ready","wikibase.client.init":"ready","ext.visualEditor.desktopArticleTarget.noscript":"ready","ext.uls.interlanguage":"ready","ext.wikimediaBadges":"ready","ext.3d.styles":"ready","mediawiki.skinning.interface":"ready","skins.vector.styles":"ready"};RLPAGEMODULES=["ext.cite.ux-enhancements","site","mediawiki.page.startup","mediawiki.page.ready","jquery.tablesorter","mediawiki.searchSuggest","ext.gadget.teahouse","ext.gadget.ReferenceTooltips","ext.gadget.watchlist-notice","ext.gadget.DRN-wizard","ext.gadget.charinsert","ext.gadget.refToolbar","ext.gadget.extra-toolbar-buttons","ext.gadget.switcher","ext.centralauth.centralautologin","mmv.head","mmv.bootstrap.autostart","ext.popups","ext.visualEditor.desktopArticleTarget.init",\n"ext.visualEditor.targetLoader","ext.eventLogging","ext.wikimediaEvents","ext.navigationTiming","ext.uls.compactlinks","ext.uls.interface","ext.cx.eventlogging.campaigns","ext.quicksurveys.init","ext.centralNotice.geoIP","ext.centralNotice.startUp","skins.vector.js"];</script>\n<script>(RLQ=window.RLQ||[]).push(function(){mw.loader.implement("user.tokens@0tffind",function($,jQuery,require,module){/*@nomin*/mw.user.tokens.set({"editToken":"+\\\\","patrolToken":"+\\\\","watchToken":"+\\\\","csrfToken":"+\\\\"});\n});});</script>\n<link rel="stylesheet" href="/w/load.php?lang=en&amp;modules=ext.3d.styles%7Cext.cite.styles%7Cext.uls.interlanguage%7Cext.visualEditor.desktopArticleTarget.noscript%7Cext.wikimediaBadges%7Cjquery.tablesorter.styles%7Cmediawiki.legacy.commonPrint%2Cshared%7Cmediawiki.skinning.interface%7Cskins.vector.styles%7Cwikibase.client.init&amp;only=s ...
#  '1996': '<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>Billboard Year-End Hot 100 singles of 1996 - Wikipedia</title>\n<script>document.documentElement.className=document.documentElement.className.replace(/(^|\\s)client-nojs(\\s|$)/,"$1client-js$2");RLCONF={"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"Billboard_Year-End_Hot_100_singles_of_1996","wgTitle":"Billboard Year-End Hot 100 singles of 1996","wgCurRevisionId":898793102,"wgRevisionId":898793102,"wgArticleId":19937784,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["1996 record charts","Billboard charts"],"wgBreakFrames":!1,"wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgMonthNamesShort":["","Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"],"wgRelevantPageName":\n"Billboard_Year-End_Hot_100_singles_of_1996","wgRelevantArticleId":19937784,"wgRequestId":"XU8hpQpAME8AAJEKSVsAAABK","wgCSPNonce":!1,"wgIsProbablyEditable":!0,"wgRelevantPageIsProbablyEditable":!0,"wgRestrictionEdit":[],"wgRestrictionMove":[],"wgMediaViewerOnClick":!0,"wgMediaViewerEnabledByDefault":!0,"wgPopupsReferencePreviews":!1,"wgPopupsConflictsWithNavPopupGadget":!1,"wgVisualEditor":{"pageLanguageCode":"en","pageLanguageDir":"ltr","pageVariantFallbacks":"en"},"wgMFDisplayWikibaseDescriptions":{"search":!0,"nearby":!0,"watchlist":!0,"tagline":!1},"wgWMESchemaEditAttemptStepOversample":!1,"wgPoweredByHHVM":!0,"wgULSCurrentAutonym":"English","wgNoticeProject":"wikipedia","wgWikibaseItemId":"Q648426","wgCentralAuthMobileDomain":!1,"wgEditSubmitButtonLabelPublish":!0};RLSTATE={"ext.gadget.charinsert-styles":"ready","ext.globalCssJs.user.styles":"ready","ext.globalCssJs.site.styles":"ready","site.styles":"ready","noscript":"ready","user.styles":\n"ready","ext.globalCssJs.user":"ready","ext.globalCssJs.site":"ready","user":"ready","user.options":"ready","user.tokens":"loading","ext.cite.styles":"ready","mediawiki.legacy.shared":"ready","mediawiki.legacy.commonPrint":"ready","jquery.tablesorter.styles":"ready","wikibase.client.init":"ready","ext.visualEditor.desktopArticleTarget.noscript":"ready","ext.uls.interlanguage":"ready","ext.wikimediaBadges":"ready","ext.3d.styles":"ready","mediawiki.skinning.interface":"ready","skins.vector.styles":"ready"};RLPAGEMODULES=["ext.cite.ux-enhancements","site","mediawiki.page.startup","mediawiki.page.ready","jquery.tablesorter","mediawiki.searchSuggest","ext.gadget.teahouse","ext.gadget.ReferenceTooltips","ext.gadget.watchlist-notice","ext.gadget.DRN-wizard","ext.gadget.charinsert","ext.gadget.refToolbar","ext.gadget.extra-toolbar-buttons","ext.gadget.switcher","ext.centralauth.centralautologin","mmv.head","mmv.bootstrap.autostart","ext.popups","ext.visualEditor.desktopArticleTarget.init",\n"ext.visualEditor.targetLoader","ext.eventLogging","ext.wikimediaEvents","ext.navigationTiming","ext.uls.compactlinks","ext.uls.interface","ext.cx.eventlogging.campaigns","ext.quicksurveys.init","ext.centralNotice.geoIP","ext.centralNotice.startUp","skins.vector.js"];</script>\n<script>(RLQ=window.RLQ||[]).push(function(){mw.loader.implement("user.tokens@0tffind",function($,jQuery,require,module){/*@nomin*/mw.user.tokens.set({"editToken":"+\\\\","patrolToken":"+\\\\","watchToken":"+\\\\","csrfToken":"+\\\\"});\n});});</script>\n<link rel="stylesheet" href="/w/load.php?lang=en&amp;modules=ext.3d.styles%7Cext.cite.styles%7Cext.uls.interlanguage%7Cext.visualEditor.desktopArticleTarget.noscript%7Cext.wikimediaBadges%7Cjquery.tablesorter.styles%7Cmediawiki.legacy.commonPrint%2Cshared%7Cmediawiki.skinning.interface%7Cskins.vector.styles%7Cwikibase.client.init&amp;only=st ...
#  '1997': '<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>Billboard Year-End Hot 100 singles of 1997 - Wikipedia</title>\n<script>document.documentElement.className=document.documentElement.className.replace(/(^|\\s)client-nojs(\\s|$)/,"$1client-js$2");RLCONF={"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"Billboard_Year-End_Hot_100_singles_of_1997","wgTitle":"Billboard Year-End Hot 100 singles of 1997","wgCurRevisionId":907891758,"wgRevisionId":907891758,"wgArticleId":19096399,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["1997 record charts","Billboard charts"],"wgBreakFrames":!1,"wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgMonthNamesShort":["","Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"],"wgRelevantPageName":\n"Billboard_Year-End_Hot_100_singles_of_1997","wgRelevantArticleId":19096399,"wgRequestId":"XU8hpgpAMFoAAGCn-XUAAABV","wgCSPNonce":!1,"wgIsProbablyEditable":!0,"wgRelevantPageIsProbablyEditable":!0,"wgRestrictionEdit":[],"wgRestrictionMove":[],"wgMediaViewerOnClick":!0,"wgMediaViewerEnabledByDefault":!0,"wgPopupsReferencePreviews":!1,"wgPopupsConflictsWithNavPopupGadget":!1,"wgVisualEditor":{"pageLanguageCode":"en","pageLanguageDir":"ltr","pageVariantFallbacks":"en"},"wgMFDisplayWikibaseDescriptions":{"search":!0,"nearby":!0,"watchlist":!0,"tagline":!1},"wgWMESchemaEditAttemptStepOversample":!1,"wgPoweredByHHVM":!0,"wgULSCurrentAutonym":"English","wgNoticeProject":"wikipedia","wgWikibaseItemId":"Q745193","wgCentralAuthMobileDomain":!1,"wgEditSubmitButtonLabelPublish":!0};RLSTATE={"ext.gadget.charinsert-styles":"ready","ext.globalCssJs.user.styles":"ready","ext.globalCssJs.site.styles":"ready","site.styles":"ready","noscript":"ready","user.styles":\n"ready","ext.globalCssJs.user":"ready","ext.globalCssJs.site":"ready","user":"ready","user.options":"ready","user.tokens":"loading","ext.cite.styles":"ready","mediawiki.legacy.shared":"ready","mediawiki.legacy.commonPrint":"ready","jquery.tablesorter.styles":"ready","wikibase.client.init":"ready","ext.visualEditor.desktopArticleTarget.noscript":"ready","ext.uls.interlanguage":"ready","ext.wikimediaBadges":"ready","ext.3d.styles":"ready","mediawiki.skinning.interface":"ready","skins.vector.styles":"ready"};RLPAGEMODULES=["ext.cite.ux-enhancements","site","mediawiki.page.startup","mediawiki.page.ready","jquery.tablesorter","mediawiki.searchSuggest","ext.gadget.teahouse","ext.gadget.ReferenceTooltips","ext.gadget.watchlist-notice","ext.gadget.DRN-wizard","ext.gadget.charinsert","ext.gadget.refToolbar","ext.gadget.extra-toolbar-buttons","ext.gadget.switcher","ext.centralauth.centralautologin","ext.popups","ext.visualEditor.desktopArticleTarget.init","ext.visualEditor.targetLoader",\n"ext.eventLogging","ext.wikimediaEvents","ext.navigationTiming","ext.uls.compactlinks","ext.uls.interface","ext.cx.eventlogging.campaigns","ext.quicksurveys.init","ext.centralNotice.geoIP","ext.centralNotice.startUp","skins.vector.js"];</script>\n<script>(RLQ=window.RLQ||[]).push(function(){mw.loader.implement("user.tokens@0tffind",function($,jQuery,require,module){/*@nomin*/mw.user.tokens.set({"editToken":"+\\\\","patrolToken":"+\\\\","watchToken":"+\\\\","csrfToken":"+\\\\"});\n});});</script>\n<link rel="stylesheet" href="/w/load.php?lang=en&amp;modules=ext.3d.styles%7Cext.cite.styles%7Cext.uls.interlanguage%7Cext.visualEditor.desktopArticleTarget.noscript%7Cext.wikimediaBadges%7Cjquery.tablesorter.styles%7Cmediawiki.legacy.commonPrint%2Cshared%7Cmediawiki.skinning.interface%7Cskins.vector.styles%7Cwikibase.client.init&amp;only=styles&amp;skin=vector"/>\n<script asyn ...
#  '1998': '<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>Billboard Year-End Hot 100 singles of 1998 - Wikipedia</title>\n<script>document.documentElement.className=document.documentElement.className.replace(/(^|\\s)client-nojs(\\s|$)/,"$1client-js$2");RLCONF={"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"Billboard_Year-End_Hot_100_singles_of_1998","wgTitle":"Billboard Year-End Hot 100 singles of 1998","wgCurRevisionId":898794290,"wgRevisionId":898794290,"wgArticleId":18913174,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["1998 record charts","Billboard charts"],"wgBreakFrames":!1,"wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgMonthNamesShort":["","Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"],"wgRelevantPageName":\n"Billboard_Year-End_Hot_100_singles_of_1998","wgRelevantArticleId":18913174,"wgRequestId":"XU8V9gpAADsAAEJZG4AAAAAD","wgCSPNonce":!1,"wgIsProbablyEditable":!0,"wgRelevantPageIsProbablyEditable":!0,"wgRestrictionEdit":[],"wgRestrictionMove":[],"wgMediaViewerOnClick":!0,"wgMediaViewerEnabledByDefault":!0,"wgPopupsReferencePreviews":!1,"wgPopupsConflictsWithNavPopupGadget":!1,"wgVisualEditor":{"pageLanguageCode":"en","pageLanguageDir":"ltr","pageVariantFallbacks":"en"},"wgMFDisplayWikibaseDescriptions":{"search":!0,"nearby":!0,"watchlist":!0,"tagline":!1},"wgWMESchemaEditAttemptStepOversample":!1,"wgPoweredByHHVM":!0,"wgULSCurrentAutonym":"English","wgNoticeProject":"wikipedia","wgWikibaseItemId":"Q513318","wgCentralAuthMobileDomain":!1,"wgEditSubmitButtonLabelPublish":!0};RLSTATE={"ext.gadget.charinsert-styles":"ready","ext.globalCssJs.user.styles":"ready","ext.globalCssJs.site.styles":"ready","site.styles":"ready","noscript":"ready","user.styles":\n"ready","ext.globalCssJs.user":"ready","ext.globalCssJs.site":"ready","user":"ready","user.options":"ready","user.tokens":"loading","ext.cite.styles":"ready","mediawiki.legacy.shared":"ready","mediawiki.legacy.commonPrint":"ready","jquery.tablesorter.styles":"ready","wikibase.client.init":"ready","ext.visualEditor.desktopArticleTarget.noscript":"ready","ext.uls.interlanguage":"ready","ext.wikimediaBadges":"ready","ext.3d.styles":"ready","mediawiki.skinning.interface":"ready","skins.vector.styles":"ready"};RLPAGEMODULES=["ext.cite.ux-enhancements","site","mediawiki.page.startup","mediawiki.page.ready","jquery.tablesorter","mediawiki.searchSuggest","ext.gadget.teahouse","ext.gadget.ReferenceTooltips","ext.gadget.watchlist-notice","ext.gadget.DRN-wizard","ext.gadget.charinsert","ext.gadget.refToolbar","ext.gadget.extra-toolbar-buttons","ext.gadget.switcher","ext.centralauth.centralautologin","mmv.head","mmv.bootstrap.autostart","ext.popups","ext.visualEditor.desktopArticleTarget.init",\n"ext.visualEditor.targetLoader","ext.eventLogging","ext.wikimediaEvents","ext.navigationTiming","ext.uls.compactlinks","ext.uls.interface","ext.cx.eventlogging.campaigns","ext.quicksurveys.init","ext.centralNotice.geoIP","ext.centralNotice.startUp","skins.vector.js"];</script>\n<script>(RLQ=window.RLQ||[]).push(function(){mw.loader.implement("user.tokens@0tffind",function($,jQuery,require,module){/*@nomin*/mw.user.tokens.set({"editToken":"+\\\\","patrolToken":"+\\\\","watchToken":"+\\\\","csrfToken":"+\\\\"});\n});});</script>\n<link rel="stylesheet" href="/w/load.php?lang=en&amp;modules=ext.3d.styles%7Cext.cite.styles%7Cext.uls.interlanguage%7Cext.visualEditor.desktopArticleTarget.noscript%7Cext.wikimediaBadges%7Cjquery.tablesorter.styles%7Cmediawiki.legacy.commonPrint%2Cshared%7Cmediawiki.skinning.interface%7Cskins.vector.styles%7Cwikibase.client.init&amp;only=st ...
#  '1999': '<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>Billboard Year-End Hot 100 singles of 1999 - Wikipedia</title>\n<script>document.documentElement.className=document.documentElement.className.replace(/(^|\\s)client-nojs(\\s|$)/,"$1client-js$2");RLCONF={"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"Billboard_Year-End_Hot_100_singles_of_1999","wgTitle":"Billboard Year-End Hot 100 singles of 1999","wgCurRevisionId":907892416,"wgRevisionId":907892416,"wgArticleId":16326921,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["1999 record charts","Billboard charts"],"wgBreakFrames":!1,"wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgMonthNamesShort":["","Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"],"wgRelevantPageName":\n"Billboard_Year-End_Hot_100_singles_of_1999","wgRelevantArticleId":16326921,"wgRequestId":"XU8UOwpAMFQAALW5qIEAAABB","wgCSPNonce":!1,"wgIsProbablyEditable":!0,"wgRelevantPageIsProbablyEditable":!0,"wgRestrictionEdit":[],"wgRestrictionMove":[],"wgMediaViewerOnClick":!0,"wgMediaViewerEnabledByDefault":!0,"wgPopupsReferencePreviews":!1,"wgPopupsConflictsWithNavPopupGadget":!1,"wgVisualEditor":{"pageLanguageCode":"en","pageLanguageDir":"ltr","pageVariantFallbacks":"en"},"wgMFDisplayWikibaseDescriptions":{"search":!0,"nearby":!0,"watchlist":!0,"tagline":!1},"wgWMESchemaEditAttemptStepOversample":!1,"wgPoweredByHHVM":!0,"wgULSCurrentAutonym":"English","wgNoticeProject":"wikipedia","wgWikibaseItemId":"Q966907","wgCentralAuthMobileDomain":!1,"wgEditSubmitButtonLabelPublish":!0};RLSTATE={"ext.gadget.charinsert-styles":"ready","ext.globalCssJs.user.styles":"ready","ext.globalCssJs.site.styles":"ready","site.styles":"ready","noscript":"ready","user.styles":\n"ready","ext.globalCssJs.user":"ready","ext.globalCssJs.site":"ready","user":"ready","user.options":"ready","user.tokens":"loading","ext.cite.styles":"ready","mediawiki.legacy.shared":"ready","mediawiki.legacy.commonPrint":"ready","jquery.tablesorter.styles":"ready","wikibase.client.init":"ready","ext.visualEditor.desktopArticleTarget.noscript":"ready","ext.uls.interlanguage":"ready","ext.wikimediaBadges":"ready","ext.3d.styles":"ready","mediawiki.skinning.interface":"ready","skins.vector.styles":"ready"};RLPAGEMODULES=["ext.cite.ux-enhancements","site","mediawiki.page.startup","mediawiki.page.ready","jquery.tablesorter","mediawiki.searchSuggest","ext.gadget.teahouse","ext.gadget.ReferenceTooltips","ext.gadget.watchlist-notice","ext.gadget.DRN-wizard","ext.gadget.charinsert","ext.gadget.refToolbar","ext.gadget.extra-toolbar-buttons","ext.gadget.switcher","ext.centralauth.centralautologin","mmv.head","mmv.bootstrap.autostart","ext.popups","ext.visualEditor.desktopArticleTarget.init",\n"ext.visualEditor.targetLoader","ext.eventLogging","ext.wikimediaEvents","ext.navigationTiming","ext.uls.compactlinks","ext.uls.interface","ext.cx.eventlogging.campaigns","ext.quicksurveys.init","ext.centralNotice.geoIP","ext.centralNotice.startUp","skins.vector.js"];</script>\n<script>(RLQ=window.RLQ||[]).push(function(){mw.loader.implement("user.tokens@0tffind",function($,jQuery,require,module){/*@nomin*/mw.user.tokens.set({"editToken":"+\\\\","patrolToken":"+\\\\","watchToken":"+\\\\","csrfToken":"+\\\\"});\n});});</script>\n<link rel="stylesheet" href="/w/load.php?lang=en&amp;modules=ext.3d.styles%7Cext.cite.styles%7Cext.uls.interlanguage%7Cext.visualEditor.desktopArticleTarget.noscript%7Cext.wikimediaBadges%7Cjquery.tablesorter.styles%7Cmediawiki.legacy.commonPrint%2Cshared%7Cmediawiki.skinning.interface%7Cskins.vector.styles%7Cwikibase.client.init&amp;only=st ...
#  '2000': '<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>Billboard Year-End Hot 100 singles of 2000 - Wikipedia</title>\n<script>document.documentElement.className=document.documentElement.className.replace(/(^|\\s)client-nojs(\\s|$)/,"$1client-js$2");RLCONF={"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"Billboard_Year-End_Hot_100_singles_of_2000","wgTitle":"Billboard Year-End Hot 100 singles of 2000","wgCurRevisionId":903329540,"wgRevisionId":903329540,"wgArticleId":18580928,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["2000 record charts","Billboard charts"],"wgBreakFrames":!1,"wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgMonthNamesShort":["","Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"],"wgRelevantPageName":\n"Billboard_Year-End_Hot_100_singles_of_2000","wgRelevantArticleId":18580928,"wgRequestId":"XU8VbgpAIC8AALsPffAAAACD","wgCSPNonce":!1,"wgIsProbablyEditable":!0,"wgRelevantPageIsProbablyEditable":!0,"wgRestrictionEdit":[],"wgRestrictionMove":[],"wgMediaViewerOnClick":!0,"wgMediaViewerEnabledByDefault":!0,"wgPopupsReferencePreviews":!1,"wgPopupsConflictsWithNavPopupGadget":!1,"wgVisualEditor":{"pageLanguageCode":"en","pageLanguageDir":"ltr","pageVariantFallbacks":"en"},"wgMFDisplayWikibaseDescriptions":{"search":!0,"nearby":!0,"watchlist":!0,"tagline":!1},"wgWMESchemaEditAttemptStepOversample":!1,"wgPoweredByHHVM":!0,"wgULSCurrentAutonym":"English","wgNoticeProject":"wikipedia","wgWikibaseItemId":"Q1488590","wgCentralAuthMobileDomain":!1,"wgEditSubmitButtonLabelPublish":!0};RLSTATE={"ext.gadget.charinsert-styles":"ready","ext.globalCssJs.user.styles":"ready","ext.globalCssJs.site.styles":"ready","site.styles":"ready","noscript":"ready","user.styles":\n"ready","ext.globalCssJs.user":"ready","ext.globalCssJs.site":"ready","user":"ready","user.options":"ready","user.tokens":"loading","ext.cite.styles":"ready","mediawiki.legacy.shared":"ready","mediawiki.legacy.commonPrint":"ready","jquery.tablesorter.styles":"ready","wikibase.client.init":"ready","ext.visualEditor.desktopArticleTarget.noscript":"ready","ext.uls.interlanguage":"ready","ext.wikimediaBadges":"ready","ext.3d.styles":"ready","mediawiki.skinning.interface":"ready","skins.vector.styles":"ready"};RLPAGEMODULES=["ext.cite.ux-enhancements","site","mediawiki.page.startup","mediawiki.page.ready","jquery.tablesorter","mediawiki.searchSuggest","ext.gadget.teahouse","ext.gadget.ReferenceTooltips","ext.gadget.watchlist-notice","ext.gadget.DRN-wizard","ext.gadget.charinsert","ext.gadget.refToolbar","ext.gadget.extra-toolbar-buttons","ext.gadget.switcher","ext.centralauth.centralautologin","mmv.head","mmv.bootstrap.autostart","ext.popups","ext.visualEditor.desktopArticleTarget.init",\n"ext.visualEditor.targetLoader","ext.eventLogging","ext.wikimediaEvents","ext.navigationTiming","ext.uls.compactlinks","ext.uls.interface","ext.cx.eventlogging.campaigns","ext.quicksurveys.init","ext.centralNotice.geoIP","ext.centralNotice.startUp","skins.vector.js"];</script>\n<script>(RLQ=window.RLQ||[]).push(function(){mw.loader.implement("user.tokens@0tffind",function($,jQuery,require,module){/*@nomin*/mw.user.tokens.set({"editToken":"+\\\\","patrolToken":"+\\\\","watchToken":"+\\\\","csrfToken":"+\\\\"});\n});});</script>\n<link rel="stylesheet" href="/w/load.php?lang=en&amp;modules=ext.3d.styles%7Cext.cite.styles%7Cext.uls.interlanguage%7Cext.visualEditor.desktopArticleTarget.noscript%7Cext.wikimediaBadges%7Cjquery.tablesorter.styles%7Cmediawiki.legacy.commonPrint%2Cshared%7Cmediawiki.skinning.interface%7Cskins.vector.styles%7Cwikibase.client.init&amp;only=s ...
#  '2001': '<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>Billboard Year-End Hot 100 singles of 2001 - Wikipedia</title>\n<script>document.documentElement.className=document.documentElement.className.replace(/(^|\\s)client-nojs(\\s|$)/,"$1client-js$2");RLCONF={"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"Billboard_Year-End_Hot_100_singles_of_2001","wgTitle":"Billboard Year-End Hot 100 singles of 2001","wgCurRevisionId":898795447,"wgRevisionId":898795447,"wgArticleId":18576563,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["2001 record charts","Billboard charts"],"wgBreakFrames":!1,"wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgMonthNamesShort":["","Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"],"wgRelevantPageName":\n"Billboard_Year-End_Hot_100_singles_of_2001","wgRelevantArticleId":18576563,"wgRequestId":"XU8W0wpAAEIAAERe8kwAAACM","wgCSPNonce":!1,"wgIsProbablyEditable":!0,"wgRelevantPageIsProbablyEditable":!0,"wgRestrictionEdit":[],"wgRestrictionMove":[],"wgMediaViewerOnClick":!0,"wgMediaViewerEnabledByDefault":!0,"wgPopupsReferencePreviews":!1,"wgPopupsConflictsWithNavPopupGadget":!1,"wgVisualEditor":{"pageLanguageCode":"en","pageLanguageDir":"ltr","pageVariantFallbacks":"en"},"wgMFDisplayWikibaseDescriptions":{"search":!0,"nearby":!0,"watchlist":!0,"tagline":!1},"wgWMESchemaEditAttemptStepOversample":!1,"wgPoweredByHHVM":!0,"wgULSCurrentAutonym":"English","wgNoticeProject":"wikipedia","wgWikibaseItemId":"Q1488620","wgCentralAuthMobileDomain":!1,"wgEditSubmitButtonLabelPublish":!0};RLSTATE={"ext.gadget.charinsert-styles":"ready","ext.globalCssJs.user.styles":"ready","ext.globalCssJs.site.styles":"ready","site.styles":"ready","noscript":"ready","user.styles":\n"ready","ext.globalCssJs.user":"ready","ext.globalCssJs.site":"ready","user":"ready","user.options":"ready","user.tokens":"loading","ext.cite.styles":"ready","mediawiki.legacy.shared":"ready","mediawiki.legacy.commonPrint":"ready","jquery.tablesorter.styles":"ready","wikibase.client.init":"ready","ext.visualEditor.desktopArticleTarget.noscript":"ready","ext.uls.interlanguage":"ready","ext.wikimediaBadges":"ready","ext.3d.styles":"ready","mediawiki.skinning.interface":"ready","skins.vector.styles":"ready"};RLPAGEMODULES=["ext.cite.ux-enhancements","site","mediawiki.page.startup","mediawiki.page.ready","jquery.tablesorter","mediawiki.searchSuggest","ext.gadget.teahouse","ext.gadget.ReferenceTooltips","ext.gadget.watchlist-notice","ext.gadget.DRN-wizard","ext.gadget.charinsert","ext.gadget.refToolbar","ext.gadget.extra-toolbar-buttons","ext.gadget.switcher","ext.centralauth.centralautologin","ext.popups","ext.visualEditor.desktopArticleTarget.init","ext.visualEditor.targetLoader",\n"ext.eventLogging","ext.wikimediaEvents","ext.navigationTiming","ext.uls.compactlinks","ext.uls.interface","ext.cx.eventlogging.campaigns","ext.quicksurveys.init","ext.centralNotice.geoIP","ext.centralNotice.startUp","skins.vector.js"];</script>\n<script>(RLQ=window.RLQ||[]).push(function(){mw.loader.implement("user.tokens@0tffind",function($,jQuery,require,module){/*@nomin*/mw.user.tokens.set({"editToken":"+\\\\","patrolToken":"+\\\\","watchToken":"+\\\\","csrfToken":"+\\\\"});\n});});</script>\n<link rel="stylesheet" href="/w/load.php?lang=en&amp;modules=ext.3d.styles%7Cext.cite.styles%7Cext.uls.interlanguage%7Cext.visualEditor.desktopArticleTarget.noscript%7Cext.wikimediaBadges%7Cjquery.tablesorter.styles%7Cmediawiki.legacy.commonPrint%2Cshared%7Cmediawiki.skinning.interface%7Cskins.vector.styles%7Cwikibase.client.init&amp;only=styles&amp;skin=vector"/>\n<script asy ...
#  '2002': '<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>Billboard Year-End Hot 100 singles of 2002 - Wikipedia</title>\n<script>document.documentElement.className=document.documentElement.className.replace(/(^|\\s)client-nojs(\\s|$)/,"$1client-js$2");RLCONF={"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"Billboard_Year-End_Hot_100_singles_of_2002","wgTitle":"Billboard Year-End Hot 100 singles of 2002","wgCurRevisionId":909589201,"wgRevisionId":909589201,"wgArticleId":18159062,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["2002 record charts","Billboard charts"],"wgBreakFrames":!1,"wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgMonthNamesShort":["","Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"],"wgRelevantPageName":\n"Billboard_Year-End_Hot_100_singles_of_2002","wgRelevantArticleId":18159062,"wgRequestId":"XU8YfwpAICAAAAYGUXQAAADI","wgCSPNonce":!1,"wgIsProbablyEditable":!0,"wgRelevantPageIsProbablyEditable":!0,"wgRestrictionEdit":[],"wgRestrictionMove":[],"wgMediaViewerOnClick":!0,"wgMediaViewerEnabledByDefault":!0,"wgPopupsReferencePreviews":!1,"wgPopupsConflictsWithNavPopupGadget":!1,"wgVisualEditor":{"pageLanguageCode":"en","pageLanguageDir":"ltr","pageVariantFallbacks":"en"},"wgMFDisplayWikibaseDescriptions":{"search":!0,"nearby":!0,"watchlist":!0,"tagline":!1},"wgWMESchemaEditAttemptStepOversample":!1,"wgPoweredByHHVM":!0,"wgULSCurrentAutonym":"English","wgNoticeProject":"wikipedia","wgWikibaseItemId":"Q1488661","wgCentralAuthMobileDomain":!1,"wgEditSubmitButtonLabelPublish":!0};RLSTATE={"ext.gadget.charinsert-styles":"ready","ext.globalCssJs.user.styles":"ready","ext.globalCssJs.site.styles":"ready","site.styles":"ready","noscript":"ready","user.styles":\n"ready","ext.globalCssJs.user":"ready","ext.globalCssJs.site":"ready","user":"ready","user.options":"ready","user.tokens":"loading","ext.cite.styles":"ready","mediawiki.legacy.shared":"ready","mediawiki.legacy.commonPrint":"ready","jquery.tablesorter.styles":"ready","wikibase.client.init":"ready","ext.visualEditor.desktopArticleTarget.noscript":"ready","ext.uls.interlanguage":"ready","ext.wikimediaBadges":"ready","ext.3d.styles":"ready","mediawiki.skinning.interface":"ready","skins.vector.styles":"ready"};RLPAGEMODULES=["ext.cite.ux-enhancements","site","mediawiki.page.startup","mediawiki.page.ready","jquery.tablesorter","mediawiki.searchSuggest","ext.gadget.teahouse","ext.gadget.ReferenceTooltips","ext.gadget.watchlist-notice","ext.gadget.DRN-wizard","ext.gadget.charinsert","ext.gadget.refToolbar","ext.gadget.extra-toolbar-buttons","ext.gadget.switcher","ext.centralauth.centralautologin","mmv.head","mmv.bootstrap.autostart","ext.popups","ext.visualEditor.desktopArticleTarget.init",\n"ext.visualEditor.targetLoader","ext.eventLogging","ext.wikimediaEvents","ext.navigationTiming","ext.uls.compactlinks","ext.uls.interface","ext.cx.eventlogging.campaigns","ext.quicksurveys.init","ext.centralNotice.geoIP","ext.centralNotice.startUp","skins.vector.js"];</script>\n<script>(RLQ=window.RLQ||[]).push(function(){mw.loader.implement("user.tokens@0tffind",function($,jQuery,require,module){/*@nomin*/mw.user.tokens.set({"editToken":"+\\\\","patrolToken":"+\\\\","watchToken":"+\\\\","csrfToken":"+\\\\"});\n});});</script>\n<link rel="stylesheet" href="/w/load.php?lang=en&amp;modules=ext.3d.styles%7Cext.cite.styles%7Cext.uls.interlanguage%7Cext.visualEditor.desktopArticleTarget.noscript%7Cext.wikimediaBadges%7Cjquery.tablesorter.styles%7Cmediawiki.legacy.commonPrint%2Cshared%7Cmediawiki.skinning.interface%7Cskins.vector.styles%7Cwikibase.client.init&amp;only=s ...
# ...
#  '2012': '<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>Billboard Year-End Hot 100 singles of 2012 - Wikipedia</title>\n<script>document.documentElement.className=document.documentElement.className.replace(/(^|\\s)client-nojs(\\s|$)/,"$1client-js$2");RLCONF={"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"Billboard_Year-End_Hot_100_singles_of_2012","wgTitle":"Billboard Year-End Hot 100 singles of 2012","wgCurRevisionId":898797667,"wgRevisionId":898797667,"wgArticleId":37865343,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Articles lacking reliable references from December 2013","All articles lacking reliable references","2012 record charts","Billboard charts"],"wgBreakFrames":!1,"wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgMonthNamesShort":["","Jan","Feb"\n,"Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"],"wgRelevantPageName":"Billboard_Year-End_Hot_100_singles_of_2012","wgRelevantArticleId":37865343,"wgRequestId":"XU8j4QpAMF0AALLVvdkAAABH","wgCSPNonce":!1,"wgIsProbablyEditable":!0,"wgRelevantPageIsProbablyEditable":!0,"wgRestrictionEdit":[],"wgRestrictionMove":[],"wgMediaViewerOnClick":!0,"wgMediaViewerEnabledByDefault":!0,"wgPopupsReferencePreviews":!1,"wgPopupsConflictsWithNavPopupGadget":!1,"wgVisualEditor":{"pageLanguageCode":"en","pageLanguageDir":"ltr","pageVariantFallbacks":"en"},"wgMFDisplayWikibaseDescriptions":{"search":!0,"nearby":!0,"watchlist":!0,"tagline":!1},"wgWMESchemaEditAttemptStepOversample":!1,"wgPoweredByHHVM":!0,"wgULSCurrentAutonym":"English","wgNoticeProject":"wikipedia","wgWikibaseItemId":"Q975332","wgCentralAuthMobileDomain":!1,"wgEditSubmitButtonLabelPublish":!0};RLSTATE={"ext.gadget.charinsert-styles":"ready","ext.globalCssJs.user.styles":"ready",\n"ext.globalCssJs.site.styles":"ready","site.styles":"ready","noscript":"ready","user.styles":"ready","ext.globalCssJs.user":"ready","ext.globalCssJs.site":"ready","user":"ready","user.options":"ready","user.tokens":"loading","ext.cite.styles":"ready","mediawiki.legacy.shared":"ready","mediawiki.legacy.commonPrint":"ready","jquery.tablesorter.styles":"ready","wikibase.client.init":"ready","ext.visualEditor.desktopArticleTarget.noscript":"ready","ext.uls.interlanguage":"ready","ext.wikimediaBadges":"ready","ext.3d.styles":"ready","mediawiki.skinning.interface":"ready","skins.vector.styles":"ready"};RLPAGEMODULES=["ext.cite.ux-enhancements","site","mediawiki.page.startup","mediawiki.page.ready","jquery.tablesorter","mediawiki.searchSuggest","ext.gadget.teahouse","ext.gadget.ReferenceTooltips","ext.gadget.watchlist-notice","ext.gadget.DRN-wizard","ext.gadget.charinsert","ext.gadget.refToolbar","ext.gadget.extra-toolbar-buttons","ext.gadget.switcher","ext.centralauth.centralautologin",\n"mmv.head","mmv.bootstrap.autostart","ext.popups","ext.visualEditor.desktopArticleTarget.init","ext.visualEditor.targetLoader","ext.eventLogging","ext.wikimediaEvents","ext.navigationTiming","ext.uls.compactlinks","ext.uls.interface","ext.cx.eventlogging.campaigns","ext.quicksurveys.init","ext.centralNotice.geoIP","ext.centralNotice.startUp","skins.vector.js"];</script>\n<script>(RLQ=window.RLQ||[]).push(function(){mw.loader.implement("user.tokens@0tffind",function($,jQuery,require,module){/*@nomin*/mw.user.tokens.set({"editToken":"+\\\\","patrolToken":"+\\\\","watchToken":"+\\\\","csrfToken":"+\\\\"});\n});});</script>\n<link rel="stylesheet" href="/w/load.php?lang=en&amp;modules=ext.3d.styles%7Cext.cite.styles%7Cext.uls.interlanguage%7Cext.visualEditor.desktopArticleTarget.noscript%7Cext.wikimediaBadges%7Cjquery.tablesorter.styles%7Cmediawiki.legacy.commonP ...
#  '2013': '<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>Billboard Year-End Hot 100 singles of 2013 - Wikipedia</title>\n<script>document.documentElement.className=document.documentElement.className.replace(/(^|\\s)client-nojs(\\s|$)/,"$1client-js$2");RLCONF={"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"Billboard_Year-End_Hot_100_singles_of_2013","wgTitle":"Billboard Year-End Hot 100 singles of 2013","wgCurRevisionId":898797813,"wgRevisionId":898797813,"wgArticleId":41356375,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Articles lacking reliable references from December 2013","All articles lacking reliable references","2013 record charts","Billboard charts"],"wgBreakFrames":!1,"wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgMonthNamesShort":["","Jan","Feb"\n,"Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"],"wgRelevantPageName":"Billboard_Year-End_Hot_100_singles_of_2013","wgRelevantArticleId":41356375,"wgRequestId":"XU8oggpAICIAAJZSdkoAAACV","wgCSPNonce":!1,"wgIsProbablyEditable":!0,"wgRelevantPageIsProbablyEditable":!0,"wgRestrictionEdit":[],"wgRestrictionMove":[],"wgMediaViewerOnClick":!0,"wgMediaViewerEnabledByDefault":!0,"wgPopupsReferencePreviews":!1,"wgPopupsConflictsWithNavPopupGadget":!1,"wgVisualEditor":{"pageLanguageCode":"en","pageLanguageDir":"ltr","pageVariantFallbacks":"en"},"wgMFDisplayWikibaseDescriptions":{"search":!0,"nearby":!0,"watchlist":!0,"tagline":!1},"wgWMESchemaEditAttemptStepOversample":!1,"wgPoweredByHHVM":!0,"wgULSCurrentAutonym":"English","wgNoticeProject":"wikipedia","wgWikibaseItemId":"Q15304660","wgCentralAuthMobileDomain":!1,"wgEditSubmitButtonLabelPublish":!0};RLSTATE={"ext.gadget.charinsert-styles":"ready","ext.globalCssJs.user.styles":"ready",\n"ext.globalCssJs.site.styles":"ready","site.styles":"ready","noscript":"ready","user.styles":"ready","ext.globalCssJs.user":"ready","ext.globalCssJs.site":"ready","user":"ready","user.options":"ready","user.tokens":"loading","ext.cite.styles":"ready","mediawiki.legacy.shared":"ready","mediawiki.legacy.commonPrint":"ready","jquery.tablesorter.styles":"ready","wikibase.client.init":"ready","ext.visualEditor.desktopArticleTarget.noscript":"ready","ext.uls.interlanguage":"ready","ext.wikimediaBadges":"ready","ext.3d.styles":"ready","mediawiki.skinning.interface":"ready","skins.vector.styles":"ready"};RLPAGEMODULES=["ext.cite.ux-enhancements","site","mediawiki.page.startup","mediawiki.page.ready","jquery.tablesorter","mediawiki.searchSuggest","ext.gadget.teahouse","ext.gadget.ReferenceTooltips","ext.gadget.watchlist-notice","ext.gadget.DRN-wizard","ext.gadget.charinsert","ext.gadget.refToolbar","ext.gadget.extra-toolbar-buttons","ext.gadget.switcher","ext.centralauth.centralautologin",\n"mmv.head","mmv.bootstrap.autostart","ext.popups","ext.visualEditor.desktopArticleTarget.init","ext.visualEditor.targetLoader","ext.eventLogging","ext.wikimediaEvents","ext.navigationTiming","ext.uls.compactlinks","ext.uls.interface","ext.cx.eventlogging.campaigns","ext.quicksurveys.init","ext.centralNotice.geoIP","ext.centralNotice.startUp","skins.vector.js"];</script>\n<script>(RLQ=window.RLQ||[]).push(function(){mw.loader.implement("user.tokens@0tffind",function($,jQuery,require,module){/*@nomin*/mw.user.tokens.set({"editToken":"+\\\\","patrolToken":"+\\\\","watchToken":"+\\\\","csrfToken":"+\\\\"});\n});});</script>\n<link rel="stylesheet" href="/w/load.php?lang=en&amp;modules=ext.3d.styles%7Cext.cite.styles%7Cext.uls.interlanguage%7Cext.visualEditor.desktopArticleTarget.noscript%7Cext.wikimediaBadges%7Cjquery.tablesorter.styles%7Cmediawiki.legacy.commo ...
#  '2014': '<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>Billboard Year-End Hot 100 singles of 2014 - Wikipedia</title>\n<script>document.documentElement.className=document.documentElement.className.replace(/(^|\\s)client-nojs(\\s|$)/,"$1client-js$2");RLCONF={"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"Billboard_Year-End_Hot_100_singles_of_2014","wgTitle":"Billboard Year-End Hot 100 singles of 2014","wgCurRevisionId":898797915,"wgRevisionId":898797915,"wgArticleId":44655089,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["2014 record charts","Billboard charts"],"wgBreakFrames":!1,"wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgMonthNamesShort":["","Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"],"wgRelevantPageName":\n"Billboard_Year-End_Hot_100_singles_of_2014","wgRelevantArticleId":44655089,"wgRequestId":"XU8rxgpAIC8AAGzadoMAAACT","wgCSPNonce":!1,"wgIsProbablyEditable":!0,"wgRelevantPageIsProbablyEditable":!0,"wgRestrictionEdit":[],"wgRestrictionMove":[],"wgMediaViewerOnClick":!0,"wgMediaViewerEnabledByDefault":!0,"wgPopupsReferencePreviews":!1,"wgPopupsConflictsWithNavPopupGadget":!1,"wgVisualEditor":{"pageLanguageCode":"en","pageLanguageDir":"ltr","pageVariantFallbacks":"en"},"wgMFDisplayWikibaseDescriptions":{"search":!0,"nearby":!0,"watchlist":!0,"tagline":!1},"wgWMESchemaEditAttemptStepOversample":!1,"wgPoweredByHHVM":!0,"wgULSCurrentAutonym":"English","wgNoticeProject":"wikipedia","wgWikibaseItemId":"Q18614607","wgCentralAuthMobileDomain":!1,"wgEditSubmitButtonLabelPublish":!0};RLSTATE={"ext.gadget.charinsert-styles":"ready","ext.globalCssJs.user.styles":"ready","ext.globalCssJs.site.styles":"ready","site.styles":"ready","noscript":"ready","user.styles":\n"ready","ext.globalCssJs.user":"ready","ext.globalCssJs.site":"ready","user":"ready","user.options":"ready","user.tokens":"loading","ext.cite.styles":"ready","mediawiki.legacy.shared":"ready","mediawiki.legacy.commonPrint":"ready","jquery.tablesorter.styles":"ready","wikibase.client.init":"ready","ext.visualEditor.desktopArticleTarget.noscript":"ready","ext.uls.interlanguage":"ready","ext.wikimediaBadges":"ready","ext.3d.styles":"ready","mediawiki.skinning.interface":"ready","skins.vector.styles":"ready"};RLPAGEMODULES=["ext.cite.ux-enhancements","site","mediawiki.page.startup","mediawiki.page.ready","jquery.tablesorter","mediawiki.searchSuggest","ext.gadget.teahouse","ext.gadget.ReferenceTooltips","ext.gadget.watchlist-notice","ext.gadget.DRN-wizard","ext.gadget.charinsert","ext.gadget.refToolbar","ext.gadget.extra-toolbar-buttons","ext.gadget.switcher","ext.centralauth.centralautologin","mmv.head","mmv.bootstrap.autostart","ext.popups","ext.visualEditor.desktopArticleTarget.init",\n"ext.visualEditor.targetLoader","ext.eventLogging","ext.wikimediaEvents","ext.navigationTiming","ext.uls.compactlinks","ext.uls.interface","ext.cx.eventlogging.campaigns","ext.quicksurveys.init","ext.centralNotice.geoIP","ext.centralNotice.startUp","skins.vector.js"];</script>\n<script>(RLQ=window.RLQ||[]).push(function(){mw.loader.implement("user.tokens@0tffind",function($,jQuery,require,module){/*@nomin*/mw.user.tokens.set({"editToken":"+\\\\","patrolToken":"+\\\\","watchToken":"+\\\\","csrfToken":"+\\\\"});\n});});</script>\n<link rel="stylesheet" href="/w/load.php?lang=en&amp;modules=ext.3d.styles%7Cext.cite.styles%7Cext.uls.interlanguage%7Cext.visualEditor.desktopArticleTarget.noscript%7Cext.wikimediaBadges%7Cjquery.tablesorter.styles%7Cmediawiki.legacy.commonPrint%2Cshared%7Cmediawiki.skinning.interface%7Cskins.vector.styles%7Cwikibase.client.init&amp;only= ...

# %% [markdown]
# ## Q1. Scraping Wikipedia for Billboard Top 100.

# %% [markdown]
# In this question you will scrape Wikipedia for the Billboard's top 100 singles.

# %% [markdown]
# ### Scraping Wikipedia for Billboard singles

# %% [markdown]
# We'll be using  [BeautifulSoup](http://www.crummy.com/software/BeautifulSoup/), and suggest that you use Python's built in `requests` library to fetch the web page.

# %% [markdown]
# #### 1.1 Parsing the Billboard Wikipedia page for 1970

# %% [markdown]
# Obtain the web page at http://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_1970 using a HTTP GET request. From this web page we'll extract the top 100 singles and their rankings. Create a list of dictionaries, 100 of them to be precise, with entries like
#
# `{'url': '/wiki/Sugarloaf_(band)', 'ranking': 30, 'band_singer': 'Sugarloaf', 'title': 'Green-Eyed Lady'}`.
#
# If you look at that web page, you'll see a link for every song, from which you can get the `url` of the singer or band. We will use these links later to scrape information about the singer or band. From the listing we can also get the band or singer name `band_singer`, and `title` of the song.
#
# *HINT: look for a table with class `wikitable`.*

# %% [markdown]
# You should get something similar to this (where songs is the aforementioned list):
#
# ```
# songs[2:4]
# ```
#
# ```
# [{'band_singer': 'The Guess Who',
#   'ranking': 3,
#   'title': '"American Woman"',
#   'url': '/wiki/The_Guess_Who'},
#  {'band_singer': 'B.J. Thomas',
#   'ranking': 4,
#   'title': '"Raindrops Keep Fallin\' on My Head"',
#   'url': '/wiki/B.J._Thomas'}]
# ```

# %% [markdown]
# #### 1.2 Generalize the previous: scrape Wikipedia from 1992 to 2014

# %% [markdown]
# By visiting the urls similar to the ones for 1970, we can obtain the billboard top 100 for the years 1992 to 2014. (We choose these later years rather than 1970 as you might find music from this era more interesting.) Download these using Python's `requests` module and store the text from those requests in a dictionary called `yearstext`. This dictionary ought to have as its keys the years (as integers from 1992 to 2014), and as values corresponding to these keys the text of the page being fetched.
#
# You ought to sleep a second (look up `time.sleep` in Python) at the very least in-between fetching each web page: you do not want Wikipedia to think you are a marauding bot attempting to mount a denial-of-service attack.

# %% [markdown]
# *HINT: you might find `range` and string-interpolation useful to construct the URLs *.

# %% [markdown]
# #### 1.3 Parse and Clean data

# %% [markdown]
# Remember the code you wrote to get data from 1970 which produces a list of dictionaries, one corresponding to each single.  Now write a function `parse_year(the_year, yeartext_dict)` which takes the year, prints it out, gets the text for the year from the just created `yearstext` dictionary, and return a list of dictionaries for that year, with one dictionary for each single. Store this list in the variable `yearinfo`.
#
# The dictionaries **must** be of this form:
#
# ```
# {'band_singer': ['Brandy', 'Monica'],
#   'ranking': 2,
#   'song': ['The Boy Is Mine'],
#   'songurl': ['/wiki/The_Boy_Is_Mine_(song)'],
#   'titletext': '" The Boy Is Mine "',
#   'url': ['/wiki/Brandy_Norwood', '/wiki/Monica_(entertainer)']}
# ```

# %% [markdown]
# The spec of this function is provided below:

# %%
"""
Function
--------
parse_year

Inputs
------
the_year: the year you want the singles for
yeartext_dict: a dictionary with keys as integer years and values the downloaded web pages 
    from wikipedia for that year.
   
Returns
-------

a list of dictionaries, each of which corresponds to a single and has the
following data:

Eg:

{'band_singer': ['Brandy', 'Monica'],
  'ranking': 2,
  'song': ['The Boy Is Mine'],
  'songurl': ['/wiki/The_Boy_Is_Mine_(song)'],
  'titletext': '" The Boy Is Mine "',
  'url': ['/wiki/Brandy_Norwood', '/wiki/Monica_(entertainer)']}
  
A dictionary with the following data:
    band_singer: a list of bands/singers who made this single
    song: a list of the titles of songs on this single
    songurl: a list of the same size as song which has urls for the songs on the single 
        (see point 3 above)
    ranking: ranking of the single
    titletext: the contents of the table cell
    band_singer: a list of bands or singers on this single
    url: a list of wikipedia singer/band urls on this single: only put in the part 
        of the url from /wiki onwards
    

Notes
-----
See description and example above.
"""
# #parse and clean data
# def parse_year(the_year, yeartext_dict):
#     soup = BeautifulSoup(yeartext_dict, 'html.parser')
#     pageTables = soup.find_all('table', 'wikitable')
    
#     tableRows = [row for row in pageTables[0].find_all('tr')]
#     # print(len(tableRows))
#     # tableRows

#     #we have to get td values of each row
#     def tdValues(inp):
#         return [each for each in inp.find_all('td')]

#     #iterating from 1st index because in zeroth index only yhe column headings will be present
#     tdVal = [tdValues(each) for each in tableRows[1:]]
# #     print(len(tdVal))
#     print(tdVal)
#     #converting into given dictionary format in homework description
#     topBillboard = [{'band_singer':each[1].a.string, 'title':each[0].string, 'url':each[1].a['href']} for each in tdVal]
#     return topBillboard

# #lets get the data as above for year 1999
# print(parse_year(1998,yearsData['1998']))

def parse_year(the_year, yeartext_dict):

    soup = BeautifulSoup(yearsData[str(the_year)], 'html.parser')
    tableData = soup.find_all('table', 'wikitable')
    rows = [row for row in tableData[0].find_all('tr')]
#     print(rows)
    yearinfo = [singleYearData(row) for row in rows[1:]]
    return yearinfo



def singleYearData(row):
    rowEle = [each for each in row.children]
    rowEle = list(filter(lambda x: x != '\n', rowEle))
    ranking = rowEle[0].string
    ranking = ranking.replace("\n","")
#     print(ranking)

    rowSingers = rowEle[2].find_all('a')
#     print(rowSingers)
    rowSinger = [each.string for each in rowSingers]
#     print(rowSingers)
    singersUrl = [each['href'] for each in rowSingers]
#     print(singersUrl)
    rowSongs = rowEle[1].find_all('a')
    songsUrl = [each['href'] for each in rowSongs]
    if songsUrl == []:
        songsUrl = [None]
    songs = [each.string for each in rowSongs]
    title = '/'.join(str(each) for each in songs)

    songInfo = {'band_singer': rowSinger, 'ranking': ranking, 'song': songs,
                   'songurl':songsUrl, 'titletext':title, 'url': singersUrl}
    return songInfo
# print(parse_year(2014,yearsData['2014']))
# print(yearinfo)
yearInfo = {}
for i in range(1992,2015):
    yearInfo[str(i)] = parse_year(i,yearsData[str(i)])
yearInfo
# Out:
# {'1992': [{'band_singer': ['Boyz II Men'],
#    'ranking': '1',
#    'song': ['End of the Road'],
#    'songurl': ['/wiki/End_of_the_Road'],
#    'titletext': 'End of the Road',
#    'url': ['/wiki/Boyz_II_Men']},
#   {'band_singer': ['Sir Mix-a-Lot'],
#    'ranking': '2',
#    'song': ['Baby Got Back'],
#    'songurl': ['/wiki/Baby_Got_Back'],
#    'titletext': 'Baby Got Back',
#    'url': ['/wiki/Sir_Mix-a-Lot']},
#   {'band_singer': ['Kris Kross'],
#    'ranking': '3',
#    'song': ['Jump'],
#    'songurl': ['/wiki/Jump_(Kris_Kross_song)'],
#    'titletext': 'Jump',
#    'url': ['/wiki/Kris_Kross']},
#   {'band_singer': ['Vanessa Williams'],
#    'ranking': '4',
#    'song': ['Save the Best for Last'],
#    'songurl': ['/wiki/Save_the_Best_for_Last'],
#    'titletext': 'Save the Best for Last',
#    'url': ['/wiki/Vanessa_L._Williams']},
#   {'band_singer': ['TLC'],
#    'ranking': '5',
#    'song': ['Baby-Baby-Baby'],
#    'songurl': ['/wiki/Baby-Baby-Baby'],
#    'titletext': 'Baby-Baby-Baby',
#    'url': ['/wiki/TLC_(band)']},
#   {'band_singer': ['Eric Clapton'],
#    'ranking': '6',
#    'song': ['Tears in Heaven'],
#    'songurl': ['/wiki/Tears_in_Heaven'],
#    'titletext': 'Tears in Heaven',
#    'url': ['/wiki/Eric_Clapton']},
#   {'band_singer': ['En Vogue'],
#    'ranking': '7',
#    'song': ["My Lovin' (You're Never Gonna Get It)"],
#    'songurl': ['/wiki/My_Lovin%27_(You%27re_Never_Gonna_Get_It)'],
#    'titletext': "My Lovin' (You're Never Gonna Get It)",
#    'url': ['/wiki/En_Vogue']},
#   {'band_singer': ['Red Hot Chili Peppers'],
#    'ranking': '8',
#    'song': ['Under the Bridge'],
#    'songurl': ['/wiki/Under_the_Bridge'],
#    'titletext': 'Under the Bridge',
#    'url': ['/wiki/Red_Hot_Chili_Peppers']},
#   {'band_singer': ['Color Me Badd'],
#    'ranking': '9',
#    'song': ['All 4 Love'],
#    'songurl': ['/wiki/All_4_Love'],
#    'titletext': 'All 4 Love',
#    'url': ['/wiki/Color_Me_Badd']},
#   {'band_singer': ['Jon Secada'],
#    'ranking': '10',
#    'song': ['Just Another Day'],
#    'songurl': ['/wiki/Just_Another_Day_(Jon_Secada_song)'],
#    'titletext': 'Just Another Day',
#    'url': ['/wiki/Jon_Secada']},
#   {'band_singer': ['Shanice'],
#    'ranking': '11',
#    'song': ['I Love Your Smile'],
#    'songurl': ['/wiki/I_Love_Your_Smile'],
#    'titletext': 'I Love Your Smile',
#    'url': ['/wiki/Shanice']},
#   {'band_singer': ['Mr. Big'],
#    'ranking': '12',
#    'song': ['To Be with You'],
#    'songurl': ['/wiki/To_Be_with_You'],
#    'titletext': 'To Be with You',
#    'url': ['/wiki/Mr._Big_(band)']},
#   {'band_singer': ['Right Said Fred'],
#    'ranking': '13',
#    'song': ["I'm Too Sexy"],
#    'songurl': ['/wiki/I%27m_Too_Sexy'],
#    'titletext': "I'm Too Sexy",
#    'url': ['/wiki/Right_Said_Fred']},
#   {'band_singer': ['Michael Jackson'],
#    'ranking': '14',
#    'song': ['Black or White'],
#    'songurl': ['/wiki/Black_or_White'],
#    'titletext': 'Black or White',
#    'url': ['/wiki/Michael_Jackson']},
#   {'band_singer': ['Billy Ray Cyrus'],
#    'ranking': '15',
#    'song': ['Achy Breaky Heart'],
#    'songurl': ['/wiki/Achy_Breaky_Heart'],
#    'titletext': 'Achy Breaky Heart',
#    'url': ['/wiki/Billy_Ray_Cyrus']},
#   {'band_singer': ['Mariah Carey'],
#    'ranking': '16',
#    'song': ["I'll Be There"],
#    'songurl': ['/wiki/I%27ll_Be_There_(The_Jackson_5_song)#Mariah_Carey_version'],
#    'titletext': "I'll Be There",
#    'url': ['/wiki/Mariah_Carey']},
#   {'band_singer': ["Guns N' Roses"],
#    'ranking': '17',
#    'song': ['November Rain'],
#    'songurl': ['/wiki/November_Rain'],
#    'titletext': 'November Rain',
#    'url': ['/wiki/Guns_N%27_Roses']},
#   {'band_singer': ['Tom Cochrane'],
#    'ranking': '18',
#    'song': ['Life Is a Highway'],
#    'songurl': ['/wiki/Life_Is_a_Highway'],
#    'titletext': 'Life Is a Highway',
#    'url': ['/wiki/Tom_Cochrane']},
#   {'band_singer': ['Michael Jackson'],
#    'ranking': '19',
#    'song': ['Remember the Time'],
#    'songurl': ['/wiki/Remember_the_Time'],
#    'titletext': 'Remember the Time',
#    'url': ['/wiki/Michael_Jackson']},
#   {'band_singer': ['CeCe Peniston'],
#    'ranking': '20',
#    'song': ['Finally'],
#    'songurl': ['/wiki/Finally_(CeCe_Peniston_song)'],
#    'titletext': 'Finally',
#    'url': ['/wiki/CeCe_Peniston']},
#   {'band_singer': ['Madonna'],
#    'ranking': '21',
#    'song': ['This Used to Be My Playground'],
#    'songurl': ['/wiki/This_Used_to_Be_My_Playground'],
#    'titletext': 'This Used to Be My Playground',
#    'url': ['/wiki/Madonna_(entertainer)']},
#   {'band_singer': ['Patty Smyth', 'Don Henley'],
#    'ranking': '22',
#    'song': ["Sometimes Love Just Ain't Enough"],
#    'songurl': ['/wiki/Sometimes_Love_Just_Ain%27t_Enough'],
#    'titletext': "Sometimes Love Just Ain't Enough",
#    'url': ['/wiki/Patty_Smyth', '/wiki/Don_Henley']},
#   {'band_singer': ['Mariah Carey'],
#    'ranking': '23',
#    'song': ["Can't Let Go"],
#    'songurl': ['/wiki/Can%27t_Let_Go_(Mariah_Carey_song)'],
#    'titletext': "Can't Let Go",
#    'url': ['/wiki/Mariah_Carey']},
#   {'band_singer': ['House of Pain'],
#    'ranking': '24',
#    'song': ['Jump Around'],
#    'songurl': ['/wiki/Jump_Around'],
#    'titletext': 'Jump Around',
#    'url': ['/wiki/House_of_Pain']},
#   {'band_singer': ['Prince', 'The New Power Generation'],
#    'ranking': '25',
#    'song': ['Diamonds and Pearls'],
#    'songurl': ['/wiki/Diamonds_and_Pearls_(song)'],
#    'titletext': 'Diamonds and Pearls',
#    'url': ['/wiki/Prince_(entertainer)', '/wiki/The_New_Power_Generation']},
#   {'band_singer': ['George Michael', 'Elton John'],
#    'ranking': '26',
#    'song': ["Don't Let the Sun Go Down on Me"],
#    'songurl': ['/wiki/Don%27t_Let_the_Sun_Go_Down_on_Me'],
#    'titletext': "Don't Let the Sun Go Down on Me",
#    'url': ['/wiki/George_Michael', '/wiki/Elton_John']},
#   {'band_singer': ['Atlantic Starr'],
#    'ranking': '27',
#    'song': ['Masterpiece'],
#    'songurl': ['/wiki/Masterpiece_(Atlantic_Starr_song)'],
#    'titletext': 'Masterpiece',
#    'url': ['/wiki/Atlantic_Starr']},
#   {'band_singer': ['Celine Dion'],
#    'ranking': '28',
#    'song': ['If You Asked Me To'],
#    'songurl': ['/wiki/If_You_Asked_Me_To'],
#    'titletext': 'If You Asked Me To',
#    'url': ['/wiki/Celine_Dion']},
#   {'band_singer': ['En Vogue'],
#    'ranking': '29',
#    'song': ['Giving Him Something He Can Feel'],
#    'songurl': ['/wiki/Something_He_Can_Feel'],
#    'titletext': 'Giving Him Something He Can Feel',
#    'url': ['/wiki/En_Vogue']},
#   {'band_singer': ['Joe Public'],
#    'ranking': '30',
#    'song': ['Live and Learn'],
#    'songurl': ['/wiki/Live_and_Learn_(Joe_Public_song)'],
#    'titletext': 'Live and Learn',
#    'url': ['/wiki/Joe_Public_(band)']},
#   {'band_singer': ['Jodeci'],
#    'ranking': '31',
#    'song': ['Come and Talk to Me'],
#    'songurl': ['/wiki/Come_and_Talk_to_Me'],
#    'titletext': 'Come and Talk to Me',
#    'url': ['/wiki/Jodeci']},
#   {'band_singer': ['Nirvana'],
#    'ranking': '32',
#    'song': ['Smells Like Teen Spirit'],
#    'songurl': ['/wiki/Smells_Like_Teen_Spirit'],
#    'titletext': 'Smells Like Teen Spirit',
#    'url': ['/wiki/Nirvana_(band)']},
#   {'band_singer': ['Bobby Brown'],
#    'ranking': '33',
#    'song': ["Humpin' Around"],
#    'songurl': ['/wiki/Humpin%27_Around'],
#    'titletext': "Humpin' Around",
#    'url': ['/wiki/Bobby_Brown']},
#   {'band_singer': ['Sophie B. Hawkins'],
#    'ranking': '34',
#    'song': ['Damn I Wish I Was Your Lover'],
#    'songurl': ['/wiki/Damn_I_Wish_I_Was_Your_Lover'],
#    'titletext': 'Damn I Wish I Was Your Lover',
#    'url': ['/wiki/Sophie_B._Hawkins']},
#   {'band_singer': ['Tevin Campbell'],
#    'ranking': '35',
#    'song': ['Tell Me What You Want Me to Do'],
#    'songurl': ['/wiki/Tell_Me_What_You_Want_Me_to_Do'],
#    'titletext': 'Tell Me What You Want Me to Do',
#    'url': ['/wiki/Tevin_Campbell']},
#   {'band_singer': ['TLC'],
#    'ranking': '36',
#    'song': ["Ain't 2 Proud 2 Beg"],
#    'songurl': ['/wiki/Ain%27t_2_Proud_2_Beg'],
#    'titletext': "Ain't 2 Proud 2 Beg",
#    'url': ['/wiki/TLC_(band)']},
#   {'band_singer': ['Boyz II Men'],
#    'ranking': '37',
#    'song': ["It's So Hard to Say Goodbye to Yesterday"],
#    'songurl': ['/wiki/It%27s_So_Hard_to_Say_Goodbye_to_Yesterday'],
#    'titletext': "It's So Hard to Say Goodbye to Yesterday",
#    'url': ['/wiki/Boyz_II_Men']},
#   {'band_singer': ['Technotronic', 'Ya Kid K'],
#    'ranking': '38',
#    'song': ['Move This'],
#    'songurl': ['/wiki/Move_This'],
#    'titletext': 'Move This',
#    'url': ['/wiki/Technotronic', '/wiki/Ya_Kid_K']},
#   {'band_singer': ['Queen'],
#    'ranking': '39',
#    'song': ['Bohemian Rhapsody'],
#    'songurl': ['/wiki/Bohemian_Rhapsody'],
#    'titletext': 'Bohemian Rhapsody',
#    'url': ['/wiki/Queen_(band)']},
#   {'band_singer': ['Arrested Development'],
#    'ranking': '40',
#    'song': ['Tennessee'],
#    'songurl': ['/wiki/Tennessee_(Arrested_Development_song)'],
#    'titletext': 'Tennessee',
#    'url': ['/wiki/Arrested_Development_(group)']},
#   {'band_singer': ['Luther Vandross', 'Janet Jackson'],
#    'ranking': '41',
#    'song': ['The Best Things in Life Are Free'],
#    'songurl': ['/wiki/The_Best_Things_in_Life_Are_Free'],
#    'titletext': 'The Best Things in Life Are Free',
#    'url': ['/wiki/Luther_Vandross', '/wiki/Janet_Jackson']},
#   {'band_singer': ['Mariah Carey'],
#    'ranking': '42',
#    'song': ['Make It Happen'],
#    'songurl': ['/wiki/Make_It_Happen_(Mariah_Carey_song)'],
#    'titletext': 'Make It Happen',
#    'url': ['/wiki/Mariah_Carey']},
#   {'band_singer': ['Elton John'],
#    'ranking': '43',
#    'song': ['The One'],
#    'songurl': ['/wiki/The_One_(Elton_John_song)'],
#    'titletext': 'The One',
#    'url': ['/wiki/Elton_John']},
#   {'band_singer': ['P.M. Dawn'],
#    'ranking': '44',
#    'song': ['Set Adrift on Memory Bliss'],
#    'songurl': ['/wiki/Set_Adrift_on_Memory_Bliss'],
#    'titletext': 'Set Adrift on Memory Bliss',
#    'url': ['/wiki/P.M._Dawn']},
#   {'band_singer': ['Shakespears Sister'],
#    'ranking': '45',
#    'song': ['Stay'],
#    'songurl': ['/wiki/Stay_(Shakespears_Sister_song)'],
#    'titletext': 'Stay',
#    'url': ['/wiki/Shakespears_Sister']},
#   {'band_singer': ['Hammer'],
#    'ranking': '46',
#    'song': ['2 Legit 2 Quit'],
#    'songurl': ['/wiki/Too_Legit_to_Quit_(song)'],
#    'titletext': '2 Legit 2 Quit',
#    'url': ['/wiki/MC_Hammer']},
#   {'band_singer': ['KWS'],
#    'ranking': '47',
#    'song': ["Please Don't Go"],
#    'songurl': ['/wiki/Please_Don%27t_Go_(KC_and_the_Sunshine_Band_song)#KWS_version'],
#    'titletext': "Please Don't Go",
#    'url': ['/wiki/KWS_(band)']},
#   {'band_singer': ['Mint Condition'],
#    'ranking': '48',
#    'song': ["Breakin' My Heart (Pretty Brown Eyes)"],
#    'songurl': ['/wiki/Breakin%27_My_Heart_(Pretty_Brown_Eyes)'],
#    'titletext': "Breakin' My Heart (Pretty Brown Eyes)",
#    'url': ['/wiki/Mint_Condition']},
#   {'band_singer': ['The Cover Girls'],
#    'ranking': '49',
#    'song': ['Wishing on a Star'],
#    'songurl': ['/wiki/Wishing_on_a_Star'],
#    'titletext': 'Wishing on a Star',
#    'url': ['/wiki/The_Cover_Girls']},
#   {'band_singer': ['Hi-Five'],
#    'ranking': '50',
#    'song': [],
#    'songurl': [None],
#    'titletext': '',
#    'url': ['/wiki/Hi-Five']},
#   {'band_singer': ['P.M. Dawn'],
#    'ranking': '51',
#    'song': ["I'd Die Without You"],
#    'songurl': ['/wiki/I%27d_Die_Without_You'],
#    'titletext': "I'd Die Without You",
#    'url': ['/wiki/P.M._Dawn']},
#   {'band_singer': ['Amy Grant'],
#    'ranking': '52',
#    'song': ['Good for Me'],
#    'songurl': ['/wiki/Good_for_Me_(song)'],
#    'titletext': 'Good for Me',
#    'url': ['/wiki/Amy_Grant']},
#   {'band_singer': ['Toad the Wet Sprocket'],
#    'ranking': '53',
#    'song': ['All I Want'],
#    'songurl': ['/wiki/All_I_Want_(Toad_the_Wet_Sprocket_song)'],
#    'titletext': 'All I Want',
#    'url': ['/wiki/Toad_the_Wet_Sprocket']},
#   {'band_singer': ['Michael Bolton'],
#    'ranking': '54',
#    'song': ['When a Man Loves a Woman'],
#    'songurl': ['/wiki/When_a_Man_Loves_a_Woman_(song)'],
#    'titletext': 'When a Man Loves a Woman',
#    'url': ['/wiki/Michael_Bolton']},
#   {'band_singer': ['Genesis'],
#    'ranking': '55',
#    'song': ["I Can't Dance"],
#    'songurl': ['/wiki/I_Can%27t_Dance'],
#    'titletext': "I Can't Dance",
#    'url': ['/wiki/Genesis_(band)']},
#   {'band_singer': ['Richard Marx'],
#    'ranking': '56',
#    'song': ['Hazard'],
#    'songurl': ['/wiki/Hazard_(song)'],
#    'titletext': 'Hazard',
#    'url': ['/wiki/Richard_Marx']},
#   {'band_singer': ['U2'],
#    'ranking': '57',
#    'song': ['Mysterious Ways'],
#    'songurl': ['/wiki/Mysterious_Ways_(song)'],
#    'titletext': 'Mysterious Ways',
#    'url': ['/wiki/U2']},
#   {'band_singer': ['George Michael'],
#    'ranking': '58',
#    'song': ['Too Funky'],
#    'songurl': ['/wiki/Too_Funky'],
#    'titletext': 'Too Funky',
#    'url': ['/wiki/George_Michael']},
#   {'band_singer': ['The Heights'],
#    'ranking': '59',
#    'song': ['How Do You Talk to an Angel'],
#    'songurl': ['/wiki/How_Do_You_Talk_to_an_Angel'],
#    'titletext': 'How Do You Talk to an Angel',
#    'url': ['/wiki/The_Heights_(American_TV_series)']},
#   {'band_singer': ['U2'],
#    'ranking': '60',
#    'song': ['One'],
#    'songurl': ['/wiki/One_(U2_song)'],
#    'titletext': 'One',
#    'url': ['/wiki/U2']},
#   {'band_singer': ['CeCe Peniston'],
#    'ranking': '61',
#    'song': ["Keep on Walkin'"],
#    'songurl': ['/wiki/Keep_on_Walkin%27_(song)'],
#    'titletext': "Keep on Walkin'",
#    'url': ['/wiki/CeCe_Peniston']},
#   {'band_singer': ['Genesis'],
#    'ranking': '62',
#    'song': ['Hold on My Heart'],
#    'songurl': ['/wiki/Hold_on_My_Heart'],
#    'titletext': 'Hold on My Heart',
#    'url': ['/wiki/Genesis_(band)']},
#   {'band_singer': ['Karyn White'],
#    'ranking': '63',
#    'song': [],
#    'songurl': [None],
#    'titletext': '',
#    'url': ['/wiki/Karyn_White']},
#   {'band_singer': ['Celine Dion', 'Peabo Bryson'],
#    'ranking': '64',
#    'song': ['Beauty and the Beast'],
#    'songurl': ['/wiki/Beauty_and_the_Beast_(Disney_song)'],
#    'titletext': 'Beauty and the Beast',
#    'url': ['/wiki/Celine_Dion', '/wiki/Peabo_Bryson']},
#   {'band_singer': ['Kris Kross'],
#    'ranking': '65',
#    'song': ['Warm It Up'],
#    'songurl': ['/wiki/Warm_It_Up'],
#    'titletext': 'Warm It Up',
#    'url': ['/wiki/Kris_Kross']},
#   {'band_singer': ['Michael Jackson'],
#    'ranking': '66',
#    'song': ['In the Closet'],
#    'songurl': ['/wiki/In_the_Closet'],
#    'titletext': 'In the Closet',
#    'url': ['/wiki/Michael_Jackson']},
#   {'band_singer': ['Arrested Development'],
#    'ranking': '67',
#    'song': ['People Everyday'],
#    'songurl': ['/wiki/People_Everyday'],
#    'titletext': 'People Everyday',
#    'url': ['/wiki/Arrested_Development_(group)']},
#   {'band_singer': ['Genesis'],
#    'ranking': '68',
#    'song': ['No Son of Mine'],
#    'songurl': ['/wiki/No_Son_of_Mine'],
#    'titletext': 'No Son of Mine',
#    'url': ['/wiki/Genesis_(band)']},
#   {'band_singer': ['Marky Mark and the Funky Bunch'],
#    'ranking': '69',
#    'song': ['Wildside'],
#    'songurl': ['/wiki/Wildside_(Marky_Mark_and_the_Funky_Bunch_song)'],
#    'titletext': 'Wildside',
#    'url': ['/wiki/Marky_Mark_and_the_Funky_Bunch']},
#   {'band_singer': ['Bryan Adams'],
#    'ranking': '70',
#    'song': ['Do I Have to Say the Words?'],
#    'songurl': ['/wiki/Do_I_Have_to_Say_the_Words%3F'],
#    'titletext': 'Do I Have to Say the Words?',
#    'url': ['/wiki/Bryan_Adams']},
#   {'band_singer': ['The Cure'],
#    'ranking': '71',
#    'song': ["Friday I'm in Love"],
#    'songurl': ['/wiki/Friday_I%27m_in_Love'],
#    'titletext': "Friday I'm in Love",
#    'url': ['/wiki/The_Cure']},
#   {'band_singer': ['Ugly Kid Joe'],
#    'ranking': '72',
#    'song': ['Everything About You'],
#    'songurl': ['/wiki/Everything_About_You_(Ugly_Kid_Joe_song)'],
#    'titletext': 'Everything About You',
#    'url': ['/wiki/Ugly_Kid_Joe']},
#   {'band_singer': ['Paula Abdul'],
#    'ranking': '73',
#    'song': ['Blowing Kisses in the Wind'],
#    'songurl': ['/wiki/Blowing_Kisses_in_the_Wind'],
#    'titletext': 'Blowing Kisses in the Wind',
#    'url': ['/wiki/Paula_Abdul']},
#   {'band_singer': ['Bryan Adams'],
#    'ranking': '74',
#    'song': ["Thought I'd Died and Gone to Heaven"],
#    'songurl': ['/wiki/Thought_I%27d_Died_and_Gone_to_Heaven'],
#    'titletext': "Thought I'd Died and Gone to Heaven",
#    'url': ['/wiki/Bryan_Adams']},
#   {'band_singer': ['Snap!'],
#    'ranking': '75',
#    'song': ['Rhythm Is a Dancer'],
#    'songurl': ['/wiki/Rhythm_Is_a_Dancer'],
#    'titletext': 'Rhythm Is a Dancer',
#    'url': ['/wiki/Snap!']},
#   {'band_singer': ['Hammer'],
#    'ranking': '76',
#    'song': ['Addams Groove'],
#    'songurl': ['/wiki/Addams_Groove'],
#    'titletext': 'Addams Groove',
#    'url': ['/wiki/MC_Hammer']},
#   {'band_singer': ['Michael Bolton'],
#    'ranking': '77',
#    'song': ['Missing You Now'],
#    'songurl': ['/wiki/Missing_You_Now'],
#    'titletext': 'Missing You Now',
#    'url': ['/wiki/Michael_Bolton']},
#   {'band_singer': ['N2Deep'],
#    'ranking': '78',
#    'song': [],
#    'songurl': [None],
#    'titletext': '',
#    'url': ['/wiki/N2Deep']},
#   {'band_singer': ['Kathy Troccoli'],
#    'ranking': '79',
#    'song': [],
#    'songurl': [None],
#    'titletext': '',
#    'url': ['/wiki/Kathy_Troccoli']},
#   {'band_singer': ['Def Leppard'],
#    'ranking': '80',
#    'song': ['Have You Ever Needed Someone So Bad'],
#    'songurl': ['/wiki/Have_You_Ever_Needed_Someone_So_Bad'],
#    'titletext': 'Have You Ever Needed Someone So Bad',
#    'url': ['/wiki/Def_Leppard']},
#   {'band_singer': ['Richard Marx'],
#    'ranking': '81',
#    'song': ['Take This Heart'],
#    'songurl': ['/wiki/Take_This_Heart'],
#    'titletext': 'Take This Heart',
#    'url': ['/wiki/Richard_Marx']},
#   {'band_singer': ['FireHouse'],
#    'ranking': '82',
#    'song': ['When I Look Into Your Eyes'],
#    'songurl': ['/wiki/When_I_Look_Into_Your_Eyes'],
#    'titletext': 'When I Look Into Your Eyes',
#    'url': ['/wiki/FireHouse_(band)']},
#   {'band_singer': ['Jade'],
#    'ranking': '83',
#    'song': ['I Wanna Love You'],
#    'songurl': ['/wiki/I_Wanna_Love_You_(Jade_song)'],
#    'titletext': 'I Wanna Love You',
#    'url': ['/wiki/Jade_(American_band)']},
#   {'band_singer': ['Boyz II Men'],
#    'ranking': '84',
#    'song': ['Uhh Ahh'],
#    'songurl': ['/wiki/Uhh_Ahh'],
#    'titletext': 'Uhh Ahh',
#    'url': ['/wiki/Boyz_II_Men']},
#   {'band_singer': ['Mary J. Blige'],
#    'ranking': '85',
#    'song': ['Real Love'],
#    'songurl': ['/wiki/Real_Love_(Mary_J._Blige_song)'],
#    'titletext': 'Real Love',
#    'url': ['/wiki/Mary_J._Blige']},
#   {'band_singer': ['The KLF'],
#    'ranking': '86',
#    'song': ['Justified and Ancient'],
#    'songurl': ['/wiki/Justified_and_Ancient'],
#    'titletext': 'Justified and Ancient',
#    'url': ['/wiki/The_KLF']},
#   {'band_singer': ['Color Me Badd'],
#    'ranking': '87',
#    'song': [],
#    'songurl': [None],
#    'titletext': '',
#    'url': ['/wiki/Color_Me_Badd']},
#   {'band_singer': ['TLC'],
#    'ranking': '88',
#    'song': ['What About Your Friends'],
#    'songurl': ['/wiki/What_About_Your_Friends'],
#    'titletext': 'What About Your Friends',
#    'url': ['/wiki/TLC_(band)']},
#   {'band_singer': ['Color Me Badd'],
#    'ranking': '89',
#    'song': [],
#    'songurl': [None],
#    'titletext': '',
#    'url': ['/wiki/Color_Me_Badd']},
#   {'band_singer': ['Charles & Eddie'],
#    'ranking': '90',
#    'song': ['Would I Lie to You?'],
#    'songurl': ['/wiki/Would_I_Lie_to_You%3F_(Charles_%26_Eddie_song)'],
#    'titletext': 'Would I Lie to You?',
#    'url': ['/wiki/Charles_%26_Eddie']},
#   {'band_singer': ['Amy Grant'],
#    'ranking': '91',
#    'song': ["That's What Love Is For"],
#    'songurl': ['/wiki/That%27s_What_Love_Is_For'],
#    'titletext': "That's What Love Is For",
#    'url': ['/wiki/Amy_Grant']},
#   {'band_singer': ['Richard Marx'],
#    'ranking': '92',
#    'song': ['Keep Coming Back'],
#    'songurl': ['/wiki/Keep_Coming_Back_(song)'],
#    'titletext': 'Keep Coming Back',
#    'url': ['/wiki/Richard_Marx']},
#   {'band_singer': ['En Vogue'],
#    'ranking': '93',
#    'song': ['Free Your Mind'],
#    'songurl': ['/wiki/Free_Your_Mind_(song)'],
#    'titletext': 'Free Your Mind',
#    'url': ['/wiki/En_Vogue']},
#   {'band_singer': ['Keith Sweat'],
#    'ranking': '94',
#    'song': ["Keep It Comin'"],
#    'songurl': ['/wiki/Keep_It_Comin%27_(song)'],
#    'titletext': "Keep It Comin'",
#    'url': ['/wiki/Keith_Sweat']},
#   {'band_singer': ['Mr. Big'],
#    'ranking': '95',
#    'song': ['Just Take My Heart'],
#    'songurl': ['/wiki/Just_Take_My_Heart_(song)'],
#    'titletext': 'Just Take My Heart',
#    'url': ['/wiki/Mr._Big_(band)']},
#   {'band_singer': ['Amy Grant'],
#    'ranking': '96',
#    'song': ['I Will Remember You'],
#    'songurl': ['/wiki/I_Will_Remember_You_(Amy_Grant_song)'],
#    'titletext': 'I Will Remember You',
#    'url': ['/wiki/Amy_Grant']},
#   {'band_singer': ['CeCe Peniston'],
#    'ranking': '97',
#    'song': ['We Got a Love Thang'],
#    'songurl': ['/wiki/We_Got_a_Love_Thang'],
#    'titletext': 'We Got a Love Thang',
#    'url': ['/wiki/CeCe_Peniston']},
#   {'band_singer': ['Def Leppard'],
#    'ranking': '98',
#    'song': ["Let's Get Rocked"],
#    'songurl': ['/wiki/Let%27s_Get_Rocked'],
#    'titletext': "Let's Get Rocked",
#    'url': ['/wiki/Def_Leppard']},
#   {'band_singer': ['Das EFX'],
#    'ranking': '99',
#    'song': ['They Want EFX'],
#    'songurl': ['/wiki/They_Want_EFX'],
#    'titletext': 'They Want EFX',
#    'url': ['/wiki/Das_EFX']},
#   {'band_singer': ['Bonnie Raitt'],
#    'ranking': '100',
#    'song': ["I Can't Make You Love Me"],
#    'songurl': ['/wiki/I_Can%27t_Make_You_Love_Me'],
#    'titletext': "I Can't Make You Love Me",
#    'url': ['/wiki/Bonnie_Raitt']}],
#  '1993': [{'band_singer': ['Whitney Houston'],
#    'ranking': '1',
#    'song': ['I Will Always Love You'],
#    'songurl': ['/wiki/I_Will_Always_Love_You#Whitney_Houston_version'],
#    'titletext': 'I Will Always Love You',
#    'url': ['/wiki/Whitney_Houston']},
#   {'band_singer': ['Tag Team'],
#    'ranking': '2',
#    'song': ['Whoomp! (There It Is)'],
#    'songurl': ['/wiki/Whoomp!_(There_It_Is)'],
#    'titletext': 'Whoomp! (There It Is)',
#    'url': ['/wiki/Tag_Team_(group)']},
#   {'band_singer': ['UB40'],
#    'ranking': '3',
#    'song': ["Can't Help Falling in Love"],
#    'songurl': ['/wiki/Can%27t_Help_Falling_in_Love'],
#    'titletext': "Can't Help Falling in Love",
#    'url': ['/wiki/UB40']},
#   {'band_singer': ['Janet Jackson'],
#    'ranking': '4',
#    'song': ["That's the Way Love Goes"],
#    'songurl': ['/wiki/That%27s_the_Way_Love_Goes_(Janet_Jackson_song)'],
#    'titletext': "That's the Way Love Goes",
#    'url': ['/wiki/Janet_Jackson']},
#   {'band_singer': ['Silk'],
#    'ranking': '5',
#    'song': ['Freak Me'],
#    'songurl': ['/wiki/Freak_Me'],
#    'titletext': 'Freak Me',
#    'url': ['/wiki/Silk_(group)']},
#   {'band_singer': ['SWV'],
#    'ranking': '6',
#    'song': ['Weak'],
#    'songurl': ['/wiki/Weak_(SWV_song)'],
#    'titletext': 'Weak',
#    'url': ['/wiki/SWV']},
#   {'band_singer': ['Shai'],
#    'ranking': '7',
#    'song': ['If I Ever Fall in Love'],
#    'songurl': ['/wiki/If_I_Ever_Fall_in_Love'],
#    'titletext': 'If I Ever Fall in Love',
#    'url': ['/wiki/Shai_(band)']},
#   {'band_singer': ['Mariah Carey'],
#    'ranking': '8',
#    'song': ['Dreamlover'],
#    'songurl': ['/wiki/Dreamlover_(song)'],
#    'titletext': 'Dreamlover',
#    'url': ['/wiki/Mariah_Carey']},
#   {'band_singer': ['Wreckx-n-Effect'],
#    'ranking': '9',
#    'song': ['Rump Shaker'],
#    'songurl': ['/wiki/Rump_Shaker_(song)'],
#    'titletext': 'Rump Shaker',
#    'url': ['/wiki/Wreckx-n-Effect']},
#   {'band_singer': ['Snow'],
#    'ranking': '10',
#    'song': ['Informer'],
#    'songurl': ['/wiki/Informer_(song)'],
#    'titletext': 'Informer',
#    'url': ['/wiki/Snow_(musician)']},
#   {'band_singer': ['Dr. Dre'],
#    'ranking': '11',
#    'song': ["Nuthin' but a 'G' Thang"],
#    'songurl': ['/wiki/Nuthin%27_but_a_%27G%27_Thang'],
#    'titletext': "Nuthin' but a 'G' Thang",
#    'url': ['/wiki/Dr._Dre']},
#   {'band_singer': ['Boyz II Men'],
#    'ranking': '12',
#    'song': ['In the Still of the Nite'],
#    'songurl': ['/wiki/In_the_Still_of_the_Night_(1956_song)#Boyz_II_Men_version'],
#    'titletext': 'In the Still of the Nite',
#    'url': ['/wiki/Boyz_II_Men']},
#   {'band_singer': ['Jade'],
#    'ranking': '13',
#    'song': ["Don't Walk Away"],
#    'songurl': ['/wiki/Don%27t_Walk_Away_(Jade_song)'],
#    'titletext': "Don't Walk Away",
#    'url': ['/wiki/Jade_(R%26B_group)']},
#   {'band_singer': ['H-Town'],
#    'ranking': '14',
#    'song': ["Knockin' da Boots"],
#    'songurl': ['/wiki/Knockin%27_da_Boots'],
#    'titletext': "Knockin' da Boots",
#    'url': ['/wiki/H-Town_(band)']},
#   {'band_singer': ['Jodeci'],
#    'ranking': '15',
#    'song': ['Lately'],
#    'songurl': ['/wiki/Lately_(Jodeci_song)'],
#    'titletext': 'Lately',
#    'url': ['/wiki/Jodeci']},
#   {'band_singer': ['Duice'],
#    'ranking': '16',
#    'song': ['Dazzey Duks'],
#    'songurl': ['/wiki/Dazzey_Duks'],
#    'titletext': 'Dazzey Duks',
#    'url': ['/wiki/Duice']},
#   {'band_singer': ['Robin S.'],
#    'ranking': '17',
#    'song': ['Show Me Love'],
#    'songurl': ['/wiki/Show_Me_Love_(Robin_S._song)'],
#    'titletext': 'Show Me Love',
#    'url': ['/wiki/Robin_S.']},
#   {'band_singer': ['Peabo Bryson', 'Regina Belle'],
#    'ranking': '18',
#    'song': ['A Whole New World'],
#    'songurl': ['/wiki/A_Whole_New_World'],
#    'titletext': 'A Whole New World',
#    'url': ['/wiki/Peabo_Bryson', '/wiki/Regina_Belle']},
#   {'band_singer': ['Janet Jackson'],
#    'ranking': '19',
#    'song': ['If'],
#    'songurl': ['/wiki/If_(Janet_Jackson_song)'],
#    'titletext': 'If',
#    'url': ['/wiki/Janet_Jackson']},
#   {'band_singer': ['SWV'],
#    'ranking': '20',
#    'song': ["I'm So Into You"],
#    'songurl': ['/wiki/I%27m_So_Into_You'],
#    'titletext': "I'm So Into You",
#    'url': ['/wiki/SWV']},
#   {'band_singer': ['Vanessa Williams', 'Brian McKnight'],
#    'ranking': '21',
#    'song': ['Love Is'],
#    'songurl': ['/wiki/Love_Is_(Vanessa_Williams_song)'],
#    'titletext': 'Love Is',
#    'url': ['/wiki/Vanessa_L._Williams', '/wiki/Brian_McKnight']},
#   {'band_singer': ['Soul Asylum'],
#    'ranking': '22',
#    'song': ['Runaway Train'],
#    'songurl': ['/wiki/Runaway_Train_(Soul_Asylum_song)'],
#    'titletext': 'Runaway Train',
#    'url': ['/wiki/Soul_Asylum']},
#   {'band_singer': ['Exposé'],
#    'ranking': '23',
#    'song': ["I'll Never Get Over You (Getting Over Me)"],
#    'songurl': ['/wiki/I%27ll_Never_Get_Over_You_(Getting_Over_Me)'],
#    'titletext': "I'll Never Get Over You (Getting Over Me)",
#    'url': ['/wiki/Expos%C3%A9_(group)']},
#   {'band_singer': ['Paperboy'],
#    'ranking': '24',
#    'song': ['Ditty'],
#    'songurl': ['/wiki/Ditty_(Paperboy_song)'],
#    'titletext': 'Ditty',
#    'url': ['/wiki/Paperboy_(rapper)']},
#   {'band_singer': ['Snap!'],
#    'ranking': '25',
#    'song': ['Rhythm Is a Dancer'],
#    'songurl': ['/wiki/Rhythm_Is_a_Dancer'],
#    'titletext': 'Rhythm Is a Dancer',
#    'url': ['/wiki/Snap!']},
#   {'band_singer': ['Billy Joel'],
#    'ranking': '26',
#    'song': ['The River of Dreams'],
#    'songurl': ['/wiki/The_River_of_Dreams'],
#    'titletext': 'The River of Dreams',
#    'url': ['/wiki/Billy_Joel']},
#   {'band_singer': ['The Proclaimers'],
#    'ranking': '27',
#    'song': ["I'm Gonna Be (500 Miles)"],
#    'songurl': ['/wiki/I%27m_Gonna_Be_(500_Miles)'],
#    'titletext': "I'm Gonna Be (500 Miles)",
#    'url': ['/wiki/The_Proclaimers']},
#   {'band_singer': ['Spin Doctors'],
#    'ranking': '28',
#    'song': ['Two Princes'],
#    'songurl': ['/wiki/Two_Princes'],
#    'titletext': 'Two Princes',
#    'url': ['/wiki/Spin_Doctors']},
#   {'band_singer': ['SWV'],
#    'ranking': '29',
#    'song': ['Right Here'],
#    'songurl': ['/wiki/Right_Here_(SWV_song)'],
#    'titletext': 'Right Here',
#    'url': ['/wiki/SWV']},
#   {'band_singer': ['Whitney Houston'],
#    'ranking': '30',
#    'song': ['I Have Nothing'],
#    'songurl': ['/wiki/I_Have_Nothing'],
#    'titletext': 'I Have Nothing',
#    'url': ['/wiki/Whitney_Houston']},
#   {'band_singer': ['Arrested Development'],
#    'ranking': '31',
#    'song': ['Mr. Wendal'],
#    'songurl': ['/wiki/Mr._Wendal'],
#    'titletext': 'Mr. Wendal',
#    'url': ['/wiki/Arrested_Development_(group)']},
#   {'band_singer': ['Rod Stewart'],
#    'ranking': '32',
#    'song': ['Have I Told You Lately'],
#    'songurl': ['/wiki/Have_I_Told_You_Lately'],
#    'titletext': 'Have I Told You Lately',
#    'url': ['/wiki/Rod_Stewart']},
#   {'band_singer': ['Shanice'],
#    'ranking': '33',
#    'song': ['Saving Forever for You'],
#    'songurl': ['/wiki/Saving_Forever_for_You'],
#    'titletext': 'Saving Forever for You',
#    'url': ['/wiki/Shanice']},
#   {'band_singer': ['Duran Duran'],
#    'ranking': '34',
#    'song': ['Ordinary World'],
#    'songurl': ['/wiki/Ordinary_World'],
#    'titletext': 'Ordinary World',
#    'url': ['/wiki/Duran_Duran']},
#   {'band_singer': ['Tony! Toni! Toné!'],
#    'ranking': '35',
#    'song': ['If I Had No Loot'],
#    'songurl': ['/wiki/If_I_Had_No_Loot'],
#    'titletext': 'If I Had No Loot',
#    'url': ['/wiki/Tony!_Toni!_Ton%C3%A9!']},
#   {'band_singer': ['Meat Loaf'],
#    'ranking': '36',
#    'song': ["I'd Do Anything for Love (But I Won't Do That)"],
#    'songurl': ['/wiki/I%27d_Do_Anything_for_Love_(But_I_Won%27t_Do_That)'],
#    'titletext': "I'd Do Anything for Love (But I Won't Do That)",
#    'url': ['/wiki/Meat_Loaf']},
#   {'band_singer': ['Onyx'],
#    'ranking': '37',
#    'song': ['Slam'],
#    'songurl': ['/wiki/Slam_(Onyx_song)'],
#    'titletext': 'Slam',
#    'url': ['/wiki/Onyx_(hip_hop_group)']},
#   {'band_singer': ['P.M. Dawn'],
#    'ranking': '38',
#    'song': ['Looking Through Patient Eyes'],
#    'songurl': ['/wiki/Looking_Through_Patient_Eyes'],
#    'titletext': 'Looking Through Patient Eyes',
#    'url': ['/wiki/P.M._Dawn']},
#   {'band_singer': ['Whitney Houston'],
#    'ranking': '39',
#    'song': ["I'm Every Woman"],
#    'songurl': ['/wiki/I%27m_Every_Woman#Whitney_Houston_version'],
#    'titletext': "I'm Every Woman",
#    'url': ['/wiki/Whitney_Houston']},
#   {'band_singer': ['Shai'],
#    'ranking': '40',
#    'song': [],
#    'songurl': [None],
#    'titletext': '',
#    'url': ['/wiki/Shai_(band)']},
#   {'band_singer': ['Duran Duran'],
#    'ranking': '41',
#    'song': ['Come Undone'],
#    'songurl': ['/wiki/Come_Undone_(Duran_Duran_song)'],
#    'titletext': 'Come Undone',
#    'url': ['/wiki/Duran_Duran']},
#   {'band_singer': ['Tina Turner'],
#    'ranking': '42',
#    'song': ["I Don't Wanna Fight"],
#    'songurl': ['/wiki/I_Don%27t_Wanna_Fight'],
#    'titletext': "I Don't Wanna Fight",
#    'url': ['/wiki/Tina_Turner']},
#   {'band_singer': ['P.M. Dawn'],
#    'ranking': '43',
#    'song': ["I'd Die Without You"],
#    'songurl': ['/wiki/I%27d_Die_Without_You'],
#    'titletext': "I'd Die Without You",
#    'url': ['/wiki/P.M._Dawn']},
#   {'band_singer': ['95 South'],
#    'ranking': '44',
#    'song': ['Whoot, There It Is'],
#    'songurl': ['/wiki/Whoot,_There_It_Is'],
#    'titletext': 'Whoot, There It Is',
#    'url': ['/wiki/95_South']},
#   {'band_singer': ['Naughty by Nature'],
#    'ranking': '45',
#    'song': ['Hip Hop Hooray'],
#    'songurl': ['/wiki/Hip_Hop_Hooray'],
#    'titletext': 'Hip Hop Hooray',
#    'url': ['/wiki/Naughty_by_Nature']},
#   {'band_singer': ['Toni Braxton'],
#    'ranking': '46',
#    'song': ['Another Sad Love Song'],
#    'songurl': ['/wiki/Another_Sad_Love_Song'],
#    'titletext': 'Another Sad Love Song',
#    'url': ['/wiki/Toni_Braxton']},
#   {'band_singer': ['Michael Jackson'],
#    'ranking': '47',
#    'song': ['Will You Be There'],
#    'songurl': ['/wiki/Will_You_Be_There'],
#    'titletext': 'Will You Be There',
#    'url': ['/wiki/Michael_Jackson']},
#   {'band_singer': ['Shai'],
#    'ranking': '48',
#    'song': ['Comforter'],
#    'songurl': ['/wiki/Comforter_(song)'],
#    'titletext': 'Comforter',
#    'url': ['/wiki/Shai_(band)']},
#   {'band_singer': ['Bobby Brown'],
#    'ranking': '49',
#    'song': [],
#    'songurl': [None],
#    'titletext': '',
#    'url': ['/wiki/Bobby_Brown']},
#   {'band_singer': ['4 Non Blondes'],
#    'ranking': '50',
#    'song': ["What's Up?"],
#    'songurl': ['/wiki/What%27s_Up%3F_(4_Non_Blondes_song)'],
#    'titletext': "What's Up?",
#    'url': ['/wiki/4_Non_Blondes']},
#   {'band_singer': ['Ace of Base'],
#    'ranking': '51',
#    'song': ['All That She Wants'],
#    'songurl': ['/wiki/All_That_She_Wants'],
#    'titletext': 'All That She Wants',
#    'url': ['/wiki/Ace_of_Base']},
#   {'band_singer': ['Prince', 'The New Power Generation'],
#    'ranking': '52',
#    'song': ['7'],
#    'songurl': ['/wiki/7_(song)'],
#    'titletext': '7',
#    'url': ['/wiki/Prince_(musician)', '/wiki/The_New_Power_Generation']},
#   {'band_singer': ['Dr. Dre', 'Snoop Doggy Dogg'],
#    'ranking': '53',
#    'song': ['Dre Day'],
#    'songurl': ['/wiki/Fuck_wit_Dre_Day_(And_Everybody%27s_Celebratin%27)'],
#    'titletext': 'Dre Day',
#    'url': ['/wiki/Dr._Dre', '/wiki/Snoop_Dogg']},
#   {'band_singer': ['Brian McKnight'],
#    'ranking': '54',
#    'song': ['One Last Cry'],
#    'songurl': ['/wiki/One_Last_Cry'],
#    'titletext': 'One Last Cry',
#    'url': ['/wiki/Brian_McKnight']},
#   {'band_singer': ['Xscape'],
#    'ranking': '55',
#    'song': ["Just Kickin' It"],
#    'songurl': ['/wiki/Just_Kickin%27_It'],
#    'titletext': "Just Kickin' It",
#    'url': ['/wiki/Xscape_(band)']},
#   {'band_singer': ['2Pac'],
#    'ranking': '56',
#    'song': ['I Get Around'],
#    'songurl': ['/wiki/I_Get_Around_(Tupac_Shakur_song)'],
#    'titletext': 'I Get Around',
#    'url': ['/wiki/Tupac_Shakur']},
#   {'band_singer': ['Bon Jovi'],
#    'ranking': '57',
#    'song': ['Bed of Roses'],
#    'songurl': ['/wiki/Bed_of_Roses_(Bon_Jovi_song)'],
#    'titletext': 'Bed of Roses',
#    'url': ['/wiki/Bon_Jovi']},
#   {'band_singer': ['Mary J. Blige'],
#    'ranking': '58',
#    'song': ['Real Love'],
#    'songurl': ['/wiki/Real_Love_(Mary_J._Blige_song)'],
#    'titletext': 'Real Love',
#    'url': ['/wiki/Mary_J._Blige']},
#   {'band_singer': ['Portrait'],
#    'ranking': '59',
#    'song': [],
#    'songurl': [None],
#    'titletext': '',
#    'url': ['/wiki/Portrait_(band)']},
#   {'band_singer': ['Aerosmith'],
#    'ranking': '60',
#    'song': ["Cryin'"],
#    'songurl': ['/wiki/Cryin%27'],
#    'titletext': "Cryin'",
#    'url': ['/wiki/Aerosmith']},
#   {'band_singer': ['Ugly Kid Joe'],
#    'ranking': '61',
#    'song': ["Cat's in the Cradle"],
#    'songurl': ['/wiki/Cat%27s_in_the_Cradle'],
#    'titletext': "Cat's in the Cradle",
#    'url': ['/wiki/Ugly_Kid_Joe']},
#   {'band_singer': ['TLC'],
#    'ranking': '62',
#    'song': ['What About Your Friends'],
#    'songurl': ['/wiki/What_About_Your_Friends'],
#    'titletext': 'What About Your Friends',
#    'url': ['/wiki/TLC_(group)']},
#   {'band_singer': ['Positive K'],
#    'ranking': '63',
#    'song': ['I Got a Man'],
#    'songurl': ['/wiki/I_Got_a_Man'],
#    'titletext': 'I Got a Man',
#    'url': ['/wiki/Positive_K']},
#   {'band_singer': ['Zhané'],
#    'ranking': '64',
#    'song': ['Hey Mr. D.J.'],
#    'songurl': ['/wiki/Hey_Mr._D.J.'],
#    'titletext': 'Hey Mr. D.J.',
#    'url': ['/wiki/Zhan%C3%A9']},
#   {'band_singer': ['Cypress Hill'],
#    'ranking': '65',
#    'song': ['Insane in the Brain'],
#    'songurl': ['/wiki/Insane_in_the_Brain'],
#    'titletext': 'Insane in the Brain',
#    'url': ['/wiki/Cypress_Hill']},
#   {'band_singer': ['Madonna'],
#    'ranking': '66',
#    'song': ['Deeper and Deeper'],
#    'songurl': ['/wiki/Deeper_and_Deeper'],
#    'titletext': 'Deeper and Deeper',
#    'url': ['/wiki/Madonna_(entertainer)']},
#   {'band_singer': ['Madonna'],
#    'ranking': '67',
#    'song': ['Rain'],
#    'songurl': ['/wiki/Rain_(Madonna_song)'],
#    'titletext': 'Rain',
#    'url': ['/wiki/Madonna_(entertainer)']},
#   {'band_singer': ['Jeremy Jordan'],
#    'ranking': '68',
#    'song': ['The Right Kind of Love'],
#    'songurl': ['/wiki/The_Right_Kind_of_Love'],
#    'titletext': 'The Right Kind of Love',
#    'url': ['/wiki/Jeremy_Jordan_(singer,_born_1973)']},
#   {'band_singer': ['Inner Circle'],
#    'ranking': '69',
#    'song': ['Bad Boys', 'Cops'],
#    'songurl': ['/wiki/Bad_Boys_(Inner_Circle_song)', '/wiki/Cops_(TV_series)'],
#    'titletext': 'Bad Boys/Cops',
#    'url': ['/wiki/Inner_Circle_(reggae_band)']},
#   {'band_singer': ['Boy Krazy'],
#    'ranking': '70',
#    'song': ["That's What Love Can Do"],
#    'songurl': ['/wiki/That%27s_What_Love_Can_Do'],
#    'titletext': "That's What Love Can Do",
#    'url': ['/wiki/Boy_Krazy']},
#   {'band_singer': ['Jon Secada'],
#    'ranking': '71',
#    'song': ['Do You Believe in Us'],
#    'songurl': ['/wiki/Do_You_Believe_in_Us'],
#    'titletext': 'Do You Believe in Us',
#    'url': ['/wiki/Jon_Secada']},
#   {'band_singer': ['Jon Secada'],
#    'ranking': '72',
#    'song': ['Angel'],
#    'songurl': ['/wiki/Angel_(Jon_Secada_song)'],
#    'titletext': 'Angel',
#    'url': ['/wiki/Jon_Secada']},
#   {'band_singer': ['Kenny G'],
#    'ranking': '73',
#    'song': ['Forever in Love'],
#    'songurl': ['/wiki/Forever_in_Love_(instrumental)'],
#    'titletext': 'Forever in Love',
#    'url': ['/wiki/Kenny_G']},
#   {'band_singer': ['Janet Jackson'],
#    'ranking': '74',
#    'song': ['Again'],
#    'songurl': ['/wiki/Again_(Janet_Jackson_song)'],
#    'titletext': 'Again',
#    'url': ['/wiki/Janet_Jackson']},
#   {'band_singer': ['DJ Jazzy Jeff & The Fresh Prince'],
#    'ranking': '75',
#    'song': ['Boom! Shake the Room'],
#    'songurl': ['/wiki/Boom!_Shake_the_Room'],
#    'titletext': 'Boom! Shake the Room',
#    'url': ['/wiki/DJ_Jazzy_Jeff_%26_The_Fresh_Prince']},
#   {'band_singer': ['Restless Heart'],
#    'ranking': '76',
#    'song': ['When She Cries'],
#    'songurl': ['/wiki/When_She_Cries'],
#    'titletext': 'When She Cries',
#    'url': ['/wiki/Restless_Heart']},
#   {'band_singer': ['Inner Circle'],
#    'ranking': '77',
#    'song': ['Sweat (A La La La La Long)'],
#    'songurl': ['/wiki/Sweat_(A_La_La_La_La_Long)'],
#    'titletext': 'Sweat (A La La La La Long)',
#    'url': ['/wiki/Inner_Circle_(reggae_band)']},
#   {'band_singer': ['Ice Cube'],
#    'ranking': '78',
#    'song': ['It Was a Good Day'],
#    'songurl': ['/wiki/It_Was_a_Good_Day'],
#    'titletext': 'It Was a Good Day',
#    'url': ['/wiki/Ice_Cube']},
#   {'band_singer': ['Captain Hollywood Project'],
#    'ranking': '79',
#    'song': ['More and More'],
#    'songurl': ['/wiki/More_and_More_(Captain_Hollywood_Project_song)'],
#    'titletext': 'More and More',
#    'url': ['/wiki/Captain_Hollywood_Project']},
#   {'band_singer': ['The Heights'],
#    'ranking': '80',
#    'song': ['How Do You Talk to an Angel'],
#    'songurl': ['/wiki/How_Do_You_Talk_to_an_Angel'],
#    'titletext': 'How Do You Talk to an Angel',
#    'url': ['/wiki/The_Heights_(American_TV_series)']},
#   {'band_singer': ['Digable Planets'],
#    'ranking': '81',
#    'song': ['Rebirth of Slick (Cool Like Dat)'],
#    'songurl': ['/wiki/Rebirth_of_Slick_(Cool_Like_Dat)'],
#    'titletext': 'Rebirth of Slick (Cool Like Dat)',
#    'url': ['/wiki/Digable_Planets']},
#   {'band_singer': ['Haddaway'],
#    'ranking': '82',
#    'song': ['What Is Love'],
#    'songurl': ['/wiki/What_Is_Love_(Haddaway_song)'],
#    'titletext': 'What Is Love',
#    'url': ['/wiki/Haddaway']},
#   {'band_singer': ['Michael Bolton'],
#    'ranking': '83',
#    'song': ['To Love Somebody'],
#    'songurl': ['/wiki/To_Love_Somebody_(song)'],
#    'titletext': 'To Love Somebody',
#    'url': ['/wiki/Michael_Bolton']},
#   {'band_singer': ['En Vogue'],
#    'ranking': '84',
#    'song': ['Give It Up, Turn It Loose'],
#    'songurl': ['/wiki/Give_It_Up,_Turn_It_Loose'],
#    'titletext': 'Give It Up, Turn It Loose',
#    'url': ['/wiki/En_Vogue']},
#   {'band_singer': ['Kris Kross'],
#    'ranking': '85',
#    'song': ['Alright'],
#    'songurl': ['/wiki/Alright_(Kris_Kross_song)'],
#    'titletext': 'Alright',
#    'url': ['/wiki/Kris_Kross']},
#   {'band_singer': ['Ice Cube', 'Das EFX'],
#    'ranking': '86',
#    'song': ['Check Yo Self'],
#    'songurl': ['/wiki/Check_Yo_Self'],
#    'titletext': 'Check Yo Self',
#    'url': ['/wiki/Ice_Cube', '/wiki/Das_EFX']},
#   {'band_singer': ['Sting'],
#    'ranking': '87',
#    'song': ['Fields of Gold'],
#    'songurl': ['/wiki/Fields_of_Gold'],
#    'titletext': 'Fields of Gold',
#    'url': ['/wiki/Sting_(musician)']},
#   {'band_singer': ['Dino'],
#    'ranking': '88',
#    'song': ['Ooh Child'],
#    'songurl': ['/wiki/Ooh_Child'],
#    'titletext': 'Ooh Child',
#    'url': ['/wiki/Dino_(singer)']},
#   {'band_singer': ['Go West'],
#    'ranking': '89',
#    'song': ['Faithful'],
#    'songurl': ['/wiki/Faithful_(Go_West_song)'],
#    'titletext': 'Faithful',
#    'url': ['/wiki/Go_West_(band)']},
#   {'band_singer': ['Rod Stewart'],
#    'ranking': '90',
#    'song': ['Reason to Believe'],
#    'songurl': ['/wiki/Reason_to_Believe'],
#    'titletext': 'Reason to Believe',
#    'url': ['/wiki/Rod_Stewart']},
#   {'band_singer': ['Tears for Fears'],
#    'ranking': '91',
#    'song': ['Break It Down Again'],
#    'songurl': ['/wiki/Break_It_Down_Again'],
#    'titletext': 'Break It Down Again',
#    'url': ['/wiki/Tears_for_Fears']},
#   {'band_singer': ['Joey Lawrence'],
#    'ranking': '92',
#    'song': ["Nothin' My Love Can't Fix"],
#    'songurl': ['/wiki/Nothin%27_My_Love_Can%27t_Fix'],
#    'titletext': "Nothin' My Love Can't Fix",
#    'url': ['/wiki/Joey_Lawrence']},
#   {'band_singer': ['Green Jellÿ'],
#    'ranking': '93',
#    'song': ['Three Little Pigs'],
#    'songurl': ['/wiki/Three_Little_Pigs_(song)'],
#    'titletext': 'Three Little Pigs',
#    'url': ['/wiki/Green_Jell%C3%BF']},
#   {'band_singer': ['Aerosmith'],
#    'ranking': '94',
#    'song': ["Livin' on the Edge"],
#    'songurl': ['/wiki/Livin%27_on_the_Edge'],
#    'titletext': "Livin' on the Edge",
#    'url': ['/wiki/Aerosmith']},
#   {'band_singer': ['Gin Blossoms'],
#    'ranking': '95',
#    'song': ['Hey Jealousy'],
#    'songurl': ['/wiki/Hey_Jealousy'],
#    'titletext': 'Hey Jealousy',
#    'url': ['/wiki/Gin_Blossoms']},
#   {'band_singer': ['Sting'],
#    'ranking': '96',
#    'song': ['If I Ever Lose My Faith in You'],
#    'songurl': ['/wiki/If_I_Ever_Lose_My_Faith_in_You'],
#    'titletext': 'If I Ever Lose My Faith in You',
#    'url': ['/wiki/Sting_(musician)']},
#   {'band_singer': ['Tony! Toni! Toné!'],
#    'ranking': '97',
#    'song': ['Anniversary'],
#    'songurl': ['/wiki/Anniversary_(Tony!_Toni!_Ton%C3%A9!_song)'],
#    'titletext': 'Anniversary',
#    'url': ['/wiki/Tony!_Toni!_Ton%C3%A9!']},
#   {'band_singer': ['Jade'],
#    'ranking': '98',
#    'song': ['One Woman'],
#    'songurl': ['/wiki/One_Woman'],
#    'titletext': 'One Woman',
#    'url': ['/wiki/Jade_(American_band)']},
#   {'band_singer': ['Taylor Dayne'],
#    'ranking': '99',
#    'song': ["Can't Get Enough of Your Love"],
#    'songurl': ['/wiki/Can%27t_Get_Enough_of_Your_Love#Taylor_Dayne_version'],
#    'titletext': "Can't Get Enough of Your Love",
#    'url': ['/wiki/Taylor_Dayne']},
#   {'band_singer': ['Def Leppard'],
#    'ranking': '100',
#    'song': ['Two Steps Behind'],
#    'songurl': ['/wiki/Two_Steps_Behind'],
#    'titletext': 'Two Steps Behind',
#    'url': ['/wiki/Def_Leppard']}],
#  '1994': [{'band_singer': ['Ace of Base'],
#    'ranking': '1',
#    'song': ['The Sign'],
#    'songurl': ['/wiki/The_Sign_(song)'],
#    'titletext': 'The Sign',
#    'url': ['/wiki/Ace_of_Base']},
#   {'band_singer': ['All-4-One'],
#    'ranking': '2',
#    'song': ['I Swear'],
#    'songurl': ['/wiki/I_Swear#All-4-One_version'],
#    'titletext': 'I Swear',
#    'url': ['/wiki/All-4-One']},
#   {'band_singer': ['Boyz II Men'],
#    'ranking': '3',
#    'song': ["I'll Make Love to You"],
#    'songurl': ['/wiki/I%27ll_Make_Love_to_You'],
#    'titletext': "I'll Make Love to You",
#    'url': ['/wiki/Boyz_II_Men']},
#   {'band_singer': ['Céline Dion'],
#    'ranking': '4',
#    'song': ['The Power of Love'],
#    'songurl': ['/wiki/The_Power_of_Love_(Jennifer_Rush_song)#Céline_Dion_version'],
#    'titletext': 'The Power of Love',
#    'url': ['/wiki/C%C3%A9line_Dion']},
#   {'band_singer': ['Mariah Carey'],
#    'ranking': '5',
#    'song': ['Hero'],
#    'songurl': ['/wiki/Hero_(Mariah_Carey_song)'],
#    'titletext': 'Hero',
#    'url': ['/wiki/Mariah_Carey']},
#   {'band_singer': ['Lisa Loeb and Nine Stories'],
#    'ranking': '6',
#    'song': ['Stay (I Missed You)'],
#    'songurl': ['/wiki/Stay_(I_Missed_You)'],
#    'titletext': 'Stay (I Missed You)',
#    'url': ['/wiki/Lisa_Loeb']},
#   {'band_singer': ['Toni Braxton'],
#    'ranking': '7',
#    'song': ['Breathe Again'],
#    'songurl': ['/wiki/Breathe_Again'],
#    'titletext': 'Breathe Again',
#    'url': ['/wiki/Toni_Braxton']},
#   {'band_singer': ['Bryan Adams', 'Rod Stewart', 'Sting'],
#    'ranking': '8',
#    'song': ['All for Love'],
#    'songurl': ['/wiki/All_for_Love_(song)'],
#    'titletext': 'All for Love',
#    'url': ['/wiki/Bryan_Adams',
#     '/wiki/Rod_Stewart',
#     '/wiki/Sting_(musician)']},
#   {'band_singer': ['Ace of Base'],
#    'ranking': '9',
#    'song': ['All That She Wants'],
#    'songurl': ['/wiki/All_That_She_Wants'],
#    'titletext': 'All That She Wants',
#    'url': ['/wiki/Ace_of_Base']},
#   {'band_singer': ['Ace of Base'],
#    'ranking': '10',
#    'song': ["Don't Turn Around"],
#    'songurl': ['/wiki/Don%27t_Turn_Around'],
#    'titletext': "Don't Turn Around",
#    'url': ['/wiki/Ace_of_Base']},
#   {'band_singer': ['R. Kelly'],
#    'ranking': '11',
#    'song': ["Bump n' Grind"],
#    'songurl': ['/wiki/Bump_n%27_Grind_(R._Kelly_song)'],
#    'titletext': "Bump n' Grind",
#    'url': ['/wiki/R._Kelly']},
#   {'band_singer': ['Janet Jackson'],
#    'ranking': '12',
#    'song': ['Again'],
#    'songurl': ['/wiki/Again_(Janet_Jackson_song)'],
#    'titletext': 'Again',
#    'url': ['/wiki/Janet_Jackson']},
#   {'band_singer': ['Madonna'],
#    'ranking': '13',
#    'song': ["I'll Remember"],
#    'songurl': ['/wiki/I%27ll_Remember'],
#    'titletext': "I'll Remember",
#    'url': ['/wiki/Madonna_(entertainer)']},
#   {'band_singer': ['Salt-n-Pepa', 'En Vogue'],
#    'ranking': '14',
#    'song': ['Whatta Man'],
#    'songurl': ['/wiki/Whatta_Man'],
#    'titletext': 'Whatta Man',
#    'url': ['/wiki/Salt-n-Pepa', '/wiki/En_Vogue']},
#   {'band_singer': ['John Mellencamp', 'Meshell Ndegeocello'],
#    'ranking': '15',
#    'song': ['Wild Night'],
#    'songurl': ['/wiki/Wild_Night'],
#    'titletext': 'Wild Night',
#    'url': ['/wiki/John_Mellencamp', '/wiki/Meshell_Ndegeocello']},
#   {'band_singer': ['Mariah Carey'],
#    'ranking': '16',
#    'song': ['Without You', 'Never Forget You'],
#    'songurl': ['/wiki/Without_You_(Badfinger_song)#Mariah_Carey_version',
#     '/wiki/Never_Forget_You_(Mariah_Carey_song)'],
#    'titletext': 'Without You/Never Forget You',
#    'url': ['/wiki/Mariah_Carey']},
#   {'band_singer': ['Toni Braxton'],
#    'ranking': '17',
#    'song': ['You Mean the World to Me'],
#    'songurl': ['/wiki/You_Mean_the_World_to_Me_(Toni_Braxton_song)'],
#    'titletext': 'You Mean the World to Me',
#    'url': ['/wiki/Toni_Braxton']},
#   {'band_singer': ['Elton John'],
#    'ranking': '18',
#    'song': ['Can You Feel the Love Tonight'],
#    'songurl': ['/wiki/Can_You_Feel_the_Love_Tonight'],
#    'titletext': 'Can You Feel the Love Tonight',
#    'url': ['/wiki/Elton_John']},
#   {'band_singer': ['Prince'],
#    'ranking': '19',
#    'song': ['The Most Beautiful Girl in the World'],
#    'songurl': ['/wiki/The_Most_Beautiful_Girl_in_the_World_(Prince_song)'],
#    'titletext': 'The Most Beautiful Girl in the World',
#    'url': ['/wiki/Prince_(musician)']},
#   {'band_singer': ['Coolio'],
#    'ranking': '20',
#    'song': ['Fantastic Voyage'],
#    'songurl': ['/wiki/Fantastic_Voyage_(Coolio_song)'],
#    'titletext': 'Fantastic Voyage',
#    'url': ['/wiki/Coolio']},
#   {'band_singer': ['Big Mountain'],
#    'ranking': '21',
#    'song': ['Baby, I Love Your Way'],
#    'songurl': ['/wiki/Baby,_I_Love_Your_Way'],
#    'titletext': 'Baby, I Love Your Way',
#    'url': ['/wiki/Big_Mountain_(band)']},
#   {'band_singer': ['Warren G', 'Nate Dogg'],
#    'ranking': '22',
#    'song': ['Regulate'],
#    'songurl': ['/wiki/Regulate_(song)'],
#    'titletext': 'Regulate',
#    'url': ['/wiki/Warren_G', '/wiki/Nate_Dogg']},
#   {'band_singer': ['Jon Secada'],
#    'ranking': '23',
#    'song': ['If You Go'],
#    'songurl': ['/wiki/If_You_Go_(song)'],
#    'titletext': 'If You Go',
#    'url': ['/wiki/Jon_Secada']},
#   {'band_singer': ['Aaliyah'],
#    'ranking': '24',
#    'song': ['Back & Forth'],
#    'songurl': ['/wiki/Back_%26_Forth_(Aaliyah_song)'],
#    'titletext': 'Back & Forth',
#    'url': ['/wiki/Aaliyah']},
#   {'band_singer': ['Richard Marx'],
#    'ranking': '25',
#    'song': ['Now and Forever'],
#    'songurl': ['/wiki/Now_and_Forever_(Richard_Marx_song)'],
#    'titletext': 'Now and Forever',
#    'url': ['/wiki/Richard_Marx']},
#   {'band_singer': ['Babyface'],
#    'ranking': '26',
#    'song': ['When Can I See You'],
#    'songurl': ['/wiki/When_Can_I_See_You'],
#    'titletext': 'When Can I See You',
#    'url': ['/wiki/Babyface_(musician)']},
#   {'band_singer': ['Bryan Adams'],
#    'ranking': '27',
#    'song': ['Please Forgive Me'],
#    'songurl': ['/wiki/Please_Forgive_Me'],
#    'titletext': 'Please Forgive Me',
#    'url': ['/wiki/Bryan_Adams']},
#   {'band_singer': ['All-4-One'],
#    'ranking': '28',
#    'song': ['So Much in Love'],
#    'songurl': ['/wiki/So_Much_in_Love'],
# ...
#    'url': ['/wiki/Iggy_Azalea', '/wiki/Rita_Ora']},
#   {'band_singer': ['Jessie J', 'Ariana Grande', 'Nicki Minaj'],
#    'ranking': '27',
#    'song': ['Bang Bang'],
#    'songurl': ['/wiki/Bang_Bang_(Jessie_J,_Ariana_Grande_and_Nicki_Minaj_song)'],
#    'titletext': 'Bang Bang',
#    'url': ['/wiki/Jessie_J', '/wiki/Ariana_Grande', '/wiki/Nicki_Minaj']},
#   {'band_singer': ['Disclosure', 'Sam Smith'],
#    'ranking': '28',
#    'song': ['Latch'],
#    'songurl': ['/wiki/Latch_(song)'],
#    'titletext': 'Latch',
#    'url': ['/wiki/Disclosure_(band)', '/wiki/Sam_Smith_(singer)']},
#   {'band_singer': ['Maroon 5'],
#    'ranking': '29',
#    'song': ['Maps'],
#    'songurl': ['/wiki/Maps_(Maroon_5_song)'],
#    'titletext': 'Maps',
#    'url': ['/wiki/Maroon_5']},
#   {'band_singer': ['Chris Brown',
#     'Lil Wayne',
#     'French Montana',
#     'Too Short',
#     'Tyga'],
#    'ranking': '30',
#    'song': ['Loyal'],
#    'songurl': ['/wiki/Loyal_(Chris_Brown_song)'],
#    'titletext': 'Loyal',
#    'url': ['/wiki/Chris_Brown',
#     '/wiki/Lil_Wayne',
#     '/wiki/French_Montana',
#     '/wiki/Too_Short',
#     '/wiki/Tyga']},
#   {'band_singer': ['American Authors'],
#    'ranking': '31',
#    'song': ['Best Day of My Life'],
#    'songurl': ['/wiki/Best_Day_of_My_Life'],
#    'titletext': 'Best Day of My Life',
#    'url': ['/wiki/American_Authors']},
#   {'band_singer': ['Tove Lo'],
#    'ranking': '32',
#    'song': ['Habits (Stay High)'],
#    'songurl': ['/wiki/Habits_(Stay_High)'],
#    'titletext': 'Habits (Stay High)',
#    'url': ['/wiki/Tove_Lo']},
#   {'band_singer': ['Calvin Harris'],
#    'ranking': '33',
#    'song': ['Summer'],
#    'songurl': ['/wiki/Summer_(Calvin_Harris_song)'],
#    'titletext': 'Summer',
#    'url': ['/wiki/Calvin_Harris']},
#   {'band_singer': ['Charli XCX'],
#    'ranking': '34',
#    'song': ['Boom Clap'],
#    'songurl': ['/wiki/Boom_Clap'],
#    'titletext': 'Boom Clap',
#    'url': ['/wiki/Charli_XCX']},
#   {'band_singer': ['Beyoncé', 'Jay-Z'],
#    'ranking': '35',
#    'song': ['Drunk in Love'],
#    'songurl': ['/wiki/Drunk_in_Love'],
#    'titletext': 'Drunk in Love',
#    'url': ['/wiki/Beyonc%C3%A9', '/wiki/Jay-Z']},
#   {'band_singer': ['Nicki Minaj'],
#    'ranking': '36',
#    'song': ['Anaconda'],
#    'songurl': ['/wiki/Anaconda_(Nicki_Minaj_song)'],
#    'titletext': 'Anaconda',
#    'url': ['/wiki/Nicki_Minaj']},
#   {'band_singer': ['Ariana Grande', 'Zedd'],
#    'ranking': '37',
#    'song': ['Break Free'],
#    'songurl': ['/wiki/Break_Free_(Ariana_Grande_song)'],
#    'titletext': 'Break Free',
#    'url': ['/wiki/Ariana_Grande', '/wiki/Zedd']},
#   {'band_singer': ['Enrique Iglesias', 'Descemer Bueno', 'Gente de Zona'],
#    'ranking': '38',
#    'song': ['Bailando'],
#    'songurl': ['/wiki/Bailando_(Enrique_Iglesias_song)'],
#    'titletext': 'Bailando',
#    'url': ['/wiki/Enrique_Iglesias',
#     '/wiki/Descemer_Bueno',
#     '/wiki/Gente_de_Zona']},
#   {'band_singer': ['Ellie Goulding'],
#    'ranking': '39',
#    'song': ['Burn'],
#    'songurl': ['/wiki/Burn_(Ellie_Goulding_song)'],
#    'titletext': 'Burn',
#    'url': ['/wiki/Ellie_Goulding']},
#   {'band_singer': ['Jason Derulo', 'Snoop Dogg'],
#    'ranking': '40',
#    'song': ['Wiggle'],
#    'songurl': ['/wiki/Wiggle_(song)'],
#    'titletext': 'Wiggle',
#    'url': ['/wiki/Jason_Derulo', '/wiki/Snoop_Dogg']},
#   {'band_singer': ['Clean Bandit', 'Jess Glynne'],
#    'ranking': '41',
#    'song': ['Rather Be'],
#    'songurl': ['/wiki/Rather_Be_(Clean_Bandit_song)'],
#    'titletext': 'Rather Be',
#    'url': ['/wiki/Clean_Bandit', '/wiki/Jess_Glynne']},
#   {'band_singer': ['Jeremih', 'YG'],
#    'ranking': '42',
#    'song': ["Don't Tell 'Em"],
#    'songurl': ['/wiki/Don%27t_Tell_%27Em'],
#    'titletext': "Don't Tell 'Em",
#    'url': ['/wiki/Jeremih', '/wiki/YG_(rapper)']},
#   {'band_singer': ['Kid Ink', 'Chris Brown'],
#    'ranking': '43',
#    'song': ['Show Me'],
#    'songurl': ['/wiki/Show_Me_(Kid_Ink_song)'],
#    'titletext': 'Show Me',
#    'url': ['/wiki/Kid_Ink', '/wiki/Chris_Brown']},
#   {'band_singer': ['Miley Cyrus'],
#    'ranking': '44',
#    'song': ['Wrecking Ball'],
#    'songurl': ['/wiki/Wrecking_Ball_(Miley_Cyrus_song)'],
#    'titletext': 'Wrecking Ball',
#    'url': ['/wiki/Miley_Cyrus']},
#   {'band_singer': ['Justin Timberlake'],
#    'ranking': '45',
#    'song': ['Not a Bad Thing'],
#    'songurl': ['/wiki/Not_a_Bad_Thing'],
#    'titletext': 'Not a Bad Thing',
#    'url': ['/wiki/Justin_Timberlake']},
#   {'band_singer': ['Katy Perry'],
#    'ranking': '46',
#    'song': ['Roar'],
#    'songurl': ['/wiki/Roar_(song)'],
#    'titletext': 'Roar',
#    'url': ['/wiki/Katy_Perry']},
#   {'band_singer': ['Paramore'],
#    'ranking': '47',
#    'song': ["Ain't It Fun"],
#    'songurl': ['/wiki/Ain%27t_It_Fun_(Paramore_song)'],
#    'titletext': "Ain't It Fun",
#    'url': ['/wiki/Paramore']},
#   {'band_singer': ['Aloe Blacc'],
#    'ranking': '48',
#    'song': ['The Man'],
#    'songurl': ['/wiki/The_Man_(Aloe_Blacc_song)'],
#    'titletext': 'The Man',
#    'url': ['/wiki/Aloe_Blacc']},
#   {'band_singer': ['Florida Georgia Line', 'Luke Bryan'],
#    'ranking': '49',
#    'song': ['This Is How We Roll'],
#    'songurl': ['/wiki/This_Is_How_We_Roll'],
#    'titletext': 'This Is How We Roll',
#    'url': ['/wiki/Florida_Georgia_Line', '/wiki/Luke_Bryan']},
#   {'band_singer': ['MKTO'],
#    'ranking': '50',
#    'song': ['Classic'],
#    'songurl': ['/wiki/Classic_(MKTO_song)'],
#    'titletext': 'Classic',
#    'url': ['/wiki/MKTO']},
#   {'band_singer': ['Coldplay'],
#    'ranking': '51',
#    'song': ['A Sky Full of Stars'],
#    'songurl': ['/wiki/A_Sky_Full_of_Stars'],
#    'titletext': 'A Sky Full of Stars',
#    'url': ['/wiki/Coldplay']},
#   {'band_singer': ['Ed Sheeran'],
#    'ranking': '52',
#    'song': ["Don't"],
#    'songurl': ['/wiki/Don%27t_(Ed_Sheeran_song)'],
#    'titletext': "Don't",
#    'url': ['/wiki/Ed_Sheeran']},
#   {'band_singer': ['Trey Songz'],
#    'ranking': '53',
#    'song': ['Na Na'],
#    'songurl': ['/wiki/Na_Na_(song)'],
#    'titletext': 'Na Na',
#    'url': ['/wiki/Trey_Songz']},
#   {'band_singer': ['Bobby Shmurda'],
#    'ranking': '54',
#    'song': ['Hot Boy'],
#    'songurl': ['/wiki/Hot_Nigga'],
#    'titletext': 'Hot Boy',
#    'url': ['/wiki/Bobby_Shmurda']},
#   {'band_singer': ['Drake', 'Majid Jordan'],
#    'ranking': '55',
#    'song': ["Hold On, We're Going Home"],
#    'songurl': ['/wiki/Hold_On,_We%27re_Going_Home'],
#    'titletext': "Hold On, We're Going Home",
#    'url': ['/wiki/Drake_(rapper)', '/wiki/Majid_Jordan']},
#   {'band_singer': ['Ed Sheeran'],
#    'ranking': '56',
#    'song': ['Sing'],
#    'songurl': ['/wiki/Sing_(Ed_Sheeran_song)'],
#    'titletext': 'Sing',
#    'url': ['/wiki/Ed_Sheeran']},
#   {'band_singer': ['Imagine Dragons'],
#    'ranking': '57',
#    'song': ['Radioactive'],
#    'songurl': ['/wiki/Radioactive_(Imagine_Dragons_song)'],
#    'titletext': 'Radioactive',
#    'url': ['/wiki/Imagine_Dragons']},
#   {'band_singer': ['YG', 'Jeezy', 'Rich Homie Quan'],
#    'ranking': '58',
#    'song': ['My Hitta'],
#    'songurl': ['/wiki/My_Nigga'],
#    'titletext': 'My Hitta',
#    'url': ['/wiki/YG_(rapper)', '/wiki/Jeezy', '/wiki/Rich_Homie_Quan']},
#   {'band_singer': ['Echosmith'],
#    'ranking': '59',
#    'song': ['Cool Kids'],
#    'songurl': ['/wiki/Cool_Kids_(Echosmith_song)'],
#    'titletext': 'Cool Kids',
#    'url': ['/wiki/Echosmith']},
#   {'band_singer': ['Avicii'],
#    'ranking': '60',
#    'song': ['Hey Brother'],
#    'songurl': ['/wiki/Hey_Brother'],
#    'titletext': 'Hey Brother',
#    'url': ['/wiki/Avicii']},
#   {'band_singer': ['Jason Derulo'],
#    'ranking': '61',
#    'song': ['Trumpets'],
#    'songurl': ['/wiki/Trumpets_(Jason_Derulo_song)'],
#    'titletext': 'Trumpets',
#    'url': ['/wiki/Jason_Derulo']},
#   {'band_singer': ['Maroon 5'],
#    'ranking': '62',
#    'song': ['Animals'],
#    'songurl': ['/wiki/Animals_(Maroon_5_song)'],
#    'titletext': 'Animals',
#    'url': ['/wiki/Maroon_5']},
#   {'band_singer': ['Jason Aldean'],
#    'ranking': '63',
#    'song': ["Burnin' It Down"],
#    'songurl': ['/wiki/Burnin%27_It_Down'],
#    'titletext': "Burnin' It Down",
#    'url': ['/wiki/Jason_Aldean']},
#   {'band_singer': ['Luke Bryan'],
#    'ranking': '64',
#    'song': ['Play It Again'],
#    'songurl': ['/wiki/Play_It_Again_(Luke_Bryan_song)'],
#    'titletext': 'Play It Again',
#    'url': ['/wiki/Luke_Bryan']},
#   {'band_singer': ['Tinashe', 'ScHoolboy Q'],
#    'ranking': '65',
#    'song': ['2 On'],
#    'songurl': ['/wiki/2_On'],
#    'titletext': '2 On',
#    'url': ['/wiki/Tinashe', '/wiki/ScHoolboy_Q']},
#   {'band_singer': ['Florida Georgia Line'],
#    'ranking': '66',
#    'song': ['Dirt'],
#    'songurl': ['/wiki/Dirt_(Florida_Georgia_Line_song)'],
#    'titletext': 'Dirt',
#    'url': ['/wiki/Florida_Georgia_Line']},
#   {'band_singer': ['OneRepublic'],
#    'ranking': '67',
#    'song': ['Love Runs Out'],
#    'songurl': ['/wiki/Love_Runs_Out'],
#    'titletext': 'Love Runs Out',
#    'url': ['/wiki/OneRepublic']},
#   {'band_singer': ['Brantley Gilbert'],
#    'ranking': '68',
#    'song': ['Bottoms Up'],
#    'songurl': ['/wiki/Bottoms_Up_(Brantley_Gilbert_song)'],
#    'titletext': 'Bottoms Up',
#    'url': ['/wiki/Brantley_Gilbert']},
#   {'band_singer': ['Becky G'],
#    'ranking': '69',
#    'song': ['Shower'],
#    'songurl': ['/wiki/Shower_(song)'],
#    'titletext': 'Shower',
#    'url': ['/wiki/Becky_G']},
#   {'band_singer': ['Rixton'],
#    'ranking': '70',
#    'song': ['Me and My Broken Heart'],
#    'songurl': ['/wiki/Me_and_My_Broken_Heart'],
#    'titletext': 'Me and My Broken Heart',
#    'url': ['/wiki/Rixton_(band)']},
#   {'band_singer': ['Martin Garrix'],
#    'ranking': '71',
#    'song': ['Animals'],
#    'songurl': ['/wiki/Animals_(Martin_Garrix_composition)'],
#    'titletext': 'Animals',
#    'url': ['/wiki/Martin_Garrix']},
#   {'band_singer': ['Rich Gang', 'Young Thug', 'Rich Homie Quan'],
#    'ranking': '72',
#    'song': ['Lifestyle'],
#    'songurl': ['/wiki/Lifestyle_(song)'],
#    'titletext': 'Lifestyle',
#    'url': ['/wiki/Rich_Gang', '/wiki/Young_Thug', '/wiki/Rich_Homie_Quan']},
#   {'band_singer': ['Kenny Chesney'],
#    'ranking': '73',
#    'song': ['American Kids'],
#    'songurl': ['/wiki/American_Kids'],
#    'titletext': 'American Kids',
#    'url': ['/wiki/Kenny_Chesney']},
#   {'band_singer': ['Sara Bareilles'],
#    'ranking': '74',
#    'song': ['Brave'],
#    'songurl': ['/wiki/Brave_(Sara_Bareilles_song)'],
#    'titletext': 'Brave',
#    'url': ['/wiki/Sara_Bareilles']},
#   {'band_singer': ['The Neighbourhood'],
#    'ranking': '75',
#    'song': ['Sweater Weather'],
#    'songurl': ['/wiki/Sweater_Weather'],
#    'titletext': 'Sweater Weather',
#    'url': ['/wiki/The_Neighbourhood']},
#   {'band_singer': ['Sam Hunt'],
#    'ranking': '76',
#    'song': ['Leave the Night On'],
#    'songurl': ['/wiki/Leave_the_Night_On'],
#    'titletext': 'Leave the Night On',
#    'url': ['/wiki/Sam_Hunt']},
#   {'band_singer': ['Chris Brown', 'Usher', 'Rick Ross'],
#    'ranking': '77',
#    'song': ['New Flame'],
#    'songurl': ['/wiki/New_Flame'],
#    'titletext': 'New Flame',
#    'url': ['/wiki/Chris_Brown', '/wiki/Usher_(musician)', '/wiki/Rick_Ross']},
#   {'band_singer': ['Michael Jackson', 'Justin Timberlake'],
#    'ranking': '78',
#    'song': ['Love Never Felt So Good'],
#    'songurl': ['/wiki/Love_Never_Felt_So_Good'],
#    'titletext': 'Love Never Felt So Good',
#    'url': ['/wiki/Michael_Jackson', '/wiki/Justin_Timberlake']},
#   {'band_singer': ['Dierks Bentley'],
#    'ranking': '79',
#    'song': ['Drunk on a Plane'],
#    'songurl': ['/wiki/Drunk_on_a_Plane'],
#    'titletext': 'Drunk on a Plane',
#    'url': ['/wiki/Dierks_Bentley']},
#   {'band_singer': ['Katy Perry'],
#    'ranking': '80',
#    'song': ['Birthday'],
#    'songurl': ['/wiki/Birthday_(Katy_Perry_song)'],
#    'titletext': 'Birthday',
#    'url': ['/wiki/Katy_Perry']},
#   {'band_singer': ['Lady Antebellum'],
#    'ranking': '81',
#    'song': ['Bartender'],
#    'songurl': ['/wiki/Bartender_(Lady_Antebellum_song)'],
#    'titletext': 'Bartender',
#    'url': ['/wiki/Lady_Antebellum']},
#   {'band_singer': ['Naughty Boy', 'Sam Smith'],
#    'ranking': '82',
#    'song': ['La La La'],
#    'songurl': ['/wiki/La_La_La_(Naughty_Boy_song)'],
#    'titletext': 'La La La',
#    'url': ['/wiki/Naughty_Boy', '/wiki/Sam_Smith_(singer)']},
#   {'band_singer': ['Robin Thicke', 'T.I.', 'Pharrell Williams'],
#    'ranking': '83',
#    'song': ['Blurred Lines'],
#    'songurl': ['/wiki/Blurred_Lines'],
#    'titletext': 'Blurred Lines',
#    'url': ['/wiki/Robin_Thicke', '/wiki/T.I.', '/wiki/Pharrell_Williams']},
#   {'band_singer': ['Lady Gaga', 'R. Kelly'],
#    'ranking': '84',
#    'song': ['Do What U Want'],
#    'songurl': ['/wiki/Do_What_U_Want'],
#    'titletext': 'Do What U Want',
#    'url': ['/wiki/Lady_Gaga', '/wiki/R._Kelly']},
#   {'band_singer': ['Shakira', 'Rihanna'],
#    'ranking': '85',
#    'song': ["Can't Remember to Forget You"],
#    'songurl': ['/wiki/Can%27t_Remember_to_Forget_You'],
#    'titletext': "Can't Remember to Forget You",
#    'url': ['/wiki/Shakira', '/wiki/Rihanna']},
#   {'band_singer': ['5 Seconds of Summer'],
#    'ranking': '86',
#    'song': ['Amnesia'],
#    'songurl': ['/wiki/Amnesia_(5_Seconds_of_Summer_song)'],
#    'titletext': 'Amnesia',
#    'url': ['/wiki/5_Seconds_of_Summer']},
#   {'band_singer': ['T.I.', 'Iggy Azalea'],
#    'ranking': '87',
#    'song': ['No Mediocre'],
#    'songurl': ['/wiki/No_Mediocre'],
#    'titletext': 'No Mediocre',
#    'url': ['/wiki/T.I.', '/wiki/Iggy_Azalea']},
#   {'band_singer': ['KONGOS'],
#    'ranking': '88',
#    'song': ['Come with Me Now'],
#    'songurl': ['/wiki/Come_with_Me_Now'],
#    'titletext': 'Come with Me Now',
#    'url': ['/wiki/Kongos_(band)']},
#   {'band_singer': ['Lil Wayne', 'Drake'],
#    'ranking': '89',
#    'song': ['Believe Me'],
#    'songurl': ['/wiki/Believe_Me_(Lil_Wayne_song)'],
#    'titletext': 'Believe Me',
#    'url': ['/wiki/Lil_Wayne', '/wiki/Drake_(rapper)']},
#   {'band_singer': ['Mike WiLL Made-It',
#     'Miley Cyrus',
#     'Wiz Khalifa',
#     'Juicy J'],
#    'ranking': '90',
#    'song': ['23'],
#    'songurl': ['/wiki/23_(song)'],
#    'titletext': '23',
#    'url': ['/wiki/Mike_Will_Made_It',
#     '/wiki/Miley_Cyrus',
#     '/wiki/Wiz_Khalifa',
#     '/wiki/Juicy_J']},
#   {'band_singer': ['Jake Owen'],
#    'ranking': '91',
#    'song': ["Beachin'"],
#    'songurl': ['/wiki/Beachin%27'],
#    'titletext': "Beachin'",
#    'url': ['/wiki/Jake_Owen']},
#   {'band_singer': ['Macklemore & Ryan Lewis', 'ScHoolboy Q', 'Hollis'],
#    'ranking': '92',
#    'song': ['White Walls'],
#    'songurl': ['/wiki/White_Walls'],
#    'titletext': 'White Walls',
#    'url': ['/wiki/Macklemore_%26_Ryan_Lewis',
#     '/wiki/ScHoolboy_Q',
#     '/wiki/Hollis_(singer)']},
#   {'band_singer': ['5 Seconds of Summer'],
#    'ranking': '93',
#    'song': ['She Looks So Perfect'],
#    'songurl': ['/wiki/She_Looks_So_Perfect'],
#    'titletext': 'She Looks So Perfect',
#    'url': ['/wiki/5_Seconds_of_Summer']},
#   {'band_singer': ['Zedd', 'Hayley Williams'],
#    'ranking': '94',
#    'song': ['Stay the Night'],
#    'songurl': ['/wiki/Stay_the_Night_(Zedd_song)'],
#    'titletext': 'Stay the Night',
#    'url': ['/wiki/Zedd', '/wiki/Hayley_Williams']},
#   {'band_singer': ['Beyoncé'],
#    'ranking': '95',
#    'song': ['Partition'],
#    'songurl': ['/wiki/Partition_(song)'],
#    'titletext': 'Partition',
#    'url': ['/wiki/Beyonc%C3%A9']},
#   {'band_singer': ['ScHoolboy Q', 'BJ the Chicago Kid'],
#    'ranking': '96',
#    'song': ['Studio'],
#    'songurl': ['/wiki/Studio_(song)'],
#    'titletext': 'Studio',
#    'url': ['/wiki/ScHoolboy_Q', '/wiki/BJ_the_Chicago_Kid']},
#   {'band_singer': ['Drake'],
#    'ranking': '97',
#    'song': ['0 to 100 / The Catch Up'],
#    'songurl': ['/wiki/0_to_100_/_The_Catch_Up'],
#    'titletext': '0 to 100 / The Catch Up',
#    'url': ['/wiki/Drake_(rapper)']},
#   {'band_singer': ['Lee Brice'],
#    'ranking': '98',
#    'song': ["I Don't Dance"],
#    'songurl': ['/wiki/I_Don%27t_Dance_(Lee_Brice_song)'],
#    'titletext': "I Don't Dance",
#    'url': ['/wiki/Lee_Brice']},
#   {'band_singer': ['Miranda Lambert', 'Carrie Underwood'],
#    'ranking': '99',
#    'song': ["Somethin' Bad"],
#    'songurl': ['/wiki/Somethin%27_Bad'],
#    'titletext': "Somethin' Bad",
#    'url': ['/wiki/Miranda_Lambert', '/wiki/Carrie_Underwood']},
#   {'band_singer': ['Miley Cyrus'],
#    'ranking': '100',
#    'song': ['Adore You'],
#    'songurl': ['/wiki/Adore_You'],
#    'titletext': 'Adore You',
#    'url': ['/wiki/Miley_Cyrus']}]}

# %% [markdown]
# #### Helpful notes
#
# Notice that some singles might have multiple songs:
#
# ```
# {'band_singer': ['Jewel'],
#   'ranking': 2,
#   'song': ['Foolish Games', 'You Were Meant for Me'],
#   'songurl': ['/wiki/Foolish_Games',
#    '/wiki/You_Were_Meant_for_Me_(Jewel_song)'],
#   'titletext': '" Foolish Games " / " You Were Meant for Me "',
#   'url': ['/wiki/Jewel_(singer)']}
# ```

# %% [markdown]
# And some singles don't have a song URL:
#
# ```
# {'band_singer': [u'Nu Flavor'],
#   'ranking': 91,
#   'song': [u'Heaven'],
#   'songurl': [None],
#   'titletext': u'"Heaven"',
#   'url': [u'/wiki/Nu_Flavor']}
# ```

# %% [markdown]
# Thus there are some issues this function must handle:
#
# 1. There can be more than one  `band_singer` as can be seen above (sometimes with a comma, sometimes with "featuring" in between). The best way to parse these is to look for the urls.
# 2. There can be two songs in a single, because of the way the industry works: there are two-sided singles. See https://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_1997 for an example. You can find other examples in 1998 and 1999.
# 3. The `titletext` is the contents of the table cell, and retains the quotes that Wikipedia puts on the single.
# 4. If no song anchor is found (see the 24th song in the above url), assume there is one song in the single, set `songurl` to [`None`] and the song name to the contents of the table cell with the quotes stripped (ie `song` is a one-element list with this the `titletext` stripped of its quotes).

# %% [markdown]
# As a check, we can do this for 1997. We'll print the first 5 outputs: `parse_year(1997, yearstext)[:5]`

# %% [markdown]
# This should give the following. Notice that the year 1997 exercises the edge cases we talked about earlier.

# %% [markdown]
# ```
# [{'band_singer': ['Elton John'],
#   'ranking': 1,
#   'song': ['Something About the Way You Look Tonight',
#    'Candle in the Wind 1997'],
#   'songurl': ['/wiki/Something_About_the_Way_You_Look_Tonight',
#    '/wiki/Candle_in_the_Wind_1997'],
#   'titletext': '" Something About the Way You Look Tonight " / " Candle in the Wind 1997 "',
#   'url': ['/wiki/Elton_John']},
#  {'band_singer': ['Jewel'],
#   'ranking': 2,
#   'song': ['Foolish Games', 'You Were Meant for Me'],
#   'songurl': ['/wiki/Foolish_Games',
#    '/wiki/You_Were_Meant_for_Me_(Jewel_song)'],
#   'titletext': '" Foolish Games " / " You Were Meant for Me "',
#   'url': ['/wiki/Jewel_(singer)']},
#  {'band_singer': ['Puff Daddy', 'Faith Evans', '112'],
#   'ranking': 3,
#   'song': ["I'll Be Missing You"],
#   'songurl': ['/wiki/I%27ll_Be_Missing_You'],
#   'titletext': '" I\'ll Be Missing You "',
#   'url': ['/wiki/Sean_Combs', '/wiki/Faith_Evans', '/wiki/112_(band)']},
#  {'band_singer': ['Toni Braxton'],
#   'ranking': 4,
#   'song': ['Un-Break My Heart'],
#   'songurl': ['/wiki/Un-Break_My_Heart'],
#   'titletext': '" Un-Break My Heart "',
#   'url': ['/wiki/Toni_Braxton']},
#  {'band_singer': ['Puff Daddy', 'Mase'],
#   'ranking': 5,
#   'song': ["Can't Nobody Hold Me Down"],
#   'songurl': ['/wiki/Can%27t_Nobody_Hold_Me_Down'],
#   'titletext': '" Can\'t Nobody Hold Me Down "',
#   'url': ['/wiki/Sean_Combs', '/wiki/Mase']}]
# ```

# %% [markdown]
# #### Save a json file of information from the scraped files

# %% [markdown]
# We do not want to lose all this work, so let's save the last data structure we created to disk. That way if you need to re-run from here, you don't need to redo all these requests and parsing.
#
# DO NOT RERUN THE HTTP REQUESTS TO WIKIPEDIA WHEN SUBMITTING.
#
# *We **DO NOT** need to see these JSON files in your submission!*

# %%
import json

# %%
# DO NOT RERUN THIS CELL WHEN SUBMITTING
fd = open("yearInfo.json","w")
json.dump(yearInfo, fd)
fd.close()
del yearInfo

# %% [markdown]
# Now let's reload our JSON file into the yearinfo variable, just to be sure everything is working.

# %%
# RERUN WHEN SUBMITTING
# Another way to deal with files. Has the advantage of closing the file for you.
with open("yearInfo.json", "r") as fd:
    year_Info = json.load(fd)

# %% [markdown]
# #### 1.4 Construct a year-song-singer dataframe from the yearly information

# %% [markdown]
# Let's construct a dataframe `flatframe` from the `yearinfo`. The frame should be similar to the frame below.  Each row of the frame represents a song, and carries with it the chief properties of year, song, singer, and ranking.
#
# ![](https://raw.githubusercontent.com/cs109/a-2017/master/hwassets/images/HW1SC1.png)

# %%
rows = []
for year in year_Info.keys():
    for song in year_Info[year]:
        song['year'] = year
        rows.append(song)
flatframe = pd.DataFrame(rows)
flatframe
# Out:
#                               band_singer ranking                       song                                   songurl                titletext                                              url  year
# 0                           [Boyz II Men]       1          [End of the Road]                   [/wiki/End_of_the_Road]          End of the Road                              [/wiki/Boyz_II_Men]  1992
# 1                         [Sir Mix-a-Lot]       2            [Baby Got Back]                     [/wiki/Baby_Got_Back]            Baby Got Back                            [/wiki/Sir_Mix-a-Lot]  1992
# 2                            [Kris Kross]       3                     [Jump]            [/wiki/Jump_(Kris_Kross_song)]                     Jump                               [/wiki/Kris_Kross]  1992
# 3                      [Vanessa Williams]       4   [Save the Best for Last]            [/wiki/Save_the_Best_for_Last]   Save the Best for Last                      [/wiki/Vanessa_L._Williams]  1992
# 4                                   [TLC]       5           [Baby-Baby-Baby]                    [/wiki/Baby-Baby-Baby]           Baby-Baby-Baby                               [/wiki/TLC_(band)]  1992
# ...                                   ...     ...                        ...                                       ...                      ...                                              ...   ...
# 2295    [ScHoolboy Q, BJ the Chicago Kid]      96                   [Studio]                     [/wiki/Studio_(song)]                   Studio    [/wiki/ScHoolboy_Q, /wiki/BJ_the_Chicago_Kid]  2014
# 2296                              [Drake]      97  [0 to 100 / The Catch Up]           [/wiki/0_to_100_/_The_Catch_Up]  0 to 100 / The Catch Up                           [/wiki/Drake_(rapper)]  2014
# 2297                          [Lee Brice]      98            [I Don't Dance]  [/wiki/I_Don%27t_Dance_(Lee_Brice_song)]            I Don't Dance                                [/wiki/Lee_Brice]  2014
# 2298  [Miranda Lambert, Carrie Underwood]      99            [Somethin' Bad]                   [/wiki/Somethin%27_Bad]            Somethin' Bad  [/wiki/Miranda_Lambert, /wiki/Carrie_Underwood]  2014
# 2299                        [Miley Cyrus]     100                [Adore You]                         [/wiki/Adore_You]                Adore You                              [/wiki/Miley_Cyrus]  2014
#
# [2300 rows x 7 columns]

# %%
#we must clean the data into individual and not as list
import re
for each in rows:
    for key in each:
        each[key] = str(each[key])
        each[key] = re.sub('[^A-Za-z0-9,_/ ]+', '', each[key])
        each[key] = re.sub('[^A-Za-z0-9,_/ ]+', '', each[key])
flatframe = pd.DataFrame(rows)
flatframe
# Out:
#                             band_singer ranking                     song                              songurl                titletext                                            url  year
# 0                           Boyz II Men       1          End of the Road                /wiki/End_of_the_Road          End of the Road                              /wiki/Boyz_II_Men  1992
# 1                           Sir MixaLot       2            Baby Got Back                  /wiki/Baby_Got_Back            Baby Got Back                              /wiki/Sir_MixaLot  1992
# 2                            Kris Kross       3                     Jump           /wiki/Jump_Kris_Kross_song                     Jump                               /wiki/Kris_Kross  1992
# 3                      Vanessa Williams       4   Save the Best for Last         /wiki/Save_the_Best_for_Last   Save the Best for Last                       /wiki/Vanessa_L_Williams  1992
# 4                                   TLC       5             BabyBabyBaby                   /wiki/BabyBabyBaby             BabyBabyBaby                                 /wiki/TLC_band  1992
# ...                                 ...     ...                      ...                                  ...                      ...                                            ...   ...
# 2295    ScHoolboy Q, BJ the Chicago Kid      96                   Studio                    /wiki/Studio_song                   Studio    /wiki/ScHoolboy_Q, /wiki/BJ_the_Chicago_Kid  2014
# 2296                              Drake      97  0 to 100 / The Catch Up        /wiki/0_to_100_/_The_Catch_Up  0 to 100 / The Catch Up                             /wiki/Drake_rapper  2014
# 2297                          Lee Brice      98             I Dont Dance  /wiki/I_Don27t_Dance_Lee_Brice_song             I Dont Dance                                /wiki/Lee_Brice  2014
# 2298  Miranda Lambert, Carrie Underwood      99             Somethin Bad                 /wiki/Somethin27_Bad             Somethin Bad  /wiki/Miranda_Lambert, /wiki/Carrie_Underwood  2014
# 2299                        Miley Cyrus     100                Adore You                      /wiki/Adore_You                Adore You                              /wiki/Miley_Cyrus  2014
#
# [2300 rows x 7 columns]

# %% [markdown]
# To construct the dataframe, we'll need to iterate over the years and the singles per year. Notice how, above, the dataframe is ordered by ranking and then year. While the exact order is up to you, note that you will have to come up with a scheme to order the information.
#
# Check that the dataframe has sensible data types. You will also likely find that the year field has become an "object" (Pandas treats strings as generic objects): this is due to the conversion to and back from JSON. Such conversions need special care. Fix any data type issues with `flatframe`. (See Pandas [astype](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.astype.html) function.)
# We will use this `flatframe` in the next question.
#
# (As an aside, we used the name `flatframe` to indicate that this dataframe is flattened from a hierarchical dictionary structure with the keys being the years.)

# %% [markdown]
# ### Who are the highest quality singers?

# %% [markdown]
# Here we show the highest quality singers and plot them on a bar chart.
#
# #### 1.5 Find highest quality singers according to how prolific they are
#
# What do we mean by highest quality? This is of course open to interpretation, but let's define "highest quality" here as the number of times a singer appears in the top 100 over this time period. If a singer appears twice in a year (for different songs), this is counted as two appearances, not one.
#
# Make a bar-plot of the most prolific singers. Singers on this chart should have appeared at-least more than 15 times. (HINT: look at the docs for the pandas method `value_counts`.)

# %%
highestCount = flatframe["band_singer"].value_counts()
highestCount
# Out:
# Mariah Carey                   18
# Rihanna                        18
# Pink                           17
# Kelly Clarkson                 16
# Britney Spears                 16
#                                ..
# Bastille                        1
# Juelz Santana                   1
# Christina Aguilera, Lil Kim     1
# 20 Fingers, Gillette            1
#                                 1
# Name: band_singer, Length: 1241, dtype: int64

# %%
qualitySingers = highestCount[highestCount.values>15]
# len(qualitySingers)
plt.figure(figsize = (10,6), frameon = False)
sns.barplot(qualitySingers.index, qualitySingers.values, color = 'blue')
plt.xticks(rotation=90)
plt.title("Top 20 occurences on Billboard by Artists");

# %% [markdown]
# #### 1.6 What if we used a different metric?

# %% [markdown]
# What we would like to capture is this: a singer should to be scored higher if the singer appears higher in the rankings. So we'd say that a singer who appeared once at a higher and once at a lower ranking is a "higher quality" singer than one who appeared twice at a lower ranking.
#
# To do this, group all of a singers songs together and assign each song a score `101 - ranking`. Order the singers by their total score and make a bar chart for the top 20.

# %%
flatframe['ranking'] = pd.to_numeric(flatframe['ranking'])

flatframe['quality_score'] = 101 - flatframe['ranking']
temp = flatframe.groupby('band_singer').quality_score.sum().sort_values(ascending = False)
top20 = temp.head(20)
# top20
plt.figure(figsize = (10,6), frameon = False)
sns.barplot(top20.index, top20.values, color = 'blue')
plt.xticks(rotation=90)
plt.xlabel('Artist')
plt.ylabel('Score: 101 - Ranking');

# %% [markdown]
# #### 1.7 Do you notice any major differences when you change the metric?
#
# How have the singers at the top shifted places? Why do you think this happens?

# %% [markdown]
# ## Q2. Scraping and Constructing: Information about Artists, Bands and Genres from Wikipedia

# %% [markdown]
# Our next job is to use those band/singer urls we collected under `flatframe.url` and get information about singers and/or bands.

# %% [markdown]
# ### Scrape information about artists from wikipedia

# %% [markdown]
# We wish to fetch information about the singers or groups for all the winning songs in a list of years.
#
# Here we show a function that fetches information about a singer or group from their url on wikipedia. We create a cache object `urlcache` that will avoid redundant HTTP requests (e.g. an artist might have multiple singles on a single year, or be on the list over a span of years). Once we have fetched information about an artist, we don't need to do it again. The caching also helps if the network goes down, or the target website is having some problems. You simply need to run the `get_page` function below again, and the `urlcache` dictionary will continue to be filled.
#
# If the request gets an HTTP return code different from 200, (such as a 404 not found or 500 Internal Server Error) the cells for that URL will have a value of 1; and if the request completely fails (e.g. no network connection) the cell will have a value of 2. This will allow you to analyse the failed requests.
#
# Notice that we have wrapped the call in whats called _an exception block_. We try to make the request. If it fails entirely, or returns a HTTP code thats not 200, we set the status to 2 and 1 respectively.

# %%
urlcache={}

# %%
def get_page(url):
    # Check if URL has already been visited.
    if (url not in urlcache) or (urlcache[url]==1) or (urlcache[url]==2):
        time.sleep(1)
        # try/except blocks are used whenever the code could generate an exception (e.g. division by zero).
        # In this case we don't know if the page really exists, or even if it does, if we'll be able to reach it.
        try:
            r = requests.get("http://en.wikipedia.org%s" % url)

            if r.status_code == 200:
                urlcache[url] = r.text
            else:
                urlcache[url] = 1
        except:
            urlcache[url] = 2
    return urlcache[url]

# %% [markdown]
# We sort the `flatframe` by year, ascending, first. Think why.

# %%
flatframe=flatframe.sort_values('year')
flatframe.head()
# Out:
#      band_singer  ranking                        song                                       songurl                   titletext                 url  year  quality_score
# 0    Boyz II Men        1             End of the Road                         /wiki/End_of_the_Road             End of the Road   /wiki/Boyz_II_Men  1992            100
# 72   Paula Abdul       73  Blowing Kisses in the Wind              /wiki/Blowing_Kisses_in_the_Wind  Blowing Kisses in the Wind   /wiki/Paula_Abdul  1992             28
# 71  Ugly Kid Joe       72        Everything About You  /wiki/Everything_About_You_Ugly_Kid_Joe_song        Everything About You  /wiki/Ugly_Kid_Joe  1992             29
# 70      The Cure       71           Friday Im in Love                     /wiki/Friday_I27m_in_Love           Friday Im in Love      /wiki/The_Cure  1992             30
# 69   Bryan Adams       70  Do I Have to Say the Words            /wiki/Do_I_Have_to_Say_the_Words3F  Do I Have to Say the Words   /wiki/Bryan_Adams  1992             31

# %% [markdown]
# #### Pulling and saving the data

# %% [markdown]
# You may have to run this function again and again, in case there were network problems. Note that, because there is a "global" cache, it will take less time each time you run it. Also note that this function is designed to be run again and again: it attempts to make sure that there are no unresolved pages remaining. Let us make sure of this: *the sum below should be 0, and the boolean True.*

# %%
# DO NOT RERUN THIS CELL WHEN SUBMITTING
# Here we are populating the url cache
# subsequent calls to this cell should be very fast, since Python won't
# need to fetch the page from the web server.
# NOTE this function will take quite some time to run (about 30 mins for me), since we sleep 1 second before
# making a request. If you run it again it will be almost instantaneous, save requests that might have failed
# (you will need to run it again if requests fail..see cell below for how to test this)
flatframe["url"].apply(get_page)

# %%
# DO NOT RERUN THIS CELL WHEN SUBMITTING
print("Number of bad requests:",np.sum([(urlcache[k]==1) or (urlcache[k]==2) for k in urlcache])) # no one or 0's)
print("Did we get all urls?", len(flatframe.url.unique())==len(urlcache)) # we got all of the urls

# %% [markdown]
# Let's save the `urlcache` to disk, just in case we need it again.

# %%
# DO NOT RERUN THIS CELL WHEN SUBMITTING
with open("artistinfo.json","w") as fd:
    json.dump(urlcache, fd)
del urlcache

# %%
# RERUN WHEN SUBMITTING
with open("artistinfo.json") as json_file:
    urlcache = json.load(json_file)

# %% [markdown]
# #### 2.1 Extract information about singers and bands

# %% [markdown]
# From each page we collected about a singer or a band, extract the following information:
#
# 1. If the page has the text "Born" in the sidebar on the right, extract the element with the class `.bday`. If the page doesn't contain "Born", store `False`.  Store either of these into the variable `born`. We want to analyze the artist's age.
#
# 2. If the text "Years active" is found, but no "born", assume a band. Store into the variable `ya` the value of the next table cell corresponding to this, or `False` if the text is not found.
#
# Put this all into a function `singer_band_info` which takes the singer/band url as argument and returns a dictionary `dict(url=url, born=born, ya=ya)`.
#
# The information can be found on the sidebar on each such wikipedia page, as the example here shows:
#
# ![sandg](https://raw.githubusercontent.com/cs109/a-2017/master/hwassets/images/sandg.png).

# %% [markdown]
# Write the function `singer_band_info` according to the following specification:

# %%
"""
Function
--------
singer_band_info

Inputs
------
url: the url
page_text: the text associated with the url
   
Returns
-------
A dictionary with the following data:
    url: copy the input argument url into this value
    born: the artist's birthday
    ya: years active variable

Notes
-----
See description above. Also note that some of the genres urls might require a 
bit of care and special handling.
"""
def singer_band_info(url, page_text):
    birthdayList = {}
    birthday = ''
    ya = ''
    soup = BeautifulSoup(page_text[url], "lxml")
    tables = soup.find('table', attrs={'class':'infobox vcard plainlist'})
    if (tables == None):
        tables = soup.find('table', attrs={'class':'infobox biography vcard'})
    bday = tables.find('span', {'class': 'birthday'})
    if birthday: 
        birthday = birthday.get_text()[:4]
        birthdayList = {'url' : url, 'born' : birthday, 'ya' : ya}
    else:
        ya = False
        for tr in tables.find_all('tr'):
            if hasattr(tr.th, 'span'):
                if hasattr(tr.th.span, 'string'):
                    if tr.th.span.string == 'Years active':                
                        if hasattr(tr.th, 'span'):
                            ya = tr.td.text
                            birthday = 'False'
                            birthdayList = {'url' : url, 'born' : 'False', 'ya' : ya}
    return birthdayList
url = '/wiki/End_of_the_Road'
singer_band_info(url, urlcache)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-100-b578d56d74ce> in <module>
#      45     return birthdayList
#      46 url = '/wiki/End_of_the_Road'
# ---> 47 singer_band_info(url, urlcache)
#
# <ipython-input-100-b578d56d74ce> in singer_band_info(url, page_text)
#      25     birthday = ''
#      26     ya = ''
# ---> 27     soup = BeautifulSoup(page_text[url], "lxml")
#      28     tables = soup.find('table', attrs={'class':'infobox vcard plainlist'})
#      29     if (tables == None):
#
# KeyError: '/wiki/End_of_the_Road'

# %% [markdown]
# #### 2.2  Merging this information in

# %% [markdown]
# Iterate over the items in the singer-group dictionary cache `urlcache`, run the above function, and create a dataframe from there with columns `url`, `born`, and `ya`. Merge this dataframe on the `url` key with `flatframe`, creating a rather wide dataframe that we shall call `largedf`. It should look something like this:
#
# ![](https://raw.githubusercontent.com/cs109/a-2017/master/hwassets/images/HW1SC3.png)
#
# Notice how the `born` and `ya` and `url` are repeated every time a different song from a given band is represented in a row.

# %%
merge = []
birthdayDict = {}
for url in urlcache.keys():
    birthdayDict = singer_band_info(url, urlcache)
    merge.append(birthdayDict)

# %%
mergeData = pd.merge(flatframe, pd.DataFrame(merge), left_on='url', right_on='url', how="outer")

# %% [markdown]
# #### 2.3 What is the age at which singers achieve their top ranking?

# %% [markdown]
# Plot a histogram of the age at which singers achieve their top ranking. What conclusions can you draw from this distribution of ages?
#
# *HINT: You will need to do some manipulation of the `born` column, and find the song for which a band or an artist achieves their top ranking. You will then need to put these rows together into another dataframe or array to make the plot.*

# %% [markdown]
# #### 2.4 At what year since inception do bands reach their top rankings?

# %% [markdown]
# Make a similar calculation to plot a histogram of the years since inception at which bands reach their top ranking. What conclusions can you draw?
